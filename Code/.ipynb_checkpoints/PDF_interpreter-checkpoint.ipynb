# %% [markdown]
# # File to extract sentences from text document

# %%
# import required libraries - assume already ran pip install pyPDF2
import PyPDF2
import re

# %%
# Open pdf reader from file name. Return reader object and #pages
def open_pdf_reader(filename):
    # create the pdf reader
    pdf_file_obj = open(filename, 'rb')
    
    # get the reader object
    pdf_reader = PyPDF2.PdfFileReader(pdf_file_obj)

    # get the page numbers
    num_pages = pdf_reader.numPages
    
    return pdf_reader, num_pages

# %%
# get the page text. Remove the page number and return as a string. Will ignore pages without valid page numbers.
# valid page numbers assumed to have the last digit as a number. A-5, A5 works, but 5A or 5-A or ii do not work
def get_page_text(reader, page_num):
    # set of valid 
    # pull out raw text
    raw_text = reader.getPage(page_num).extractText()
    
    # extract page number - assume '\n' in first 'x' identifies it. but no "."
    i = 10
    valid_number = False
    while i > 0:
        if raw_text[i] != '\n': # check if != \n continue searching backward
            i = i-1
            continue
        elif raw_text[i-1].isdigit(): # check if there is number, if so assume it is a page number
            # flag this search as valid. Also use i as the top of the slice
            valid_number = True
            break
        else:
            i = i-1
    
    # if not valid page number, skip by returning empty text
    if valid_number == False:
        return '', ''

    # page number slice
    pdf_page_num = raw_text[:i].replace('\n', '')
    
    # remainder text
    new_text = raw_text[i:]
    
    return pdf_page_num, new_text

# %%
# function to extract sentences from a page
def extract_page_sentences(reader, page_num, residual_text ):
    # Get additional text - an empty pdf_page_num or new_text should be skipped.
    try:
        pdf_page_num, new_text = get_page_text(reader, page_num)
    except:
        pdf_page_num = ''
        new_text = ''
        
    if pdf_page_num == '':
        print('should skip this page. There is no valid page number so likely table of context or odd format')
        return [], ''

    page_text = residual_text + new_text

    # initialize variables needed
    temp_sentences = [] # local copy of extracted sentences
    local_num = 0 # running number of the sentences in the page
    i_start = 0 # position in the temp_text
    i_max = len(page_text) # if any thing returns past this point, collect as residual and be done
    i_period = 0 # i_of the active period underinvestigation

    not_at_end = True

    # continue while not at the end
    while(not_at_end):
        # get the next possible period
        i_period = page_text.find('.', i_period +1 )
        is_sentence_end = False

        # special cases - end of the file:
        if i_period < 0: # if there are no other periods: 
            not_at_end = False
            continue

        elif i_period == i_max-2 and page_text[i_period:] == '.\n': # special case where exactly a sentence at the end of the page
            is_sentence_end = True
            not_at_end = False

        elif i_period > i_max - 10: # if too close to the end, just attach to the next page
            not_at_end = False
            continue

        # Identify if the period is the end of a sentence

        # reject if the '.' is proceeded and is followed by a number
        if page_text[i_period-1].isdigit() and page_text[i_period+1].isdigit():
            continue

        # look for positive identification of a sentence end;
        expr = '\\n[A-Z]'
        if re.search(expr, page_text[i_period+1:i_period+4]):
            is_sentence_end = True

        expr = '  [A-Z]'
        if re.search(expr, page_text[i_period+1:i_period+4]):
            is_sentence_end = True

        expr = ' [A-Z]' # only one space check that there was not a capital proceeding the .
        if re.search(expr, page_text[i_period+1:i_period+3]):
            expr = '[A-Z]'
            if re.search(expr, page_text[i_period-3:i_period]):
                is_sentence_end = False
            else:
                is_sentence_end = True

        # special case where we check if the period is followed by numbering in perenthesis
        expr = '\\n\(\w{1,3}\)'
        if re.search(expr, page_text[i_period+1:i_period+8]):
            is_sentence_end = True

        # special case where we check for \n.............
        expr = '\\n...'
        if re.search(expr, page_text[i_period-2:i_period+3]):
            is_sentence_end = True

        # if is_sentence_end, select the sentence
        if is_sentence_end:
            local_num = local_num + 1
            entry = {}
            entry['page_num'] = str(page_num)
            entry['pdf_page_num'] = pdf_page_num
            entry['local_num'] = local_num
            entry['category'] = 'sentence'
            entry['sentence'] = page_text[i_start:i_period+1]

            # add the entry to the set
            temp_sentences.append(entry)

            # set i_start to be the next location after i_period
            i_start = i_period+1

            # check for special case of ..... If so, remove ....
            expr = '\\n...'
            if re.search(expr, page_text[i_period-2:i_period+3]):
                i_dot = i_period
                check = True
                while check:
                    # step forward through the text
                    i_dot = i_dot+1

                    # stop advancing once there is a real character
                    if re.search('\w', page_text[i_dot]) and page_text[i_dot+1] != '.':
                        check = False

                # set i_start at the last i_dot which was not a dot
                i_start = i_dot
                i_period = i_dot


    # record the residual
    residual_text = page_text[i_start:-1]

    return temp_sentences, residual_text

# %%
# function to globalize the sentences - update the running number and repare the sentences ot have only standard characters
def globalize_sentences(temp_sentences, global_num):

    # pull each entry individually.
    max_num = 0
    global_sentences = []
    for entry in temp_sentences:
        # make global number
        entry['global_num'] = int(entry['local_num']) + global_num

        # update tracker of the max number
        max_num = max([global_num, entry['global_num']])

        # remove non-standard characters from the sentences
        entry['sentence'] = entry['sentence'].replace('\n', '')    
        entry['sentence'] = entry['sentence'].replace("[^a-zA-Z0-9#']", " ")
        entry['sentence'] = entry['sentence'].strip()

        # append the correct entry to the global entries   
        global_sentences.append(entry)

    # return temp_sentences, global_num
    return global_sentences, max_num

# %%
# Control - run the functions to extract sentences from a file
filename = '../Data/raw_pdfs/20190220_02IUQ7_Prospectus_SD000000002587520085.pdf'
reader, num_pages = open_pdf_reader(filename)

# hold extracted sentences dictionary:
# global_num: keep an order of extraction - could consider the proximity of sentences in later analysis
# page_num: page number of the extracted text
# category: type of sentence or set of words extracted - could be sentence or heading or other
# sentence: hold the actual sentence
sentences = []
residual_text = ''
global_num = 0

# extract page by page. Execute by all information in a buffer - patterns cannot be extracted from a single location.
# between pages hold onto residual information and pass into the next page for concatination
for page_num in range(0,num_pages-1):
    temp_sentences, residual_text = extract_page_sentences(reader, page_num, residual_text )
    
    # if the sentences are empty, skip the page and keep going
    if temp_sentences == []:
        continue

    # fix the temp_sentences - remove extra characters, make lower
    temp_sentences, global_num = globalize_sentences(temp_sentences, global_num) 

    # append the temp_sentences to the set of sentences
    sentences = sentences + temp_sentences

    print('page ', str(page_num), ' global_num ', str(global_num))
sentences
# Out:
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# page  22  global_num  23
# page  23  global_num  51
# page  24  global_num  72
# page  25  global_num  94
# page  26  global_num  104
# page  27  global_num  111
# page  28  global_num  121
# page  29  global_num  128
# page  30  global_num  138
# page  31  global_num  145
# page  32  global_num  148
# page  33  global_num  163
# page  34  global_num  178
# page  35  global_num  186
# page  36  global_num  190
# page  37  global_num  204
# page  38  global_num  215
# page  39  global_num  228
# page  40  global_num  241
# page  41  global_num  254
# page  42  global_num  263
# page  43  global_num  277
# page  44  global_num  293
# page  45  global_num  311
# page  46  global_num  331
# page  47  global_num  336
# page  49  global_num  355
# page  50  global_num  383
# page  51  global_num  401
# page  52  global_num  413
# page  53  global_num  431
# page  54  global_num  458
# page  55  global_num  480
# page  56  global_num  500
# page  57  global_num  526
# page  58  global_num  534
# page  59  global_num  541
# page  60  global_num  551
# page  61  global_num  578
# page  62  global_num  594
# page  63  global_num  616
# page  64  global_num  638
# page  65  global_num  654
# page  66  global_num  676
# page  67  global_num  694
# page  68  global_num  719
# page  69  global_num  739
# page  70  global_num  765
# page  71  global_num  786
# page  72  global_num  798
# page  73  global_num  821
# page  74  global_num  846
# page  75  global_num  872
# page  76  global_num  887
# page  77  global_num  911
# page  78  global_num  931
# page  79  global_num  953
# page  80  global_num  977
# page  81  global_num  1000
# page  82  global_num  1021
# page  83  global_num  1040
# page  84  global_num  1058
# page  85  global_num  1075
# page  86  global_num  1095
# page  87  global_num  1118
# page  88  global_num  1139
# page  89  global_num  1159
# page  90  global_num  1174
# page  91  global_num  1200
# page  92  global_num  1219
# page  93  global_num  1237
# page  94  global_num  1260
# page  95  global_num  1275
# page  96  global_num  1294
# page  97  global_num  1306
# page  98  global_num  1318
# page  99  global_num  1342
# page  100  global_num  1353
# page  101  global_num  1368
# page  102  global_num  1391
# page  103  global_num  1403
# page  104  global_num  1422
# page  105  global_num  1438
# page  106  global_num  1457
# page  107  global_num  1477
# page  108  global_num  1492
# page  109  global_num  1506
# page  110  global_num  1518
# page  111  global_num  1531
# page  112  global_num  1542
# page  113  global_num  1559
# page  114  global_num  1578
# page  115  global_num  1596
# page  116  global_num  1606
# page  117  global_num  1615
# page  118  global_num  1624
# page  119  global_num  1633
# page  120  global_num  1641
# page  121  global_num  1646
# page  122  global_num  1649
# page  123  global_num  1659
# page  124  global_num  1662
# page  125  global_num  1668
# page  126  global_num  1675
# page  128  global_num  1680
# page  129  global_num  1689
# page  130  global_num  1697
# page  131  global_num  1706
# page  132  global_num  1711
# page  133  global_num  1718
# page  134  global_num  1725
# page  138  global_num  1727
# page  139  global_num  1735
# page  140  global_num  1740
# page  141  global_num  1742
# page  142  global_num  1745
# page  143  global_num  1749
# page  144  global_num  1757
# page  147  global_num  1759
# page  148  global_num  1762
# page  149  global_num  1767
# page  150  global_num  1772
# page  151  global_num  1784
# page  152  global_num  1793
# page  153  global_num  1800
# page  154  global_num  1804
# page  155  global_num  1805
# page  156  global_num  1807
# page  157  global_num  1811
# page  158  global_num  1812
# page  159  global_num  1816
# page  160  global_num  1818
# page  161  global_num  1827
# page  162  global_num  1832
# page  163  global_num  1846
# page  164  global_num  1857
# page  165  global_num  1859
# page  166  global_num  1867
# page  167  global_num  1885
# page  168  global_num  1892
# page  169  global_num  1896
# page  170  global_num  1906
# page  171  global_num  1908
# page  172  global_num  1912
# page  173  global_num  1920
# page  174  global_num  1929
# page  175  global_num  1942
# page  176  global_num  1952
# page  177  global_num  1968
# page  178  global_num  1983
# page  179  global_num  2005
# page  180  global_num  2030
# page  181  global_num  2044
# page  182  global_num  2065
# page  183  global_num  2083
# page  184  global_num  2108
# page  185  global_num  2128
# page  186  global_num  2135
# page  187  global_num  2150
# page  188  global_num  2165
# page  189  global_num  2190
# page  190  global_num  2213
# page  191  global_num  2237
# page  192  global_num  2264
# page  193  global_num  2290
# page  194  global_num  2304
# page  195  global_num  2313
# page  196  global_num  2323
# page  197  global_num  2324
# page  198  global_num  2330
# page  199  global_num  2342
# page  200  global_num  2350
# page  201  global_num  2354
# page  202  global_num  2368
# page  203  global_num  2382
# page  204  global_num  2393
# page  206  global_num  2398
# page  207  global_num  2410
# page  208  global_num  2427
# page  209  global_num  2440
# page  210  global_num  2445
# page  211  global_num  2455
# page  212  global_num  2459
# page  213  global_num  2463
# page  214  global_num  2473
# page  215  global_num  2486
# page  216  global_num  2499
# page  217  global_num  2510
# page  218  global_num  2522
# page  219  global_num  2537
# page  220  global_num  2546
# page  221  global_num  2564
# page  222  global_num  2583
# page  223  global_num  2592
# page  224  global_num  2600
# page  225  global_num  2612
# page  226  global_num  2624
# page  227  global_num  2630
# page  228  global_num  2644
# page  229  global_num  2655
# page  230  global_num  2660
# page  231  global_num  2674
# page  232  global_num  2685
# page  233  global_num  2692
# page  235  global_num  2696
# page  237  global_num  2701
# page  239  global_num  2703
# page  240  global_num  2722
# page  241  global_num  2737
# page  242  global_num  2745
# page  243  global_num  2758
# page  244  global_num  2777
# page  245  global_num  2802
# page  246  global_num  2815
# page  247  global_num  2835
# page  248  global_num  2863
# page  249  global_num  2889
# page  250  global_num  2911
# page  251  global_num  2937
# page  252  global_num  2956
# page  253  global_num  2988
# page  254  global_num  3015
# page  255  global_num  3035
# page  256  global_num  3058
# page  257  global_num  3076
# page  258  global_num  3095
# page  259  global_num  3110
# page  260  global_num  3125
# page  261  global_num  3147
# page  262  global_num  3171
# page  263  global_num  3192
# page  264  global_num  3214
# page  265  global_num  3234
# page  266  global_num  3253
# page  267  global_num  3272
# page  268  global_num  3291
# page  269  global_num  3314
# page  270  global_num  3327
# page  271  global_num  3348
# page  272  global_num  3367
# page  273  global_num  3388
# page  274  global_num  3424
# page  275  global_num  3448
# page  276  global_num  3466
# page  277  global_num  3482
# page  278  global_num  3499
# page  279  global_num  3513
# page  280  global_num  3526
# page  281  global_num  3535
# page  282  global_num  3559
# page  283  global_num  3561
# page  284  global_num  3668
# page  285  global_num  3784
# page  286  global_num  3896
# page  287  global_num  4012
# page  288  global_num  4130
# page  289  global_num  4142
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# page  308  global_num  4175
# page  309  global_num  4208
# page  310  global_num  4219
# should skip this page. There is no valid page number so likely table of context or odd format
# page  312  global_num  4246
# page  313  global_num  4282
# page  314  global_num  4291
# page  315  global_num  4292
# page  316  global_num  4313
# page  317  global_num  4332
# page  318  global_num  4351
# page  319  global_num  4375
# page  320  global_num  4392
# page  321  global_num  4394
# page  322  global_num  4409
# page  323  global_num  4422
# page  324  global_num  4440
# page  325  global_num  4449
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# page  373  global_num  4455
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# should skip this page. There is no valid page number so likely table of context or odd format
# page  386  global_num  4465
# page  387  global_num  4482
# should skip this page. There is no valid page number so likely table of context or odd format
# [{'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'SUMMARY OF OFFERING CIRCULARThe following summary is qualified in its entirety by reference to the more detailed information appearing elsewhere in this Offering Circular.',
#   'global_num': 1},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 2,
#   'category': 'sentence',
#   'sentence': 'Capitalized terms used in this summary and notdefined in this summary have the meanings given to them elsewhere in this Offering Circular.',
#   'global_num': 2},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 3,
#   'category': 'sentence',
#   'sentence': 'See ﬁIndex of Significant Termsﬂ in this Offering Circular.',
#   'global_num': 3},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'Purchasers should carefully read this Offering Circular in its entirety, including the information set forth under ﬁRisk Factorsﬂ in this Offering Circular, prior to making an investment in the Certificates.',
#   'global_num': 4},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'Title of Certificates.',
#   'global_num': 5},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'Waikiki Beach HotelTrust 2019-WBM,Commercial Mortgage Pass-Through Certificates, Series 2019-WBM, which will be issued pursuant to the Trust and Servicing Agreement, to be dated as of the Closing Date, among the Depositor, the Trustee, the Certificate Administrator, the Servicer, the Special Servicerand the Operating Advisor(the ﬁTrust and Servicing Agreementﬂ).',
#   'global_num': 6},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': 'Depositor.',
#   'global_num': 7},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 8,
#   'category': 'sentence',
#   'sentence': 'Wells Fargo Commercial Mortgage Securities, Inc. (the ﬁDepositorﬂ), a North Carolina corporation, and an affiliate of Wells Fargo Bank, National Association (aMortgage Loan Seller, the Servicerand the Certificate Administrator) and Wells Fargo Securities, LLC (anInitial Purchaser).  SeeﬁTransaction PartiesŠThe Depositorﬂ in this Offering Circular.',
#   'global_num': 8},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 9,
#   'category': 'sentence',
#   'sentence': 'Mortgage Loan Sellers.',
#   'global_num': 9},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 10,
#   'category': 'sentence',
#   'sentence': 'Each of the following entities (collectively, the ﬁMortgage Loan Sellersﬂ) was a co-originator of the Mortgage Loan.',
#   'global_num': 10},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 11,
#   'category': 'sentence',
#   'sentence': 'On the Closing Date, each Mortgage Loan Seller will sell its respective portion of the Mortgage Loan set forth in the table below (each a ﬁLoan Percentage Interestﬂ) to the Depositor.',
#   'global_num': 11},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 12,
#   'category': 'sentence',
#   'sentence': 'Mortgage Loan SellerOriginal Principal Balance of the Mortgage Loan Seller portion% of Initial Original Principal Balance of the Mortgage LoanWells Fargo Bank, National Association..',
#   'global_num': 12},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 13,
#   'category': 'sentence',
#   'sentence': '201,900,00060.0%JPMorgan Chase Bank, National Association.',
#   'global_num': 13},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 14,
#   'category': 'sentence',
#   'sentence': '67,300,00020.0Goldman Sachs Mortgage Company.',
#   'global_num': 14},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 15,
#   'category': 'sentence',
#   'sentence': '67,300,00020.0Total.',
#   'global_num': 15},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 16,
#   'category': 'sentence',
#   'sentence': '336,500,000100.0%See ﬁTransaction PartiesŠThe Mortgage Loan Sellersﬂ in this Offering Circular.',
#   'global_num': 16},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 17,
#   'category': 'sentence',
#   'sentence': 'Issuing Entity.',
#   'global_num': 17},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 18,
#   'category': 'sentence',
#   'sentence': 'Waikiki Beach HotelTrust 2019-WBM(the ﬁTrustﬂ), a New York common law trust to be formed on the Closing Date pursuant to the Trust and Servicing Agreement.',
#   'global_num': 18},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 19,
#   'category': 'sentence',
#   'sentence': 'See ﬁTransaction PartiesŠThe Issuing Entityﬂ in this Offering Circular.',
#   'global_num': 19},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 20,
#   'category': 'sentence',
#   'sentence': 'Servicer.',
#   'global_num': 20},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 21,
#   'category': 'sentence',
#   'sentence': 'Wells Fargo Bank, National Association, a national banking association (in its capacity as servicer, the ﬁServicerﬂ).',
#   'global_num': 21},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 22,
#   'category': 'sentence',
#   'sentence': 'The principal west coast commercial mortgage master servicing office of Wells Fargo Bank, National Association is located at MAC A0227-020, 1901 Harrison Street, Oakland, California 94612.',
#   'global_num': 22},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 23,
#   'category': 'sentence',
#   'sentence': 'The principal east coast commercial mortgage master servicing office of Wells Fargo Bank, National Association is located at MAC D1050-084, 401 South Tryon Street, 8thFloor, Charlotte, North Carolina 28202. See ﬁTransaction PartiesŠThe Servicerﬂ in this Offering Circular.',
#   'global_num': 23},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'Special Servicer.',
#   'global_num': 24},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 2,
#   'category': 'sentence',
#   'sentence': 'CWCapital Asset Management LLC, aDelaware limited liability company, acting as special servicer(the ﬁSpecial Servicerﬂ).',
#   'global_num': 25},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 3,
#   'category': 'sentence',
#   'sentence': 'The principal servicing offices of the Special Servicer are located at 7501 Wisconsin Avenue, Suite 500 West, Bethesda, Maryland 20814.',
#   'global_num': 26},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'See ﬁTransaction PartiesŠThe Special Servicerﬂ in this Offering Circular.',
#   'global_num': 27},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'The Special Servicer may be removed, with or without cause, and a successor Special Servicer appointed at any time as described under ﬁDescription of the Trust and Servicing AgreementŠReplacement of the Special Servicer After Operating Advisor Recommendation and Investor Voteﬂ and ﬁŠReplacement of the Special Servicerﬂin this Offering Circular.',
#   'global_num': 28},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'Trustee.',
#   'global_num': 29},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': 'Wilmington Trust, National Association, a national banking association (the ﬁTrusteeﬂ).',
#   'global_num': 30},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 8,
#   'category': 'sentence',
#   'sentence': 'The principal place of business of Wilmington Trust, National Association, is 1100 North Market Street, Wilmington, Delaware 19890.',
#   'global_num': 31},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 9,
#   'category': 'sentence',
#   'sentence': 'See ﬁTransaction PartiesŠThe Trusteeﬂ in this Offering Circular.',
#   'global_num': 32},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 10,
#   'category': 'sentence',
#   'sentence': 'Certificate Administrator.',
#   'global_num': 33},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 11,
#   'category': 'sentence',
#   'sentence': 'Wells Fargo Bank, National Association, a national banking association (in such capacity, the ﬁCertificate Administratorﬂ). The principal corporate trust offices of the Certificate Administrator are located at 9062 Old Annapolis Road, Columbia, Maryland 21045, and its office for certificate transfer services is located at 600 South 4thStreet, 7thFloor, MAC N9300-070, Minneapolis, Minnesota 55479.   See ﬁTransaction PartiesŠThe Certificate Administratorﬂ in this Offering Circular.',
#   'global_num': 34},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 12,
#   'category': 'sentence',
#   'sentence': 'Operating Advisor.',
#   'global_num': 35},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 13,
#   'category': 'sentence',
#   'sentence': 'Park Bridge Lender Services LLC, a New York limited liability company and an indirect wholly-owned subsidiary of Park Bridge Financial LLC,acting asoperating advisor(the ﬁOperating Advisorﬂ).',
#   'global_num': 36},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 14,
#   'category': 'sentence',
#   'sentence': 'The principal place of business of the Operating Advisor is 600 Third Avenue, 40th Floor, New York, New York 10016.',
#   'global_num': 37},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 15,
#   'category': 'sentence',
#   'sentence': 'See ﬁTransaction PartiesŠThe Operating Advisorﬂ in this Offering Circular.',
#   'global_num': 38},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 16,
#   'category': 'sentence',
#   'sentence': 'Initial Purchasers.',
#   'global_num': 39},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 17,
#   'category': 'sentence',
#   'sentence': 'Wells Fargo Securities, LLC(ﬁWFSﬂ), J.',
#   'global_num': 40},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 18,
#   'category': 'sentence',
#   'sentence': 'Morgan Securities LLC (ﬁJPMSﬂ) and Goldman Sachs & Co. LLC (ﬁGS&Co.ﬂ)arethe initial purchasers (collectively, the ﬁInitial Purchasersﬂ)of the Certificates.',
#   'global_num': 41},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 19,
#   'category': 'sentence',
#   'sentence': 'Credit Risk Retention.',
#   'global_num': 42},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 20,
#   'category': 'sentence',
#   'sentence': 'This transaction will be subject to the credit risk retention rules of Section 15G of the Securities Exchange Act of 1934.',
#   'global_num': 43},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 21,
#   'category': 'sentence',
#   'sentence': 'This transaction is being structured with a ﬁthird party purchaserﬂ that will acquire an ﬁeligible horizontal residual interestﬂ, which will be comprised of the Class HRR Certificates.',
#   'global_num': 44},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 22,
#   'category': 'sentence',
#   'sentence': 'Waikiki Hotel Grand Avenue Partners, LLC, in satisfaction of the retention obligations of WFB in its capacity as the ﬁretaining sponsorﬂ under the Credit Risk Retention Rules, will be contractually obligated to retain the Class HRR Certificates for a minimum of five years after the Closing Date, unless a shorter holding period is required or permitted under the Credit Risk Retention Rules as then in effect.',
#   'global_num': 45},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 23,
#   'category': 'sentence',
#   'sentence': 'During this holding period, Waikiki Hotel Grand Avenue Partners, LLCwill agree to comply with hedging, transfer and financing restrictions that are applicable to third party purchasers under the Credit Risk Retention Rules.',
#   'global_num': 46},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 24,
#   'category': 'sentence',
#   'sentence': 'See ﬁCredit Risk Retentionﬂin this Offering Circular.',
#   'global_num': 47},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 25,
#   'category': 'sentence',
#   'sentence': 'Certain Affiliations.',
#   'global_num': 48},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 26,
#   'category': 'sentence',
#   'sentence': 'Wells Fargo Bank, National Association (ﬁWFBﬂ) and its affiliates have several roles in this transaction.  WFB co-originated the Mortgage Loan and will sell its LoanPercentage Interest in the Mortgage Loanto the Depositor.',
#   'global_num': 49},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 27,
#   'category': 'sentence',
#   'sentence': 'In addition, WFB is the Servicer and the Certificate Administrator.',
#   'global_num': 50},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 28,
#   'category': 'sentence',
#   'sentence': 'WFB is also an affiliate of Wells Fargo Commercial Mortgage Securities, Inc., the Depositor, and WFS, one of theInitial Purchasersfor the offering of the Certificates.',
#   'global_num': 51},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'JPMorgan Chase Bank, National Association (ﬁJPMCBﬂ)and its affiliates have several roles in this transaction.',
#   'global_num': 52},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 2,
#   'category': 'sentence',
#   'sentence': 'JPMCB co-originated the Mortgage Loan and will sell its Loan Percentage Interest in the MortgageLoan to the Depositor.',
#   'global_num': 53},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 3,
#   'category': 'sentence',
#   'sentence': 'In addition, JPMCB is also an affiliate of JPMS, one of the Initial Purchasers for the offering of the Certificates.',
#   'global_num': 54},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'Goldman Sachs Mortgage Company(ﬁGSMCﬂ)and its affiliates have several roles in this transaction.',
#   'global_num': 55},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'GSMC co-originated the Mortgage Loan and will sell its Loan Percentage Interest in the MortgageLoan to the Depositor.',
#   'global_num': 56},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'In addition, GSMC is also an affiliate of GS&Co., one of the Initial Purchasers for the offering of the Certificates.',
#   'global_num': 57},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': 'These roles and other potential relationships may give rise to conflicts of interest as further described under ﬁRisk FactorsŠRisks Related to Conflictsof InterestŠPotential Conflicts of Interest of the Mortgage Loan Sellersﬂ, ﬁŠPotential Conflicts of Interest ofthe Servicer and the Special Servicerﬂ , ﬁŠPotential Conflicts of Interest of the Operating Advisorﬂand ﬁŠPotential Conflicts of Interest of the Initial Purchasersand TheirAffiliatesﬂ.',
#   'global_num': 58},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 8,
#   'category': 'sentence',
#   'sentence': 'Borrower; Borrower Sponsor.',
#   'global_num': 59},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 9,
#   'category': 'sentence',
#   'sentence': 'W2005 WKI Realty, LLC, a Delaware limited liability company (the ﬁBorrowerﬂ ), is a special purpose entity whose primary business is the ownership of the Mortgaged Property and the performance of the obligations under the Mortgage Loan Documents.',
#   'global_num': 60},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 10,
#   'category': 'sentence',
#   'sentence': 'See ﬁRisk FactorsŠRecourse on the Mortgage Loan Is Limited to the Mortgaged Property and Other Collateral Securing the Mortgage Loanﬂ in this Offering Circular.',
#   'global_num': 61},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 11,
#   'category': 'sentence',
#   'sentence': 'The Borrower isindirectly owned by Atrium WKI Holding LLC(the ﬁBorrower Sponsorﬂ)(an affiliate ofAtrium Holding Company). HLB Funding LLC and Atrium Leveraged Loan Fund, LLC guaranty therecourse obligations of the Borrower under the Mortgage Loan Documents (jointly and severally, the ﬁGuarantorsﬂ) pursuant to aguaranty (the ﬁGuarantyﬂ) dated as of the Origination Date.',
#   'global_num': 62},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 12,
#   'category': 'sentence',
#   'sentence': 'The term ﬁGuarantorﬂ as used in this Offering Circular, means (i) the Guarantors, or (ii) a replacement guarantorthat assumes the liabilities and obligations of the Guarantors in accordance with the Mortgage Loan Documents.',
#   'global_num': 63},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 13,
#   'category': 'sentence',
#   'sentence': 'See ﬁDescription of the Borrower and Related Partiesﬂ and ﬁDescription of the Mortgage LoanŠNon-Recourse Provisions and Exceptionsﬂ in this Offering Circular.',
#   'global_num': 64},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 14,
#   'category': 'sentence',
#   'sentence': 'Property Manager.',
#   'global_num': 65},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 15,
#   'category': 'sentence',
#   'sentence': 'The Mortgaged Property is currently managed by Marriott Hotel Services, Inc., under that certain management agreement dated as of July 25, 2001, as amended, between the Borrowerand the Property Manager, as more particularly described under ﬁDescription of the Management AgreementandAssignment of Management Agreementﬂin this Offering Circular.',
#   'global_num': 66},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 16,
#   'category': 'sentence',
#   'sentence': 'As used in this Offering Circular, the ﬁProperty Managerﬂmeans Marriott Hotel Services, Inc.or, if the context requires, any replacement property manager that may be appointed pursuant to the Mortgage Loan Documents, and the ﬁManagement Agreementﬂmeans the management agreements described above or, if the context requires, any replacement management agreements entered into pursuant to the terms of the Mortgage Loan Agreement.',
#   'global_num': 67},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 17,
#   'category': 'sentence',
#   'sentence': 'Cut-off Date.',
#   'global_num': 68},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 18,
#   'category': 'sentence',
#   'sentence': 'February 9, 2019(the ﬁCut-off Dateﬂ).',
#   'global_num': 69},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 19,
#   'category': 'sentence',
#   'sentence': 'Closing Date.',
#   'global_num': 70},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 20,
#   'category': 'sentence',
#   'sentence': 'On or about February 20, 2019(the ﬁClosing Dateﬂ).',
#   'global_num': 71},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 21,
#   'category': 'sentence',
#   'sentence': 'The Mortgage Loan and the Notes.',
#   'global_num': 72},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'The primary assets of theTrust will be a 2-year (subject to five(5), one-year extension options), floating rate, interest-only mortgage loan evidenced by threepromissory notes(the ﬁNotesﬂand such loan evidenced by the Notes, the ﬁMortgage Loanﬂ) with an outstanding principal balance as of the Cut-off Date of $336,500,000.',
#   'global_num': 73},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 2,
#   'category': 'sentence',
#   'sentence': 'The Mortgage Loan is secured by a first priority mortgage lien on the Borrower™s leasehold interestsin a full-service hospitalityproperty located in Honolulu, Hawaii(the ﬁMortgaged Propertyﬂ).',
#   'global_num': 74},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 3,
#   'category': 'sentence',
#   'sentence': 'The Mortgage Loan was made to the Borrower by the Mortgage Loan Sellers(in theirrespective capacity as lendersunder the Mortgage Loan Agreement, together with theirsuccessors andassignees, collectively, theﬁMortgage Lenderﬂ)on December5,2018(the ﬁOrigination Dateﬂ) pursuant to a mortgage loan agreement, dated as ofDecember5,2018, between the Borrower and the Mortgage Lender (the ﬁMortgage Loan Agreementﬂ).',
#   'global_num': 75},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'The Mortgage Loan will be sold by the Mortgage Loan Sellers to the Depositor in the amounts shown in the chart below (which amounts are subject to further redetermination):NoteSponsorOriginal Principal BalanceLoan Percentage InterestNote A-1.',
#   'global_num': 76},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'WFB$201,900,00060.0%Note A-2.',
#   'global_num': 77},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'JPMCB67,300,00020.',
#   'global_num': 78},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': '0Note A-3.',
#   'global_num': 79},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 8,
#   'category': 'sentence',
#   'sentence': 'GSMC67,300,00020.',
#   'global_num': 80},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 9,
#   'category': 'sentence',
#   'sentence': '0Total.',
#   'global_num': 81},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 10,
#   'category': 'sentence',
#   'sentence': '336,500,000100.0%On the Closing Date, each Mortgage Loan Seller will assign its LoanPercentage Interest in the Mortgage Loan to the Depositor and the Depositor will subsequently assign the Mortgage Loan to the Trust.',
#   'global_num': 82},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 11,
#   'category': 'sentence',
#   'sentence': 'On the Closing Date, the outstanding principal balance of the Mortgage Loan is expected to be $336,500,000.',
#   'global_num': 83},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 12,
#   'category': 'sentence',
#   'sentence': 'The Certificates will represent beneficial interests in the assets of the Trust, which primarily consist of the Mortgage Loan.',
#   'global_num': 84},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 13,
#   'category': 'sentence',
#   'sentence': 'For purposes of calculating interest and other amounts payable on the Mortgage Loan, the Mortgage Loan is currently divided into seven components (each, a ﬁComponentﬂ, and together, the ﬁComponentsﬂ).',
#   'global_num': 85},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 14,
#   'category': 'sentence',
#   'sentence': 'ComponentInitialPrincipal BalanceInitial Component Spread to LIBOR(1)Component A.',
#   'global_num': 86},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 15,
#   'category': 'sentence',
#   'sentence': '112,200,0001.0690%Component B.',
#   'global_num': 87},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 16,
#   'category': 'sentence',
#   'sentence': '36,800,0001.2490%Component C.',
#   'global_num': 88},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 17,
#   'category': 'sentence',
#   'sentence': '27,300,0001.4990%Component D.',
#   'global_num': 89},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 18,
#   'category': 'sentence',
#   'sentence': '36,100,0002.0490%Component E.',
#   'global_num': 90},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 19,
#   'category': 'sentence',
#   'sentence': '56,900,0002.6990%Component F.',
#   'global_num': 91},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 20,
#   'category': 'sentence',
#   'sentence': '50,375,0003.1008%Component HRR.',
#   'global_num': 92},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 21,
#   'category': 'sentence',
#   'sentence': '16,825,0005.8990%Total/Wtd. Avg..',
#   'global_num': 93},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 22,
#   'category': 'sentence',
#   'sentence': '336,500,0002.0500%(1)The Component Spread for each Component will be increased by 0.250% upon the commencement of the fourthExtension Option and continueat such increased Component Spreadfor each Mortgage Loan Interest Accrual Period thereafter.',
#   'global_num': 94},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'Except when LIBOR cannot be determined as described below, interest (other than Default Interest) will be payable on each Component at a variable rate per annum(each, a ﬁComponent Rateﬂ)equal to LIBOR plus (i) for each Mortgage Loan Interest Accrual Period from the initial Mortgage Loan Interest Accrual Period through (and including) the Mortgage Loan Interest Accrual Period ending in December 2023, the applicable spread set forth in the table above for such Component and (ii) for each Mortgage Loan Interest Accrual Period following the commencement of the fourthExtension Term through and including the Mortgage Loan Interest Accrual Period for the Maturity Date, the applicable spread set forth in the table above for such Component plus 0.250% (each such spread in clauses (i)and (ii), the ﬁComponent Spreadﬂ), in each case assuming the relevant extension options have been exercised.',
#   'global_num': 95},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 2,
#   'category': 'sentence',
#   'sentence': 'The initial per annumweighted average Component Spread will be equal to 2.0500%.',
#   'global_num': 96},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 3,
#   'category': 'sentence',
#   'sentence': 'The total interest accrued under the Mortgage Loan with respect to any Mortgage Loan Interest Accrual Period will be the sum of the interest accrued on each of the Components with respect to such Mortgage Loan Interest Accrual Period.',
#   'global_num': 97},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'As a result of the Components having different Component Rates,allocation ofprepayments will result inthe per annum weighted average interest rate of the Components increasingover time.',
#   'global_num': 98},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'See ﬁRisk FactorsŠSpecial Prepayment and Yield Considerationsﬂand ﬁDescription of the Mortgage LoanŠPrincipal and Interestﬂ Monthly payments of interest oneach Component are required to be made on the 9thday of each calendar month in which the related Mortgage Loan Interest Accrual Period ends (or if such 9thday is not a Business Day, the immediately precedingBusiness Day) (each, a ﬁMortgage Loan PaymentDateﬂ).',
#   'global_num': 99},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'On each Mortgage Loan Payment Date, the Borrower is required to pay to the Mortgage Lender interest on each Component for the entire applicable Mortgage Loan Interest Accrual Period at the applicable Component Rate.',
#   'global_num': 100},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': 'For so long as an event of default under the Mortgage Loan (a ﬁMortgage Loan Event of Defaultﬂ) has occurred and is continuing, the monthly payment on each Component will be increased by the amount of Default Interest accrued on such Component during the applicable Mortgage Loan Interest Accrual Period.',
#   'global_num': 101},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 8,
#   'category': 'sentence',
#   'sentence': 'The MortgageLoan does not require regularly scheduled payments of principal prior to the Maturity Date.',
#   'global_num': 102},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 9,
#   'category': 'sentence',
#   'sentence': 'The principal balance of the Mortgage Loan, to the extent not prepaid, will be payable on the Maturity Date together with all accrued and unpaid interest on the outstanding principal balance of the Notesthrough the end of the related Mortgage Loan Interest Accrual Period and all other amounts then due under the Mortgage Loan Documents.',
#   'global_num': 103},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 10,
#   'category': 'sentence',
#   'sentence': 'During the continuance of a Mortgage Loan Event of Default, payments of principal and, to the extent permitted by applicable law, interest and any other amounts required to be paid by the Borrower in respect of each Component will accrue interest at a default rate of interest per annum(the ﬁDefault Rateﬂ) equal to the lesser of (a)the maximum amount permitted by lawand  (b) 3.0% in excess of the Component Rate applicable to such Component,in each case, from the date such payment is due. If any payments of principal, interest or other payments due under the Mortgage Loan Documents (other than the amounts due on the Maturity Date)are not paid by the Borrower on or prior to the date on which they are due, the Mortgage Lender is entitled to demand from the Borrower a late fee equal to the lesser of (i) 3.0% of such unpaid sum or (ii) the maximum legal rate.  The Borrower willnot be liable for payment of the late payment charge in the event there are sufficient funds on deposit in the Cash Management Account for purposes of paying the interest to which such late payment charge relates andtheBorrower isthen entitled to a disbursement from the Cash Management Account for the purpose of payingsuch interest.',
#   'global_num': 104},
#  {'page_num': '27',
#   'pdf_page_num': '6',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'In theevent that the Mortgage Lender hasin good faith determined that LIBOR either (A) cannot be determined as provided in the definition of LIBORor (B) has been replaced in the market for commercial mortgage-backed securities financing transactions by an alternative floating interest rate index,the Mortgage Loan will be converted from a loan that accrues interest at a rate of interest based on LIBOR to a loan that accrues interest at a rate of interest based on an alternative floating rate index (or, if such index cannot be determined in accordance with the Mortgage Loan Documents, at the ﬁprime rateﬂ as published in the Wall Street Journal).',
#   'global_num': 105},
#  {'page_num': '27',
#   'pdf_page_num': '6',
#   'local_num': 2,
#   'category': 'sentence',
#   'sentence': 'If the Mortgage Loan has been converted toa loan that accrues interest at a rate of interest based on an alternative floating rate index and the Mortgage Lenderthereafterdetermines that the events or circumstances that resulted in such conversion are no longer applicable, the Mortgage Loan will be converted, from and after the first day of the next succeeding Mortgage Loan Interest Accrual Period, to a loan that accrues interest at a rate ofinterest based on LIBOR in effect on the related InterestDetermination Date.',
#   'global_num': 106},
#  {'page_num': '27',
#   'pdf_page_num': '6',
#   'local_num': 3,
#   'category': 'sentence',
#   'sentence': 'See ﬁDescription of the Mortgage LoanŠPrincipal and Interestﬂ.',
#   'global_num': 107},
#  {'page_num': '27',
#   'pdf_page_num': '6',
#   'local_num': 4,
#   'category': 'sentence',
# ...
#   'global_num': 956},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'Additionally, the Servicer, the Special Servicer or any of their affiliates, in the ordinary course of their businesses, may in the future acquire mortgage loans fortheir own account, including, in each such case, mortgage loans similar to the Mortgage Loan.',
#   'global_num': 957},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'The real properties securing these other mortgage loans may be in the same markets as, and compete with, the Mortgaged Propertysecuring the Mortgage Loan.',
#   'global_num': 958},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'Consequently, personnel of the Servicer or the Special Servicer may perform services, on behalf of the Trust, with respect to the Mortgage Loan at the same time as they are performing services with respect to, or while the Servicer, the Special Servicer or any of their affiliates are holding, other mortgage loans secured by propertiesthat compete with the Mortgaged Property securing the Mortgage Loan.',
#   'global_num': 959},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': 'This may pose inherent conflicts for the Servicer or the Special Servicer.',
#   'global_num': 960},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 8,
#   'category': 'sentence',
#   'sentence': 'Certain relationships and transactions between a Certificateholder and the Special Servicer may result in conflicts of interest.',
#   'global_num': 961},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 9,
#   'category': 'sentence',
#   'sentence': 'Additionally, these parties (and/or their affiliates) may, in the ordinary course of business, have relationships with, render services to, and engage in other transactions with each other.',
#   'global_num': 962},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 10,
#   'category': 'sentence',
#   'sentence': 'We cannot assure you that these transactions andrelationships will not influence the actions taken by the Special Servicer.',
#   'global_num': 963},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 11,
#   'category': 'sentence',
#   'sentence': 'Each of the foregoing relationships should be considered carefully by you before you invest in any Certificates.',
#   'global_num': 964},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 12,
#   'category': 'sentence',
#   'sentence': 'See also ﬁŠPotential Conflicts of Interest Among Various Certificateholdersﬂ below.',
#   'global_num': 965},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 13,
#   'category': 'sentence',
#   'sentence': 'Potential Conflicts of Interest of the Operating AdvisorPark Bridge Lender Services LLC, a New York limited liability company, has been appointed as the initial Operating Advisor with respect to the Mortgage Loan.',
#   'global_num': 966},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 14,
#   'category': 'sentence',
#   'sentence': 'See ﬁTransaction PartiesŠThe Operating Advisorﬂ in this Offering Circular.',
#   'global_num': 967},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 15,
#   'category': 'sentence',
#   'sentence': 'In the normal course of conducting its business, the initial Operating Advisor and its affiliates may have rendered services to,performed surveillance of, provided valuation and due diligence services to, and negotiated with, numerous parties engaged in activities related to structured finance and commercial mortgage securitization.',
#   'global_num': 968},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 16,
#   'category': 'sentence',
#   'sentence': 'These parties may have included institutional investors, the Depositor, the Mortgage Loan Sellers, the Borrower Sponsor, the Certificate Administrator, the Trustee, the Servicer, the Special Servicer, the Directing Certificateholder, the Borrower Sponsor, the Guarantorsor the Borrower or affiliates of any of those parties.',
#   'global_num': 969},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 17,
#   'category': 'sentence',
#   'sentence': 'Each of these relationships, to the extent they exist, may continue in the future, and may involve a conflict of interest with respect to the initial Operating Advisor™s duties as Operating Advisor.',
#   'global_num': 970},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 18,
#   'category': 'sentence',
#   'sentence': 'We cannot assure you that the existence of these relationships and other relationships in the future will not impact the manner in which the initial Operating Advisor performs its duties under the Trust and Servicing Agreement.',
#   'global_num': 971},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 19,
#   'category': 'sentence',
#   'sentence': 'Additionally, Park Bridge Lender Services LLC or its affiliates, in the ordinary course of its business, may in the future (a) perform forthird parties contract underwriting and due diligence services and advisory services as well as service or specially service mortgage loans and (b) acquire or have interest in existing and new commercial and multifamily mortgage loans for its own account,including mortgage loans similar to the Mortgage Loan.',
#   'global_num': 972},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 20,
#   'category': 'sentence',
#   'sentence': 'The real properties securing these other mortgage loans may be in the same markets as, or have owners, obligors or property managers in common with, and compete with, the Mortgaged Propertysecuring the Mortgage Loan.',
#   'global_num': 973},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 21,
#   'category': 'sentence',
#   'sentence': 'Consequently, personnel of Park Bridge Lender Services LLC may perform services, on behalf of the Trust, with respect to the Mortgage Loan at the same time as they are performing services with respect to, or while Park Bridge Lender Services LLC or its affiliates are holding, other mortgage loans secured by properties that compete with the Mortgaged Propertysecuring the Mortgage Loan.',
#   'global_num': 974},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 22,
#   'category': 'sentence',
#   'sentence': 'This may pose inherent conflicts of interest for Park Bridge Lender Services LLC. Although the Operating Advisor is required to consider Accepted Servicing Practices in connection with its activities under the Trust and Servicing Agreement, the Operating Advisor will not itself be bound by Accepted Servicing Practices.',
#   'global_num': 975},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 23,
#   'category': 'sentence',
#   'sentence': 'In addition, the Operating Advisor and its affiliates may have interests that are in conflict with those of Certificateholders if the Operating Advisor or any of its affiliates has financial interests in or financial dealings with the Borrower, a parent of the Borrower or any of their affiliates.',
#   'global_num': 976},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 24,
#   'category': 'sentence',
#   'sentence': 'Each of these relationships may also create a conflict of interest.',
#   'global_num': 977},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'Potential Conflicts of Interest of the Initial Purchasersand TheirAffiliatesThe activities and interests of the Initial Purchasersand theirrespective affiliates (individually, each an ﬁInitial Purchaser Entityﬂandcollectively, the ﬁInitial Purchaser Entitiesﬂ) will not align with, and may in fact be directly contrary to, those of Certificateholders.',
#   'global_num': 978},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 2,
#   'category': 'sentence',
#   'sentence': 'The Initial Purchaser Entities are each part of global banking, investment banking, securities and investment management firms that provide a wide range of financial services to a substantial and diversified client base that includes corporations, financial institutions, governments and high net worth individuals.',
#   'global_num': 979},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 3,
#   'category': 'sentence',
#   'sentence': 'As such, they actively make markets in and trade financial instruments for their own account and for the accounts of customers.',
#   'global_num': 980},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'These financial instruments include debt and equity securities, currencies, commodities, bank loans, indices, baskets and other products.',
#   'global_num': 981},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'The Initial Purchaser Entities™ activities include, among other things, executing large block trades and taking long and short positions directly and indirectly, through derivative instruments or otherwise.',
#   'global_num': 982},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'The securities and instruments in which the Initial Purchaser Entities take positions, or expect to take positions, include loans similar to theMortgage Loan, securities and instruments similar to the Certificates and other securities and instruments.',
#   'global_num': 983},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': 'Market making is an activity where the Initial Purchaser Entities buy and sell on behalf of customers, or for their own account, to satisfythe expected demand of customers.',
#   'global_num': 984},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 8,
#   'category': 'sentence',
#   'sentence': 'By its nature, market making involves facilitating transactions among market participants that have differing views of securities and instruments.',
#   'global_num': 985},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 9,
#   'category': 'sentence',
#   'sentence': 'As a result, you should expect that the Initial Purchaser Entities will take positions that are inconsistent with, or adverse to, the investment objectives of investors in the Certificates.',
#   'global_num': 986},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 10,
#   'category': 'sentence',
#   'sentence': 'As a result of the Initial Purchaser Entities™ various financial market activities, including acting as a research provider, investment advisor, market maker or principal investor, you should expect that personnel in various businesses throughoutthe Initial Purchaser Entities will have and express research or investment views and make recommendations that are inconsistent with, or adverse to, the objectives of investors in the Certificates.',
#   'global_num': 987},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 11,
#   'category': 'sentence',
#   'sentence': 'If any Initial Purchaser Entity becomes a holder of any of the Certificates, through market-making activity or otherwise, any actions that it may take in its capacity as a Certificateholder, including voting, providing consents or otherwise will not necessarily be aligned with the interests of the other holdersof the same Class or other Classes of the Certificates.',
#   'global_num': 988},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 12,
#   'category': 'sentence',
#   'sentence': 'We cannot assure youthat any actions that such party takes in either such capacity will necessarily be aligned with the interests of the holders of the Certificates.',
#   'global_num': 989},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 13,
#   'category': 'sentence',
#   'sentence': 'To the extent an Initial Purchaser Entity makes a market in the Certificates(which it is under no obligation to do), it would expect to receive income from the spreads between its bid and offer prices for the Certificates.',
#   'global_num': 990},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 14,
#   'category': 'sentence',
#   'sentence': 'The price at which an Initial Purchaser Entity may be willing to purchase Certificates, if it makes a market, will depend on market conditions and other relevant factors and may be significantly lower than the issue price for the Certificatesand significantly lower than the price at which it may be willing to sell Certificates.',
#   'global_num': 991},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 15,
#   'category': 'sentence',
#   'sentence': 'In addition, the Initial Purchaser Entities will have no obligation to monitor the performance of the Certificates or the actions of the Servicer, the Special Servicer, the Operating Advisor, the Certificate Administrator or the Trustee and will have no authority to advise any such parties or to direct their actions.',
#   'global_num': 992},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 16,
#   'category': 'sentence',
#   'sentence': 'Furthermore, the Initial Purchaser Entities expect that a completed offering will enhance their ability to assist clients and counterparties in the transaction or in related transactions (including assisting clients in additional purchases and sales of the Certificatesand hedging transactions).',
#   'global_num': 993},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 17,
#   'category': 'sentence',
#   'sentence': 'The Initial Purchaser Entities expect to derive fees and other revenues from these transactions.',
#   'global_num': 994},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 18,
#   'category': 'sentence',
#   'sentence': 'In addition, participating in a successful offering and providing related services to clients may enhance the Initial Purchaser Entities™ relationships with various parties, facilitate additional business development, and enable them to obtain additional business and generate additional revenue.',
#   'global_num': 995},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 19,
#   'category': 'sentence',
#   'sentence': 'In addition, the Initial Purchaser Entities may have ongoing relationships with, render services to, and engage in transactions with any Borrower Affiliates, which relationships and transactions may create conflicts of interest between the Initial Purchaser and its affiliates, on the one hand, and the Trust, on the other hand.',
#   'global_num': 996},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 20,
#   'category': 'sentence',
#   'sentence': 'See ﬁSummary of Offering CircularŠCertain Affiliationsﬂ in this Offering Circular for a description of certain affiliations and relationships between the Initial Purchaser and otherparticipants in this offering.',
#   'global_num': 997},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 21,
#   'category': 'sentence',
#   'sentence': 'Each of the foregoing relationships should be considered carefully by you before you invest in any Certificates.',
#   'global_num': 998},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 22,
#   'category': 'sentence',
#   'sentence': 'Potential Conflicts of Interest of the Property ManagerThe Property Manager, and any replacement Property Manager, also manage other properties including properties that compete with the Mortgaged Property.',
#   'global_num': 999},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 23,
#   'category': 'sentence',
#   'sentence': 'Accordingly, the Property Manager, including any replacement Property Manager, may experience conflicts of interest in the management of the Mortgaged Property, and may be hesitant to take actions with respect to the Mortgaged Property that may have an adverse effect on any other properties that they manage or own.',
#   'global_num': 1000},
#  ...]

# %%
num_pages
# Out:
# 390

# %%
sentences
# Out:
# [{'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'SUMMARY OF OFFERING CIRCULARThe following summary is qualified in its entirety by reference to the more detailed information appearing elsewhere in this Offering Circular.',
#   'global_num': 1},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 2,
#   'category': 'sentence',
#   'sentence': 'Capitalized terms used in this summary and notdefined in this summary have the meanings given to them elsewhere in this Offering Circular.',
#   'global_num': 2},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 3,
#   'category': 'sentence',
#   'sentence': 'See ﬁIndex of Significant Termsﬂ in this Offering Circular.',
#   'global_num': 3},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'Purchasers should carefully read this Offering Circular in its entirety, including the information set forth under ﬁRisk Factorsﬂ in this Offering Circular, prior to making an investment in the Certificates.',
#   'global_num': 4},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'Title of Certificates.',
#   'global_num': 5},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'Waikiki Beach HotelTrust 2019-WBM,Commercial Mortgage Pass-Through Certificates, Series 2019-WBM, which will be issued pursuant to the Trust and Servicing Agreement, to be dated as of the Closing Date, among the Depositor, the Trustee, the Certificate Administrator, the Servicer, the Special Servicerand the Operating Advisor(the ﬁTrust and Servicing Agreementﬂ).',
#   'global_num': 6},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': 'Depositor.',
#   'global_num': 7},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 8,
#   'category': 'sentence',
#   'sentence': 'Wells Fargo Commercial Mortgage Securities, Inc. (the ﬁDepositorﬂ), a North Carolina corporation, and an affiliate of Wells Fargo Bank, National Association (aMortgage Loan Seller, the Servicerand the Certificate Administrator) and Wells Fargo Securities, LLC (anInitial Purchaser).  SeeﬁTransaction PartiesŠThe Depositorﬂ in this Offering Circular.',
#   'global_num': 8},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 9,
#   'category': 'sentence',
#   'sentence': 'Mortgage Loan Sellers.',
#   'global_num': 9},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 10,
#   'category': 'sentence',
#   'sentence': 'Each of the following entities (collectively, the ﬁMortgage Loan Sellersﬂ) was a co-originator of the Mortgage Loan.',
#   'global_num': 10},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 11,
#   'category': 'sentence',
#   'sentence': 'On the Closing Date, each Mortgage Loan Seller will sell its respective portion of the Mortgage Loan set forth in the table below (each a ﬁLoan Percentage Interestﬂ) to the Depositor.',
#   'global_num': 11},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 12,
#   'category': 'sentence',
#   'sentence': 'Mortgage Loan SellerOriginal Principal Balance of the Mortgage Loan Seller portion% of Initial Original Principal Balance of the Mortgage LoanWells Fargo Bank, National Association..',
#   'global_num': 12},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 13,
#   'category': 'sentence',
#   'sentence': '201,900,00060.0%JPMorgan Chase Bank, National Association.',
#   'global_num': 13},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 14,
#   'category': 'sentence',
#   'sentence': '67,300,00020.0Goldman Sachs Mortgage Company.',
#   'global_num': 14},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 15,
#   'category': 'sentence',
#   'sentence': '67,300,00020.0Total.',
#   'global_num': 15},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 16,
#   'category': 'sentence',
#   'sentence': '336,500,000100.0%See ﬁTransaction PartiesŠThe Mortgage Loan Sellersﬂ in this Offering Circular.',
#   'global_num': 16},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 17,
#   'category': 'sentence',
#   'sentence': 'Issuing Entity.',
#   'global_num': 17},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 18,
#   'category': 'sentence',
#   'sentence': 'Waikiki Beach HotelTrust 2019-WBM(the ﬁTrustﬂ), a New York common law trust to be formed on the Closing Date pursuant to the Trust and Servicing Agreement.',
#   'global_num': 18},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 19,
#   'category': 'sentence',
#   'sentence': 'See ﬁTransaction PartiesŠThe Issuing Entityﬂ in this Offering Circular.',
#   'global_num': 19},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 20,
#   'category': 'sentence',
#   'sentence': 'Servicer.',
#   'global_num': 20},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 21,
#   'category': 'sentence',
#   'sentence': 'Wells Fargo Bank, National Association, a national banking association (in its capacity as servicer, the ﬁServicerﬂ).',
#   'global_num': 21},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 22,
#   'category': 'sentence',
#   'sentence': 'The principal west coast commercial mortgage master servicing office of Wells Fargo Bank, National Association is located at MAC A0227-020, 1901 Harrison Street, Oakland, California 94612.',
#   'global_num': 22},
#  {'page_num': '22',
#   'pdf_page_num': '1',
#   'local_num': 23,
#   'category': 'sentence',
#   'sentence': 'The principal east coast commercial mortgage master servicing office of Wells Fargo Bank, National Association is located at MAC D1050-084, 401 South Tryon Street, 8thFloor, Charlotte, North Carolina 28202. See ﬁTransaction PartiesŠThe Servicerﬂ in this Offering Circular.',
#   'global_num': 23},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'Special Servicer.',
#   'global_num': 24},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 2,
#   'category': 'sentence',
#   'sentence': 'CWCapital Asset Management LLC, aDelaware limited liability company, acting as special servicer(the ﬁSpecial Servicerﬂ).',
#   'global_num': 25},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 3,
#   'category': 'sentence',
#   'sentence': 'The principal servicing offices of the Special Servicer are located at 7501 Wisconsin Avenue, Suite 500 West, Bethesda, Maryland 20814.',
#   'global_num': 26},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'See ﬁTransaction PartiesŠThe Special Servicerﬂ in this Offering Circular.',
#   'global_num': 27},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'The Special Servicer may be removed, with or without cause, and a successor Special Servicer appointed at any time as described under ﬁDescription of the Trust and Servicing AgreementŠReplacement of the Special Servicer After Operating Advisor Recommendation and Investor Voteﬂ and ﬁŠReplacement of the Special Servicerﬂin this Offering Circular.',
#   'global_num': 28},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'Trustee.',
#   'global_num': 29},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': 'Wilmington Trust, National Association, a national banking association (the ﬁTrusteeﬂ).',
#   'global_num': 30},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 8,
#   'category': 'sentence',
#   'sentence': 'The principal place of business of Wilmington Trust, National Association, is 1100 North Market Street, Wilmington, Delaware 19890.',
#   'global_num': 31},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 9,
#   'category': 'sentence',
#   'sentence': 'See ﬁTransaction PartiesŠThe Trusteeﬂ in this Offering Circular.',
#   'global_num': 32},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 10,
#   'category': 'sentence',
#   'sentence': 'Certificate Administrator.',
#   'global_num': 33},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 11,
#   'category': 'sentence',
#   'sentence': 'Wells Fargo Bank, National Association, a national banking association (in such capacity, the ﬁCertificate Administratorﬂ). The principal corporate trust offices of the Certificate Administrator are located at 9062 Old Annapolis Road, Columbia, Maryland 21045, and its office for certificate transfer services is located at 600 South 4thStreet, 7thFloor, MAC N9300-070, Minneapolis, Minnesota 55479.   See ﬁTransaction PartiesŠThe Certificate Administratorﬂ in this Offering Circular.',
#   'global_num': 34},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 12,
#   'category': 'sentence',
#   'sentence': 'Operating Advisor.',
#   'global_num': 35},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 13,
#   'category': 'sentence',
#   'sentence': 'Park Bridge Lender Services LLC, a New York limited liability company and an indirect wholly-owned subsidiary of Park Bridge Financial LLC,acting asoperating advisor(the ﬁOperating Advisorﬂ).',
#   'global_num': 36},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 14,
#   'category': 'sentence',
#   'sentence': 'The principal place of business of the Operating Advisor is 600 Third Avenue, 40th Floor, New York, New York 10016.',
#   'global_num': 37},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 15,
#   'category': 'sentence',
#   'sentence': 'See ﬁTransaction PartiesŠThe Operating Advisorﬂ in this Offering Circular.',
#   'global_num': 38},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 16,
#   'category': 'sentence',
#   'sentence': 'Initial Purchasers.',
#   'global_num': 39},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 17,
#   'category': 'sentence',
#   'sentence': 'Wells Fargo Securities, LLC(ﬁWFSﬂ), J.',
#   'global_num': 40},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 18,
#   'category': 'sentence',
#   'sentence': 'Morgan Securities LLC (ﬁJPMSﬂ) and Goldman Sachs & Co. LLC (ﬁGS&Co.ﬂ)arethe initial purchasers (collectively, the ﬁInitial Purchasersﬂ)of the Certificates.',
#   'global_num': 41},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 19,
#   'category': 'sentence',
#   'sentence': 'Credit Risk Retention.',
#   'global_num': 42},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 20,
#   'category': 'sentence',
#   'sentence': 'This transaction will be subject to the credit risk retention rules of Section 15G of the Securities Exchange Act of 1934.',
#   'global_num': 43},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 21,
#   'category': 'sentence',
#   'sentence': 'This transaction is being structured with a ﬁthird party purchaserﬂ that will acquire an ﬁeligible horizontal residual interestﬂ, which will be comprised of the Class HRR Certificates.',
#   'global_num': 44},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 22,
#   'category': 'sentence',
#   'sentence': 'Waikiki Hotel Grand Avenue Partners, LLC, in satisfaction of the retention obligations of WFB in its capacity as the ﬁretaining sponsorﬂ under the Credit Risk Retention Rules, will be contractually obligated to retain the Class HRR Certificates for a minimum of five years after the Closing Date, unless a shorter holding period is required or permitted under the Credit Risk Retention Rules as then in effect.',
#   'global_num': 45},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 23,
#   'category': 'sentence',
#   'sentence': 'During this holding period, Waikiki Hotel Grand Avenue Partners, LLCwill agree to comply with hedging, transfer and financing restrictions that are applicable to third party purchasers under the Credit Risk Retention Rules.',
#   'global_num': 46},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 24,
#   'category': 'sentence',
#   'sentence': 'See ﬁCredit Risk Retentionﬂin this Offering Circular.',
#   'global_num': 47},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 25,
#   'category': 'sentence',
#   'sentence': 'Certain Affiliations.',
#   'global_num': 48},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 26,
#   'category': 'sentence',
#   'sentence': 'Wells Fargo Bank, National Association (ﬁWFBﬂ) and its affiliates have several roles in this transaction.  WFB co-originated the Mortgage Loan and will sell its LoanPercentage Interest in the Mortgage Loanto the Depositor.',
#   'global_num': 49},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 27,
#   'category': 'sentence',
#   'sentence': 'In addition, WFB is the Servicer and the Certificate Administrator.',
#   'global_num': 50},
#  {'page_num': '23',
#   'pdf_page_num': '2',
#   'local_num': 28,
#   'category': 'sentence',
#   'sentence': 'WFB is also an affiliate of Wells Fargo Commercial Mortgage Securities, Inc., the Depositor, and WFS, one of theInitial Purchasersfor the offering of the Certificates.',
#   'global_num': 51},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'JPMorgan Chase Bank, National Association (ﬁJPMCBﬂ)and its affiliates have several roles in this transaction.',
#   'global_num': 52},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 2,
#   'category': 'sentence',
#   'sentence': 'JPMCB co-originated the Mortgage Loan and will sell its Loan Percentage Interest in the MortgageLoan to the Depositor.',
#   'global_num': 53},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 3,
#   'category': 'sentence',
#   'sentence': 'In addition, JPMCB is also an affiliate of JPMS, one of the Initial Purchasers for the offering of the Certificates.',
#   'global_num': 54},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'Goldman Sachs Mortgage Company(ﬁGSMCﬂ)and its affiliates have several roles in this transaction.',
#   'global_num': 55},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'GSMC co-originated the Mortgage Loan and will sell its Loan Percentage Interest in the MortgageLoan to the Depositor.',
#   'global_num': 56},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'In addition, GSMC is also an affiliate of GS&Co., one of the Initial Purchasers for the offering of the Certificates.',
#   'global_num': 57},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': 'These roles and other potential relationships may give rise to conflicts of interest as further described under ﬁRisk FactorsŠRisks Related to Conflictsof InterestŠPotential Conflicts of Interest of the Mortgage Loan Sellersﬂ, ﬁŠPotential Conflicts of Interest ofthe Servicer and the Special Servicerﬂ , ﬁŠPotential Conflicts of Interest of the Operating Advisorﬂand ﬁŠPotential Conflicts of Interest of the Initial Purchasersand TheirAffiliatesﬂ.',
#   'global_num': 58},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 8,
#   'category': 'sentence',
#   'sentence': 'Borrower; Borrower Sponsor.',
#   'global_num': 59},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 9,
#   'category': 'sentence',
#   'sentence': 'W2005 WKI Realty, LLC, a Delaware limited liability company (the ﬁBorrowerﬂ ), is a special purpose entity whose primary business is the ownership of the Mortgaged Property and the performance of the obligations under the Mortgage Loan Documents.',
#   'global_num': 60},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 10,
#   'category': 'sentence',
#   'sentence': 'See ﬁRisk FactorsŠRecourse on the Mortgage Loan Is Limited to the Mortgaged Property and Other Collateral Securing the Mortgage Loanﬂ in this Offering Circular.',
#   'global_num': 61},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 11,
#   'category': 'sentence',
#   'sentence': 'The Borrower isindirectly owned by Atrium WKI Holding LLC(the ﬁBorrower Sponsorﬂ)(an affiliate ofAtrium Holding Company). HLB Funding LLC and Atrium Leveraged Loan Fund, LLC guaranty therecourse obligations of the Borrower under the Mortgage Loan Documents (jointly and severally, the ﬁGuarantorsﬂ) pursuant to aguaranty (the ﬁGuarantyﬂ) dated as of the Origination Date.',
#   'global_num': 62},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 12,
#   'category': 'sentence',
#   'sentence': 'The term ﬁGuarantorﬂ as used in this Offering Circular, means (i) the Guarantors, or (ii) a replacement guarantorthat assumes the liabilities and obligations of the Guarantors in accordance with the Mortgage Loan Documents.',
#   'global_num': 63},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 13,
#   'category': 'sentence',
#   'sentence': 'See ﬁDescription of the Borrower and Related Partiesﬂ and ﬁDescription of the Mortgage LoanŠNon-Recourse Provisions and Exceptionsﬂ in this Offering Circular.',
#   'global_num': 64},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 14,
#   'category': 'sentence',
#   'sentence': 'Property Manager.',
#   'global_num': 65},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 15,
#   'category': 'sentence',
#   'sentence': 'The Mortgaged Property is currently managed by Marriott Hotel Services, Inc., under that certain management agreement dated as of July 25, 2001, as amended, between the Borrowerand the Property Manager, as more particularly described under ﬁDescription of the Management AgreementandAssignment of Management Agreementﬂin this Offering Circular.',
#   'global_num': 66},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 16,
#   'category': 'sentence',
#   'sentence': 'As used in this Offering Circular, the ﬁProperty Managerﬂmeans Marriott Hotel Services, Inc.or, if the context requires, any replacement property manager that may be appointed pursuant to the Mortgage Loan Documents, and the ﬁManagement Agreementﬂmeans the management agreements described above or, if the context requires, any replacement management agreements entered into pursuant to the terms of the Mortgage Loan Agreement.',
#   'global_num': 67},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 17,
#   'category': 'sentence',
#   'sentence': 'Cut-off Date.',
#   'global_num': 68},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 18,
#   'category': 'sentence',
#   'sentence': 'February 9, 2019(the ﬁCut-off Dateﬂ).',
#   'global_num': 69},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 19,
#   'category': 'sentence',
#   'sentence': 'Closing Date.',
#   'global_num': 70},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 20,
#   'category': 'sentence',
#   'sentence': 'On or about February 20, 2019(the ﬁClosing Dateﬂ).',
#   'global_num': 71},
#  {'page_num': '24',
#   'pdf_page_num': '3',
#   'local_num': 21,
#   'category': 'sentence',
#   'sentence': 'The Mortgage Loan and the Notes.',
#   'global_num': 72},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'The primary assets of theTrust will be a 2-year (subject to five(5), one-year extension options), floating rate, interest-only mortgage loan evidenced by threepromissory notes(the ﬁNotesﬂand such loan evidenced by the Notes, the ﬁMortgage Loanﬂ) with an outstanding principal balance as of the Cut-off Date of $336,500,000.',
#   'global_num': 73},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 2,
#   'category': 'sentence',
#   'sentence': 'The Mortgage Loan is secured by a first priority mortgage lien on the Borrower™s leasehold interestsin a full-service hospitalityproperty located in Honolulu, Hawaii(the ﬁMortgaged Propertyﬂ).',
#   'global_num': 74},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 3,
#   'category': 'sentence',
#   'sentence': 'The Mortgage Loan was made to the Borrower by the Mortgage Loan Sellers(in theirrespective capacity as lendersunder the Mortgage Loan Agreement, together with theirsuccessors andassignees, collectively, theﬁMortgage Lenderﬂ)on December5,2018(the ﬁOrigination Dateﬂ) pursuant to a mortgage loan agreement, dated as ofDecember5,2018, between the Borrower and the Mortgage Lender (the ﬁMortgage Loan Agreementﬂ).',
#   'global_num': 75},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'The Mortgage Loan will be sold by the Mortgage Loan Sellers to the Depositor in the amounts shown in the chart below (which amounts are subject to further redetermination):NoteSponsorOriginal Principal BalanceLoan Percentage InterestNote A-1.',
#   'global_num': 76},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'WFB$201,900,00060.0%Note A-2.',
#   'global_num': 77},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'JPMCB67,300,00020.',
#   'global_num': 78},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': '0Note A-3.',
#   'global_num': 79},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 8,
#   'category': 'sentence',
#   'sentence': 'GSMC67,300,00020.',
#   'global_num': 80},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 9,
#   'category': 'sentence',
#   'sentence': '0Total.',
#   'global_num': 81},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 10,
#   'category': 'sentence',
#   'sentence': '336,500,000100.0%On the Closing Date, each Mortgage Loan Seller will assign its LoanPercentage Interest in the Mortgage Loan to the Depositor and the Depositor will subsequently assign the Mortgage Loan to the Trust.',
#   'global_num': 82},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 11,
#   'category': 'sentence',
#   'sentence': 'On the Closing Date, the outstanding principal balance of the Mortgage Loan is expected to be $336,500,000.',
#   'global_num': 83},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 12,
#   'category': 'sentence',
#   'sentence': 'The Certificates will represent beneficial interests in the assets of the Trust, which primarily consist of the Mortgage Loan.',
#   'global_num': 84},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 13,
#   'category': 'sentence',
#   'sentence': 'For purposes of calculating interest and other amounts payable on the Mortgage Loan, the Mortgage Loan is currently divided into seven components (each, a ﬁComponentﬂ, and together, the ﬁComponentsﬂ).',
#   'global_num': 85},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 14,
#   'category': 'sentence',
#   'sentence': 'ComponentInitialPrincipal BalanceInitial Component Spread to LIBOR(1)Component A.',
#   'global_num': 86},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 15,
#   'category': 'sentence',
#   'sentence': '112,200,0001.0690%Component B.',
#   'global_num': 87},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 16,
#   'category': 'sentence',
#   'sentence': '36,800,0001.2490%Component C.',
#   'global_num': 88},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 17,
#   'category': 'sentence',
#   'sentence': '27,300,0001.4990%Component D.',
#   'global_num': 89},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 18,
#   'category': 'sentence',
#   'sentence': '36,100,0002.0490%Component E.',
#   'global_num': 90},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 19,
#   'category': 'sentence',
#   'sentence': '56,900,0002.6990%Component F.',
#   'global_num': 91},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 20,
#   'category': 'sentence',
#   'sentence': '50,375,0003.1008%Component HRR.',
#   'global_num': 92},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 21,
#   'category': 'sentence',
#   'sentence': '16,825,0005.8990%Total/Wtd. Avg..',
#   'global_num': 93},
#  {'page_num': '25',
#   'pdf_page_num': '4',
#   'local_num': 22,
#   'category': 'sentence',
#   'sentence': '336,500,0002.0500%(1)The Component Spread for each Component will be increased by 0.250% upon the commencement of the fourthExtension Option and continueat such increased Component Spreadfor each Mortgage Loan Interest Accrual Period thereafter.',
#   'global_num': 94},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'Except when LIBOR cannot be determined as described below, interest (other than Default Interest) will be payable on each Component at a variable rate per annum(each, a ﬁComponent Rateﬂ)equal to LIBOR plus (i) for each Mortgage Loan Interest Accrual Period from the initial Mortgage Loan Interest Accrual Period through (and including) the Mortgage Loan Interest Accrual Period ending in December 2023, the applicable spread set forth in the table above for such Component and (ii) for each Mortgage Loan Interest Accrual Period following the commencement of the fourthExtension Term through and including the Mortgage Loan Interest Accrual Period for the Maturity Date, the applicable spread set forth in the table above for such Component plus 0.250% (each such spread in clauses (i)and (ii), the ﬁComponent Spreadﬂ), in each case assuming the relevant extension options have been exercised.',
#   'global_num': 95},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 2,
#   'category': 'sentence',
#   'sentence': 'The initial per annumweighted average Component Spread will be equal to 2.0500%.',
#   'global_num': 96},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 3,
#   'category': 'sentence',
#   'sentence': 'The total interest accrued under the Mortgage Loan with respect to any Mortgage Loan Interest Accrual Period will be the sum of the interest accrued on each of the Components with respect to such Mortgage Loan Interest Accrual Period.',
#   'global_num': 97},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'As a result of the Components having different Component Rates,allocation ofprepayments will result inthe per annum weighted average interest rate of the Components increasingover time.',
#   'global_num': 98},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'See ﬁRisk FactorsŠSpecial Prepayment and Yield Considerationsﬂand ﬁDescription of the Mortgage LoanŠPrincipal and Interestﬂ Monthly payments of interest oneach Component are required to be made on the 9thday of each calendar month in which the related Mortgage Loan Interest Accrual Period ends (or if such 9thday is not a Business Day, the immediately precedingBusiness Day) (each, a ﬁMortgage Loan PaymentDateﬂ).',
#   'global_num': 99},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'On each Mortgage Loan Payment Date, the Borrower is required to pay to the Mortgage Lender interest on each Component for the entire applicable Mortgage Loan Interest Accrual Period at the applicable Component Rate.',
#   'global_num': 100},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': 'For so long as an event of default under the Mortgage Loan (a ﬁMortgage Loan Event of Defaultﬂ) has occurred and is continuing, the monthly payment on each Component will be increased by the amount of Default Interest accrued on such Component during the applicable Mortgage Loan Interest Accrual Period.',
#   'global_num': 101},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 8,
#   'category': 'sentence',
#   'sentence': 'The MortgageLoan does not require regularly scheduled payments of principal prior to the Maturity Date.',
#   'global_num': 102},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 9,
#   'category': 'sentence',
#   'sentence': 'The principal balance of the Mortgage Loan, to the extent not prepaid, will be payable on the Maturity Date together with all accrued and unpaid interest on the outstanding principal balance of the Notesthrough the end of the related Mortgage Loan Interest Accrual Period and all other amounts then due under the Mortgage Loan Documents.',
#   'global_num': 103},
#  {'page_num': '26',
#   'pdf_page_num': '5',
#   'local_num': 10,
#   'category': 'sentence',
#   'sentence': 'During the continuance of a Mortgage Loan Event of Default, payments of principal and, to the extent permitted by applicable law, interest and any other amounts required to be paid by the Borrower in respect of each Component will accrue interest at a default rate of interest per annum(the ﬁDefault Rateﬂ) equal to the lesser of (a)the maximum amount permitted by lawand  (b) 3.0% in excess of the Component Rate applicable to such Component,in each case, from the date such payment is due. If any payments of principal, interest or other payments due under the Mortgage Loan Documents (other than the amounts due on the Maturity Date)are not paid by the Borrower on or prior to the date on which they are due, the Mortgage Lender is entitled to demand from the Borrower a late fee equal to the lesser of (i) 3.0% of such unpaid sum or (ii) the maximum legal rate.  The Borrower willnot be liable for payment of the late payment charge in the event there are sufficient funds on deposit in the Cash Management Account for purposes of paying the interest to which such late payment charge relates andtheBorrower isthen entitled to a disbursement from the Cash Management Account for the purpose of payingsuch interest.',
#   'global_num': 104},
#  {'page_num': '27',
#   'pdf_page_num': '6',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'In theevent that the Mortgage Lender hasin good faith determined that LIBOR either (A) cannot be determined as provided in the definition of LIBORor (B) has been replaced in the market for commercial mortgage-backed securities financing transactions by an alternative floating interest rate index,the Mortgage Loan will be converted from a loan that accrues interest at a rate of interest based on LIBOR to a loan that accrues interest at a rate of interest based on an alternative floating rate index (or, if such index cannot be determined in accordance with the Mortgage Loan Documents, at the ﬁprime rateﬂ as published in the Wall Street Journal).',
#   'global_num': 105},
#  {'page_num': '27',
#   'pdf_page_num': '6',
#   'local_num': 2,
#   'category': 'sentence',
#   'sentence': 'If the Mortgage Loan has been converted toa loan that accrues interest at a rate of interest based on an alternative floating rate index and the Mortgage Lenderthereafterdetermines that the events or circumstances that resulted in such conversion are no longer applicable, the Mortgage Loan will be converted, from and after the first day of the next succeeding Mortgage Loan Interest Accrual Period, to a loan that accrues interest at a rate ofinterest based on LIBOR in effect on the related InterestDetermination Date.',
#   'global_num': 106},
#  {'page_num': '27',
#   'pdf_page_num': '6',
#   'local_num': 3,
#   'category': 'sentence',
#   'sentence': 'See ﬁDescription of the Mortgage LoanŠPrincipal and Interestﬂ.',
#   'global_num': 107},
#  {'page_num': '27',
#   'pdf_page_num': '6',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'Calculations of interest on the Notes and Components will be made on the basis of a 360-day year and the actual number of days elapsed in the related Mortgage Loan Interest Accrual Period.ﬁBusiness Dayﬂmeans (i)with respect to any references to ﬁBusiness Dayﬂ, any day other than a Saturday, Sunday or any other day on which any of the following institutions are not open for business: (a) national banks in New York, New York, (b)in the place of business or any principal servicing officeoftheTrustee, the Certificate Administrator, the Servicer, the Special Servicer or the financial institution that maintains the Collection Account, the REO Accountor any Reserve Funds or (c) the New York Stock Exchange or the Federal Reserve Bank of New York and (ii) with respect to any references to ﬁBusiness Dayﬂ regarding an Interest Determination Date, ﬁBusiness Dayﬂ means a day on which banks are open for dealing in foreign currency and exchange in London.ﬁDefault Interestﬂmeans the amountby which interest accrued on any Component at its Default Rate exceeds the amount of interest that would have accrued on such Component at the Component Rate.ﬁInterest Determination Dateﬂ means, with respect to any Mortgage Loan Interest Accrual Period and any related Certificate Interest Accrual Period, the second Business Day prior to the 15th day of the calendar month which occurs immediately prior to the related Mortgage Loan Payment Date.',
#   'global_num': 108},
#  {'page_num': '27',
#   'pdf_page_num': '6',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'With respect to the initial Certificate Interest Accrual Period, the Interest Determination Date will be February 13, 2019.ﬁMortgage Loan Interest Accrual Periodﬂmeans with respect to each Component (and therefore, the Mortgage Loan) for any Mortgage Loan Payment Date, the period commencing on (and including) the 9thday of the prior calendar month and ending on (and including) the 8thday of the calendar month in which such Mortgage Loan Payment Date occurs.',
#   'global_num': 109},
#  {'page_num': '27',
#   'pdf_page_num': '6',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'See ﬁDescription of the Mortgage LoanŠPrincipal and Interestﬂ for a further description of the payment of principal and interest on the MortgageLoan.',
#   'global_num': 110},
#  {'page_num': '27',
#   'pdf_page_num': '6',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': 'Mortgage Loan Maturity Date.',
#   'global_num': 111},
#  {'page_num': '28',
#   'pdf_page_num': '7',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'The initial maturity date with respect to the MortgageLoan is December 9, 2020(the ﬁInitial MaturityDateﬂ), subject to fivesuccessiveone-year extension options (as extended, each extended maturity date, the ﬁExtended Maturity Dateﬂ), or such earlier date as may result from prepayment or acceleration of the MortgageLoan in accordance with the terms of the Mortgage Loan Agreement (such Initial Maturity Date, Extended Maturity Date or earlier date, as applicable, the ﬁMaturity Dateﬂ).',
#   'global_num': 112},
#  {'page_num': '28',
#   'pdf_page_num': '7',
#   'local_num': 2,
#   'category': 'sentence',
#   'sentence': 'Prepayment of the Mortgage Loan.',
#   'global_num': 113},
#  {'page_num': '28',
#   'pdf_page_num': '7',
#   'local_num': 3,
#   'category': 'sentence',
#   'sentence': 'The Mortgage Loan may be prepaid in whole or in part at any time, subject to payment of aSpread Maintenance Premium on the principal amount of such prepayment, if made prior to the Spread Maintenance End Date.',
#   'global_num': 114},
#  {'page_num': '28',
#   'pdf_page_num': '7',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'In addition, theMortgage Loan may also be prepaid in part (a) in connection with a release of a portion of the MortgagedProperty (as described under ﬁDescription of the Mortgage LoanŠRelease of the Mortgaged Propertyﬂ below) and (b) to achieve the Debt Yield necessary to permit a Debt Yield Cure (as described under ﬁDescription of the Mortgage LoanŠDebt Yield Cure Paymentsﬂ below).  Any voluntary prepayments are subject to satisfaction of all the conditions in the Mortgage Loan Documents including, without limitation, (i) no Mortgage Loan Event of Default exists and is continuing (exceptthe Borrower may prepay the Mortgage Loan in whole during the continuance of a Mortgage Loan Event of Default in accordance with the Mortgage Loan Documents); and (ii) the Borrower pays, in addition to the outstanding principal amount of the Mortgage Loan to be prepaid, (A) all interest that would have accrued on the amount of the Mortgage Loan to be paid through and including the last day of the Mortgage Loan Interest Accrual Period in which such prepayment occurs; (B) all other sums then due and payable under the Mortgage Loan Documents; and (C) if such prepayment is made prior to the Spread Maintenance End Date, the Spread Maintenance Premium.',
#   'global_num': 115},
#  {'page_num': '28',
#   'pdf_page_num': '7',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'Involuntary prepayments can also occur in part at any time as a result of casualty or condemnation if the related proceeds are not required to be applied to the restoration of the MortgagedProperty or otherwise remitted to the Borrower.',
#   'global_num': 116},
#  {'page_num': '28',
#   'pdf_page_num': '7',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'No Spread Maintenance Premium or other prepayment premium will be required in connection with such involuntary principal prepayment.',
#   'global_num': 117},
#  {'page_num': '28',
#   'pdf_page_num': '7',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': 'See ﬁDescription of the Mortgage LoanŠPrepaymentﬂ and ﬁŠCasualty and Condemnationﬂ.',
#   'global_num': 118},
#  {'page_num': '28',
#   'pdf_page_num': '7',
#   'local_num': 8,
#   'category': 'sentence',
#   'sentence': 'All payments of principal will be applied to the Components sequentially, to Component A, Component B, Component C, Component D, Component E, Component Fand Component HRR, in such order, in each case until paid to zero.ﬁSpread Maintenance End Dateﬂmeans June 9, 2020.ﬁSpread Maintenance Premiumﬂmeans, in connection with any prepayment or repayment of the outstanding principal amount of any Component being prepaid prior to the Spread Maintenance End Date, an amount equal to the product of (a)the related Component Spread, (b)the principal balanceprepaid on such Component, (c) a fraction, (i) the numerator of which is the number of days following (but not including) the date through which interest on the prepaid amount has been paid to (but excluding) the Spread Maintenance End Date and (ii) the denominator of whichis 360.',
#   'global_num': 119},
#  {'page_num': '28',
#   'pdf_page_num': '7',
#   'local_num': 9,
#   'category': 'sentence',
#   'sentence': 'Permitted Transfers.',
#   'global_num': 120},
#  {'page_num': '28',
#   'pdf_page_num': '7',
#   'local_num': 10,
#   'category': 'sentence',
#   'sentence': 'Other than Permitted Transfers (as defined under ﬁDescription of the Mortgage LoanŠTransfer Restrictionsﬂ), the Borrower generally may not permit, without the Mortgage Lender™s consent,(i) a sale or pledge of the Mortgaged Property or (ii) a sale or pledge of an interest in any Restricted Party.',
#   'global_num': 121},
#  {'page_num': '29',
#   'pdf_page_num': '8',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'Extension Options.',
#   'global_num': 122},
#  {'page_num': '29',
#   'pdf_page_num': '8',
#   'local_num': 2,
#   'category': 'sentence',
#   'sentence': 'The Borrower has the option to extend the term of the Mortgage Loan beyond the Initial Maturity Date for fiveconsecutive terms of one-year (each such option, an ﬁExtension Optionﬂand each such successive term, an ﬁExtension Termﬂ) each upon satisfaction of certain conditions, including, without limitation:(i)the Borrower has delivered to the Mortgage Lender written notice of its election of such Extension Term at least ten(10) Business Days prior to the then applicable Maturity Date; (ii)no Mortgage Loan Event of Default has occurred and is continuing on either the date of such notice or the then applicable Maturity Date; (iii)the Borrower has entered into an Interest Rate CapAgreement for the applicable Extension Term in form and substance acceptable to the Mortgage Lender (including, without limitation, at a strike rate equal to or less than the Strike Price) and otherwise inaccordance with the terms of the Mortgage Loan Agreement and has collaterally assigned such Interest Rate CapAgreement to the Mortgage Lender pursuant to the terms of a collateral assignment in form and substance satisfactory to the Mortgage Lender; (iv)(a)with respect to the fourth Extension Option (if any), the Debt Yield calculated as of the most recent ended fiscal quarter will be required to equal or exceed 8.0% and (b) with respect to the fifth Extension Option (if any), the Debt Yield calculated as of the most recent ended fiscal quarter will be required to equal or exceed 8.5%, providedthat the Borrower has the right to deliver a letter of credit to the Mortgage Lender in accordance with the terms of the Mortgage Loan Documents in anamount such that, if such letter of credit were applied to pay down the principal balance of the Mortgage Loan it would result in the required Debt Yield; and (v)the Borrower reimburses the Mortgage Lender for all reasonable out-of-pocket expenses incurred by the lender inconnection with such Extension Option.ﬁStrike Priceﬂmeans (a) with respect to the initial term of the Mortgage Loan, 4.50%and (b) with respect to eachExtension Term,the rate that, when added to the weighted average Component Spread or Alternate Rate Spread, as applicable, would result in a debt service coverage ratio of not less than 1.10x.',
#   'global_num': 123},
#  {'page_num': '29',
#   'pdf_page_num': '8',
#   'local_num': 3,
#   'category': 'sentence',
#   'sentence': 'See ﬁDescription of the Mortgage LoanŠExtension Optionsﬂ.',
#   'global_num': 124},
#  {'page_num': '29',
#   'pdf_page_num': '8',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'Interest Rate CapAgreement.',
#   'global_num': 125},
#  {'page_num': '29',
#   'pdf_page_num': '8',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'The Mortgage Loan Agreement requires that the Borrower enters into an Interest Rate Capagreement with respect to the Mortgage Loan (an ﬁInterest Rate CapAgreementﬂ), with one or more Interest Rate Capproviders (each, an ﬁInterest Rate CapCounterpartyﬂ) with a strike price equalto or less thanthe Strike Price(or, subject to certain conditionsdescribed under  ﬁDescription of the Mortgage LoanŠInterest Rate CapAgreementﬂ, the Alternate Strike Price).',
#   'global_num': 126},
#  {'page_num': '29',
#   'pdf_page_num': '8',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'In connection with the origination of the Mortgage Loan, the Borrower entered into an Interest Rate CapAgreement with SMBC Capital Markets, Inc.which expires on December 9, 2020with a strike price of 4.50%.',
#   'global_num': 127},
#  {'page_num': '29',
#   'pdf_page_num': '8',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': 'The effect of the Interest Rate CapAgreement will be to limit the maximum interest rate exposure of the Borrower on the Components with respect to increases in LIBOR through the Initial Maturity Date.',
#   'global_num': 128},
#  {'page_num': '30',
#   'pdf_page_num': '9',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'In connection with any extension of the term of the Mortgage Loan, the Borrower is required to enter into an Interest Rate Cap Agreement having a strike price equal to a rate that, when added to the weighted average Component Spread or Alternate Rate Spread, as applicable,would achieve a debt service coverage ratio as calculated under the loan documentsof at least 1.10x.',
#   'global_num': 129},
#  {'page_num': '30',
#   'pdf_page_num': '9',
#   'local_num': 2,
#   'category': 'sentence',
#   'sentence': 'If either (x) the Mortgage Loan has been converted to and remains a loan bearing interest based on an alternative floating rate index(as described under ﬁDescription of the Mortgage LoanŠPrincipal and Interestﬂ) or (y) the Borrower is unable to obtain a replacement Interest Rate Cap Agreement due to the unavailability or uncertainty in the continuing availability of LIBOR as a reference rate, then the Borrower may deliver to the Mortgage Lender one or more replacement Interest Rate Cap Agreements from an Acceptable Counterparty that, in the reasonable judgment of the Mortgage Lender, either provides the reasonably equivalent protection to the Mortgage Lender as is otherwise required by the Mortgage Loan Agreement, or is otherwise in form and substance reasonably acceptable to the Mortgage Lender and is approved in writing by the Rating Agency. See ﬁDescription of the Mortgage LoanŠInterest Rate Cap Agreementﬂ.',
#   'global_num': 130},
#  {'page_num': '30',
#   'pdf_page_num': '9',
#   'local_num': 3,
#   'category': 'sentence',
#   'sentence': 'The Interest Rate CapCounterparty is required to have and maintain at all times the credit ratings described under  ﬁDescription of the Mortgage LoanŠInterest Rate CapAgreementﬂ.',
#   'global_num': 131},
#  {'page_num': '30',
#   'pdf_page_num': '9',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'The Borrower has pledged its interest in the benefits of the Interest Rate CapAgreement as security for the Mortgage Loan.',
#   'global_num': 132},
#  {'page_num': '30',
#   'pdf_page_num': '9',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'Such security interest will be assigned to the Trustee on behalf of the Trustfor the benefit of the Certificateholders.',
#   'global_num': 133},
#  {'page_num': '30',
#   'pdf_page_num': '9',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'Pursuant to the collateral assignment of the Interest Rate Cap Agreement, SMBC Capital Markets, Inc. has agreed to remit all payments due under the Interest Rate CapAgreement to the LockboxAccountduring the continuance of a Cash Sweep Event.',
#   'global_num': 134},
#  {'page_num': '30',
#   'pdf_page_num': '9',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': 'See ﬁDescription of the Interest Rate CapAgreementﬂ.',
#   'global_num': 135},
#  {'page_num': '30',
#   'pdf_page_num': '9',
#   'local_num': 8,
#   'category': 'sentence',
#   'sentence': 'Release of Hotel Rooms.',
#   'global_num': 136},
#  {'page_num': '30',
#   'pdf_page_num': '9',
#   'local_num': 9,
#   'category': 'sentence',
#   'sentence': 'The Borrower is permitted to either (a) obtain the release from the lien of the Mortgage Loan Documentsor (b) subordinate the lien of the Mortgage Loan Documentsto a lease to a third-party Marriott brand timeshare operatorof up to 308 hotel rooms at the Mortgaged Property, subject to the satisfaction of certain conditions, including but not limited to (a) the Borrower provides the Mortgage Lender with at least 30 days prior written noticeof its request to obtain a release of the hotel rooms,(b) the released rooms consist of all hotel rooms on one or more floors, (c)the Borrowerpays tothe MortgageLender an amount no less than the Release Price for each related hotel room, (d) no Mortgage Loan Event of Default has occurred and is continuing as of the date of the release, (e)the Borrower provides the Mortgage Lender with evidence reasonably acceptable to the Mortgage Lender that (i) the released hotel rooms are legally subdivided from the rest of the Mortgaged Property and (ii)the released hotel roomsarenot necessary for the Mortgaged Property to comply with any zoning, building, land use or parking or other similar legal requirements, (f) the Borrower has delivered to the Mortgage Lender an endorsement to the applicable title insurance policy, (g)the Mortgage Lender has received payment of all the Mortgage Lender™s reasonable, out-of-pocket costs and expenses actually incurred in connection with the release of the hotel rooms, (h) the debt yield of the Mortgage Loan following the release of the hotel rooms will meet certain requirements specified in the Mortgage Loan Documents, (i) the release complies with all applicable REMIC requirements and (j) the Mortgage Lender has received a Rating Agency Confirmation with respect to the release of the hotel rooms.',
#   'global_num': 137},
#  {'page_num': '30',
#   'pdf_page_num': '9',
#   'local_num': 10,
#   'category': 'sentence',
#   'sentence': 'See ﬁDescription of the Mortgage LoanŠRelease of the Mortgaged Propertyﬂin this Offering Circular.',
#   'global_num': 138},
#  {'page_num': '31',
#   'pdf_page_num': '10',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'Release of the ParkingParcel.',
#   'global_num': 139},
#  {'page_num': '31',
#   'pdf_page_num': '10',
#   'local_num': 2,
#   'category': 'sentence',
# ...
#   'global_num': 956},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'Additionally, the Servicer, the Special Servicer or any of their affiliates, in the ordinary course of their businesses, may in the future acquire mortgage loans fortheir own account, including, in each such case, mortgage loans similar to the Mortgage Loan.',
#   'global_num': 957},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'The real properties securing these other mortgage loans may be in the same markets as, and compete with, the Mortgaged Propertysecuring the Mortgage Loan.',
#   'global_num': 958},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'Consequently, personnel of the Servicer or the Special Servicer may perform services, on behalf of the Trust, with respect to the Mortgage Loan at the same time as they are performing services with respect to, or while the Servicer, the Special Servicer or any of their affiliates are holding, other mortgage loans secured by propertiesthat compete with the Mortgaged Property securing the Mortgage Loan.',
#   'global_num': 959},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': 'This may pose inherent conflicts for the Servicer or the Special Servicer.',
#   'global_num': 960},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 8,
#   'category': 'sentence',
#   'sentence': 'Certain relationships and transactions between a Certificateholder and the Special Servicer may result in conflicts of interest.',
#   'global_num': 961},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 9,
#   'category': 'sentence',
#   'sentence': 'Additionally, these parties (and/or their affiliates) may, in the ordinary course of business, have relationships with, render services to, and engage in other transactions with each other.',
#   'global_num': 962},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 10,
#   'category': 'sentence',
#   'sentence': 'We cannot assure you that these transactions andrelationships will not influence the actions taken by the Special Servicer.',
#   'global_num': 963},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 11,
#   'category': 'sentence',
#   'sentence': 'Each of the foregoing relationships should be considered carefully by you before you invest in any Certificates.',
#   'global_num': 964},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 12,
#   'category': 'sentence',
#   'sentence': 'See also ﬁŠPotential Conflicts of Interest Among Various Certificateholdersﬂ below.',
#   'global_num': 965},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 13,
#   'category': 'sentence',
#   'sentence': 'Potential Conflicts of Interest of the Operating AdvisorPark Bridge Lender Services LLC, a New York limited liability company, has been appointed as the initial Operating Advisor with respect to the Mortgage Loan.',
#   'global_num': 966},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 14,
#   'category': 'sentence',
#   'sentence': 'See ﬁTransaction PartiesŠThe Operating Advisorﬂ in this Offering Circular.',
#   'global_num': 967},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 15,
#   'category': 'sentence',
#   'sentence': 'In the normal course of conducting its business, the initial Operating Advisor and its affiliates may have rendered services to,performed surveillance of, provided valuation and due diligence services to, and negotiated with, numerous parties engaged in activities related to structured finance and commercial mortgage securitization.',
#   'global_num': 968},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 16,
#   'category': 'sentence',
#   'sentence': 'These parties may have included institutional investors, the Depositor, the Mortgage Loan Sellers, the Borrower Sponsor, the Certificate Administrator, the Trustee, the Servicer, the Special Servicer, the Directing Certificateholder, the Borrower Sponsor, the Guarantorsor the Borrower or affiliates of any of those parties.',
#   'global_num': 969},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 17,
#   'category': 'sentence',
#   'sentence': 'Each of these relationships, to the extent they exist, may continue in the future, and may involve a conflict of interest with respect to the initial Operating Advisor™s duties as Operating Advisor.',
#   'global_num': 970},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 18,
#   'category': 'sentence',
#   'sentence': 'We cannot assure you that the existence of these relationships and other relationships in the future will not impact the manner in which the initial Operating Advisor performs its duties under the Trust and Servicing Agreement.',
#   'global_num': 971},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 19,
#   'category': 'sentence',
#   'sentence': 'Additionally, Park Bridge Lender Services LLC or its affiliates, in the ordinary course of its business, may in the future (a) perform forthird parties contract underwriting and due diligence services and advisory services as well as service or specially service mortgage loans and (b) acquire or have interest in existing and new commercial and multifamily mortgage loans for its own account,including mortgage loans similar to the Mortgage Loan.',
#   'global_num': 972},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 20,
#   'category': 'sentence',
#   'sentence': 'The real properties securing these other mortgage loans may be in the same markets as, or have owners, obligors or property managers in common with, and compete with, the Mortgaged Propertysecuring the Mortgage Loan.',
#   'global_num': 973},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 21,
#   'category': 'sentence',
#   'sentence': 'Consequently, personnel of Park Bridge Lender Services LLC may perform services, on behalf of the Trust, with respect to the Mortgage Loan at the same time as they are performing services with respect to, or while Park Bridge Lender Services LLC or its affiliates are holding, other mortgage loans secured by properties that compete with the Mortgaged Propertysecuring the Mortgage Loan.',
#   'global_num': 974},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 22,
#   'category': 'sentence',
#   'sentence': 'This may pose inherent conflicts of interest for Park Bridge Lender Services LLC. Although the Operating Advisor is required to consider Accepted Servicing Practices in connection with its activities under the Trust and Servicing Agreement, the Operating Advisor will not itself be bound by Accepted Servicing Practices.',
#   'global_num': 975},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 23,
#   'category': 'sentence',
#   'sentence': 'In addition, the Operating Advisor and its affiliates may have interests that are in conflict with those of Certificateholders if the Operating Advisor or any of its affiliates has financial interests in or financial dealings with the Borrower, a parent of the Borrower or any of their affiliates.',
#   'global_num': 976},
#  {'page_num': '80',
#   'pdf_page_num': '59',
#   'local_num': 24,
#   'category': 'sentence',
#   'sentence': 'Each of these relationships may also create a conflict of interest.',
#   'global_num': 977},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 1,
#   'category': 'sentence',
#   'sentence': 'Potential Conflicts of Interest of the Initial Purchasersand TheirAffiliatesThe activities and interests of the Initial Purchasersand theirrespective affiliates (individually, each an ﬁInitial Purchaser Entityﬂandcollectively, the ﬁInitial Purchaser Entitiesﬂ) will not align with, and may in fact be directly contrary to, those of Certificateholders.',
#   'global_num': 978},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 2,
#   'category': 'sentence',
#   'sentence': 'The Initial Purchaser Entities are each part of global banking, investment banking, securities and investment management firms that provide a wide range of financial services to a substantial and diversified client base that includes corporations, financial institutions, governments and high net worth individuals.',
#   'global_num': 979},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 3,
#   'category': 'sentence',
#   'sentence': 'As such, they actively make markets in and trade financial instruments for their own account and for the accounts of customers.',
#   'global_num': 980},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 4,
#   'category': 'sentence',
#   'sentence': 'These financial instruments include debt and equity securities, currencies, commodities, bank loans, indices, baskets and other products.',
#   'global_num': 981},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 5,
#   'category': 'sentence',
#   'sentence': 'The Initial Purchaser Entities™ activities include, among other things, executing large block trades and taking long and short positions directly and indirectly, through derivative instruments or otherwise.',
#   'global_num': 982},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 6,
#   'category': 'sentence',
#   'sentence': 'The securities and instruments in which the Initial Purchaser Entities take positions, or expect to take positions, include loans similar to theMortgage Loan, securities and instruments similar to the Certificates and other securities and instruments.',
#   'global_num': 983},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 7,
#   'category': 'sentence',
#   'sentence': 'Market making is an activity where the Initial Purchaser Entities buy and sell on behalf of customers, or for their own account, to satisfythe expected demand of customers.',
#   'global_num': 984},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 8,
#   'category': 'sentence',
#   'sentence': 'By its nature, market making involves facilitating transactions among market participants that have differing views of securities and instruments.',
#   'global_num': 985},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 9,
#   'category': 'sentence',
#   'sentence': 'As a result, you should expect that the Initial Purchaser Entities will take positions that are inconsistent with, or adverse to, the investment objectives of investors in the Certificates.',
#   'global_num': 986},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 10,
#   'category': 'sentence',
#   'sentence': 'As a result of the Initial Purchaser Entities™ various financial market activities, including acting as a research provider, investment advisor, market maker or principal investor, you should expect that personnel in various businesses throughoutthe Initial Purchaser Entities will have and express research or investment views and make recommendations that are inconsistent with, or adverse to, the objectives of investors in the Certificates.',
#   'global_num': 987},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 11,
#   'category': 'sentence',
#   'sentence': 'If any Initial Purchaser Entity becomes a holder of any of the Certificates, through market-making activity or otherwise, any actions that it may take in its capacity as a Certificateholder, including voting, providing consents or otherwise will not necessarily be aligned with the interests of the other holdersof the same Class or other Classes of the Certificates.',
#   'global_num': 988},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 12,
#   'category': 'sentence',
#   'sentence': 'We cannot assure youthat any actions that such party takes in either such capacity will necessarily be aligned with the interests of the holders of the Certificates.',
#   'global_num': 989},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 13,
#   'category': 'sentence',
#   'sentence': 'To the extent an Initial Purchaser Entity makes a market in the Certificates(which it is under no obligation to do), it would expect to receive income from the spreads between its bid and offer prices for the Certificates.',
#   'global_num': 990},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 14,
#   'category': 'sentence',
#   'sentence': 'The price at which an Initial Purchaser Entity may be willing to purchase Certificates, if it makes a market, will depend on market conditions and other relevant factors and may be significantly lower than the issue price for the Certificatesand significantly lower than the price at which it may be willing to sell Certificates.',
#   'global_num': 991},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 15,
#   'category': 'sentence',
#   'sentence': 'In addition, the Initial Purchaser Entities will have no obligation to monitor the performance of the Certificates or the actions of the Servicer, the Special Servicer, the Operating Advisor, the Certificate Administrator or the Trustee and will have no authority to advise any such parties or to direct their actions.',
#   'global_num': 992},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 16,
#   'category': 'sentence',
#   'sentence': 'Furthermore, the Initial Purchaser Entities expect that a completed offering will enhance their ability to assist clients and counterparties in the transaction or in related transactions (including assisting clients in additional purchases and sales of the Certificatesand hedging transactions).',
#   'global_num': 993},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 17,
#   'category': 'sentence',
#   'sentence': 'The Initial Purchaser Entities expect to derive fees and other revenues from these transactions.',
#   'global_num': 994},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 18,
#   'category': 'sentence',
#   'sentence': 'In addition, participating in a successful offering and providing related services to clients may enhance the Initial Purchaser Entities™ relationships with various parties, facilitate additional business development, and enable them to obtain additional business and generate additional revenue.',
#   'global_num': 995},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 19,
#   'category': 'sentence',
#   'sentence': 'In addition, the Initial Purchaser Entities may have ongoing relationships with, render services to, and engage in transactions with any Borrower Affiliates, which relationships and transactions may create conflicts of interest between the Initial Purchaser and its affiliates, on the one hand, and the Trust, on the other hand.',
#   'global_num': 996},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 20,
#   'category': 'sentence',
#   'sentence': 'See ﬁSummary of Offering CircularŠCertain Affiliationsﬂ in this Offering Circular for a description of certain affiliations and relationships between the Initial Purchaser and otherparticipants in this offering.',
#   'global_num': 997},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 21,
#   'category': 'sentence',
#   'sentence': 'Each of the foregoing relationships should be considered carefully by you before you invest in any Certificates.',
#   'global_num': 998},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 22,
#   'category': 'sentence',
#   'sentence': 'Potential Conflicts of Interest of the Property ManagerThe Property Manager, and any replacement Property Manager, also manage other properties including properties that compete with the Mortgaged Property.',
#   'global_num': 999},
#  {'page_num': '81',
#   'pdf_page_num': '60',
#   'local_num': 23,
#   'category': 'sentence',
#   'sentence': 'Accordingly, the Property Manager, including any replacement Property Manager, may experience conflicts of interest in the management of the Mortgaged Property, and may be hesitant to take actions with respect to the Mortgaged Property that may have an adverse effect on any other properties that they manage or own.',
#   'global_num': 1000},
#  ...]

# %%
# Out:
# 21

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-18d22dd20608> in <module>
# ----> 1 page_obj.getItem('/Page')
#       2
#
# AttributeError: 'PageObject' object has no attribute 'getItem'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-61193d4035a4> in <module>
# ----> 1 page_obj = pdf_reader.getPage(51)
#       2 x = page_obj.extractText()
#       3 x[2:4]
#       4 expr = '\\n[A-Z]'
#       5 m = re.search(expr, x[2:4])
#
# NameError: name 'pdf_reader' is not defined
