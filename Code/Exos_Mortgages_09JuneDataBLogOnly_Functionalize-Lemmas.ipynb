# %% [markdown]
# # Claira Project: Mortgage Contracts

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
import string
import numpy as np
import gzip
import seaborn as sns
np.random.seed(99)
RANDOM_STATE = 99
import datetime
pd.set_option('display.max_rows', 151)
pd.set_option('display.max_columns', 30)


# Import vectorizing and modeling tools in preparation for modeling steps
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.feature_extraction import text, stop_words
from sklearn.naive_bayes import MultinomialNB, GaussianNB, BernoulliNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
import time

from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer

import spacy
import en_core_web_lg
from spacy.lang.en import English
from spacy.lang.en.stop_words import STOP_WORDS
nlp = spacy.load('en_core_web_sm', disable = ['parser', 'ner'])

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, cross_val_predict
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import roc_curve, auc

# Import CountVectorizer and TFIDFVectorizer from feature_extraction.text.
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
# Out:
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_extraction.stop_words module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_extraction.text. Anything that cannot be imported from sklearn.feature_extraction.text is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## Define sub-functions

# %%
# printing functions
def explore_data_cleaning(raw_df):
    trigger_order = raw_df['Trigger'].value_counts().sort_values(ascending = False).index

    fig = plt.gcf()
    fig.set_size_inches(8, 8)
    ax = sns.countplot(y=raw_df['Trigger'], data=raw_df, orient = 'h', order = trigger_order)
    ax.set_title('Number of Trigger Types');

    for p in ax.patches:
        ax.annotate(int(p.get_width()),((p.get_x() + p.get_width()), p.get_y()), xytext=(17, -15),fontsize=9,textcoords='offset points', horizontalalignment='right')

    #https://stackoverflow.com/questions/50190409/how-to-annotate-horizontal-seaborn-countplots
    return

# %%
# function to get data 
def get_data():
    # Import the CSV file
    raw_df = pd.read_csv('../data/sasb_cash_trap_triggers_06_09_20.csv')
    return raw_df

# function to clean data
def clean_data(raw_df, print_fns=False):
    # project out extra columns
    raw_df = raw_df[['Document', 'Sentence', 'Trigger', 'Multiclass']]
    
    # Convert each category to Title format (to remove discrepancies based on capitalization)
    raw_df['Trigger'] = raw_df['Trigger'].str.title()

    # Some data fixes
    raw_df['Trigger'] = raw_df['Trigger'].str.replace('Falll', 'Fall')
    raw_df.loc[raw_df['Trigger'] == 'Aggregate Debt Yield', 'Trigger'] = 'Aggregate Debt Yield Fall'

    # Some dollar sign symbols are causing problems - will remove them here
    raw_df['Sentence'] = raw_df['Sentence'].replace({'\$':''}, regex = True)

    # Drop Multiclass column since it isn't needed
    raw_df = raw_df.drop('Multiclass', axis = 1)
    
    # Count the number of distinct documents
    num_docs = raw_df['Document'].nunique()
    print(f'{num_docs} unique documents have been included in the data set')
    
    # Summarize the trigger counts for the existing Document set
    max_triggers = raw_df['Document'].value_counts().max()
    min_triggers = raw_df['Document'].value_counts().min()
    print(f'The {num_docs} Documents have tag counts that range from {min_triggers} to {max_triggers}.')

    # run the extra code that analyzes the data
    if print_fns:
        explore_data_cleaning(raw_df)
        
    return raw_df

# %%
# function to reshape the dataframe such that the triggers are 0/1 columns. Remove duplicates
def reshape_trigger_representation(dataframe):
    # select trigger types
    trigger_types = list(dataframe['Trigger'].unique())
    trigger_types = [x for x in trigger_types if str(x) != 'nan']

    # create new dataframe with unique document-sentence pairs (no duplicates)
    reshaped = dataframe.drop('Trigger', axis = 1).drop_duplicates().reset_index().drop('index', axis = 1)

    # select rows by trigger, reassign as 1 or 0 (for True or False)
    for tt in trigger_types:
        # select part that is trigger_type
        temp = dataframe.loc[dataframe['Trigger'] == tt].copy()

        # create a new column of true with trigger name
        temp[tt.lower().replace(' ', '_')] = np.int64(1)
        temp.drop('Trigger', axis=1, inplace=True)
        temp[tt.lower().replace(' ', '_')] = temp[tt.lower().replace(' ', '_')].astype('Int64')

        # left join this adjusted column to the unique data
        reshaped = reshaped.merge(temp, how='left', left_on=['Document', 'Sentence'], right_on=['Document', 'Sentence'])

    # replace nulls with False
    reshaped = reshaped.fillna(0)  
    
    return reshaped

# %%
# Shall we create doc view and remove the extraneous document without tags?

# %%
def tokenize(text):
    doc = nlp(text)
    tokens = [token.text for token in doc]
    return ' '.join(tokens)

# %%
def lemmatize(text):
    doc = nlp(text)
    lemmas = [token.lemma_ for token in doc]
    return ' '.join(lemmas)

# %%
# NLP processing the sentence columns to prep for models
def tokenize_sentences(dataframe):
    print('Tokenizing the input sentences...')
    dataframe['SentenceTokens'] = dataframe['Sentence'].apply(tokenize)
    dataframe['SentenceLemmas'] = dataframe['Sentence'].apply(lemmatize)
    print(f"{len(dataframe['Sentence'])} sentences have been tokenized and lemmatized.")
    print("\n")
    return dataframe

# %%
# Incorporate Stopwords
def get_stopwords():
    # might need space
    short_stopwords = ['the', 'to', 'of', 'be', 'and', 'in', 'a']
    short_stopwords2 = ['the', 'and', 'a', 'to', 'it', 'be', 'for', 'with', 'that']
    stopwords = list(STOP_WORDS)

    return short_stopwords, short_stopwords2, stopwords

# %%
# function to split data for each target column (trigger type)
def get_split_data(df, target_info):
    # extract target name
    target = target_info['target']
    model_input  = target_info['model_input']
    


    # create X, Y
    X = df[model_input]
    y = df[target]
    indices = df.index

    print(f"Number of labeled instances within the full sentence data set: {y.value_counts()[1]}")   
    
    y = y.astype('int')

    # run test, train split
    X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(X, y, indices, test_size = 0.3, stratify = y, random_state = RANDOM_STATE)

    # print information


#    print(indices_train.shape, indices_test.shape)
    
    # create output dictionary
    split_data = {}
    split_data['X_train'] = X_train
    split_data['X_test'] = X_test
    split_data['y_train'] = y_train
    split_data['y_test'] = y_test
    split_data['indices_train'] = indices_train
    split_data['indices_test'] = indices_test
    
    return split_data

# %%
# run the model with the chosen model and metric
def run_model(split_data, target_info):

    # get stopwords
    short_stopwords, short_stopwords2, stopwords = get_stopwords()
    
    # set pipeline according to the selected model:
    if target_info['model'] == 'lr':
        # Define CVEC + Logistic Regression Pipeline
        pipe = Pipeline([('cvec', CountVectorizer()), ('lr', LogisticRegression(solver = 'liblinear', random_state = RANDOM_STATE))])
        params = {
            'cvec__ngram_range': [(1,2), (1,3), (1,4), (1,5), (1,6), (1,7)],
            'cvec__stop_words': [None, short_stopwords, short_stopwords2, stopwords],  
            'cvec__max_features': [100, 200, 400, 600, 1000],
            'cvec__min_df': [2],
            'cvec__max_df': [.99],
            }

    elif target_info['model'] == 'rf':
        # Define CVEC + Logistic Regression Pipeline
        pipe = Pipeline([('cvec', CountVectorizer()), ('rf', RandomForestClassifier(random_state = RANDOM_STATE, n_jobs = 2))])
        params = {
            'cvec__ngram_range': [(1,2), (1,3), (1,4), (1,5)],
            'cvec__stop_words': [None, short_stopwords, short_stopwords2],  
            'cvec__max_features': [100, 200, 400, 800],
            'cvec__min_df': [2],
            'cvec__max_df': [.99],
            'rf__max_depth': [4,5, 6],
            'rf__min_samples_split': [2,3],
            'rf__min_samples_leaf': [10, 12]
            }

    
    else:
        print('did not specify model throw error')

    # define pipeline
    gs_model = GridSearchCV(pipe, param_grid = params, cv = 3, scoring = target_info['metric'])

    # Start the timer.
    t0 = time.time()

    # extract x/y_train
    X_train = split_data['X_train']
    y_train = split_data['y_train']
    
    # run pipeline
    model_result = gs_model.fit(X_train, y_train)

    print(f"Seconds elapsed for fitting: {(time.time() - t0):.3f}") # How many seconds elapsed.   
    return model_result

# %% [markdown]
# ## Main Control Function - runs the full model for all target types

# %%
# Control of the main project

# define dictionary of targets contains: tag, model, metric, input, order
target_dict = {}
target_dict['nontrigger'] = {'target': 'nontrigger', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['loan_default'] = {'target': 'loan_default', 'model': 'lr', 'metric':'accuracy', 'model_input':'SentenceLemmas'}
target_dict['unspecified'] = {'target': 'unspecified', 'model': 'lr', 'metric':'accuracy', 'model_input':'SentenceLemmas'}
target_dict['debt_yield_fall'] = {'target': 'debt_yield_fall', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['mezzanine_default'] = {'target': 'mezzanine_default', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['tenant_failure'] = {'target': 'tenant_failure', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['bankruptcy'] = {'target': 'bankruptcy', 'model': 'lr', 'metric': 'accuracy', 'model_input': 'SentenceLemmas'}
target_dict['aggregate_debt_yield_fall'] = {'target': 'aggregate_debt_yield_fall', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['dscr_fall'] = {'target': 'dscr_fall', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['renovations'] = {'target': 'renovations', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['operator_termination'] = {'target': 'operator_termination', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['sponsor_termination'] = {'target': 'sponsor_termination', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['mezzanine_outstanding'] = {'target': 'mezzanine_outstanding', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['aggregate_dscr_fall'] = {'target': 'aggregate_dscr_fall', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['sff'] = {'target': 'sff', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}

# set output_dict - will contain target + output of calculations
output_dict = {}

# get data
raw_df = get_data()
raw_df = clean_data(raw_df)

# Reshape our original dataframe and tokenize to prepare sentences for models
df = reshape_trigger_representation(raw_df)
df = tokenize_sentences(df)

# run for each model definition
for k,v in target_dict.items():
    
    print(f"{target_dict[k]['target'].replace('_', ' ').title()}: creating Train-Test split")
    # get split data
    split_data = get_split_data(df, v)
    
    print(f"Model fit in progress: {target_dict[k]}")
    # run model
    model_result = run_model(split_data, v)
    
    # make the output dictionary
    output_dict[k] = v
    output_dict[k]['split_data'] = split_data
    output_dict[k]['model_result'] = model_result

    
    print(f"Best fit parameters: {model_result.best_params_}")
    print(f"Best fit 3-fold cross validation score: {model_result.best_score_:.3f}")
    print(f"{target_dict[k]['target'].replace('_', ' ').title()} {target_dict[k]['metric']} Train score: {model_result.score(split_data['X_train'], split_data['y_train']):.3f}")
    print(f"{target_dict[k]['target'].replace('_', ' ').title()} {target_dict[k]['metric']} Test score: {model_result.score(split_data['X_test'], split_data['y_test']):.3f}")
    print("\n")
    
    output_dict[k]['best_params'] = model_result.best_params_
    output_dict[k]['count'] = df[target_dict[k]['target']].value_counts()[1]
    output_dict[k]['best_crossval_score'] = model_result.best_score_
    output_dict[k]['train_score'] = model_result.score(split_data['X_train'], split_data['y_train'])
    output_dict[k]['test_score'] = model_result.score(split_data['X_test'], split_data['y_test'])                                                  
    

full_output_dict = [output_dict[key] for key in output_dict.keys()]
results_df = pd.DataFrame.from_dict(full_output_dict)
    
print("Modeling complete!")
# Out:
# 27 unique documents have been included in the data set
# The 27 Documents have tag counts that range from 25 to 176.
# Tokenizing the input sentences...
# 2041 sentences have been tokenized and lemmatized.
#
#
# Nontrigger: creating Train-Test split
# Number of labeled instances within the full sentence data set: 1056
# Model fit in progress: {'target': 'nontrigger', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 191.108
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 1000, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 3), 'cvec__stop_words': ['mostly', 'before', 'i', 'noone', 'has', 'nobody', 'top', 'whatever', 'another', 'really', 'some', 'onto', 'please', 'them', 'bottom', 'less', 'always', 'same', 'nothing', 'did', 'put', 'indeed', 'two', 'yourself', 'yourselves', 'here', 'amongst', 'his', 'serious', 'give', 'by', 'thereupon', 'own', 'mine', 'thus', 'for', 'during', 'cannot', 'three', 'could', 'would', 'against', 'our', 'enough', 'but', 'ca', 'hers', 'nevertheless', 'next', 'quite', 'may', 'back', 'everywhere', 'wherever', 'above', 'everything', 'becomes', 'often', 'beside', 'via', 'first', 'more', 'if', 'such', 'to', 'too', 'do', 'other', 'then', 'therein', 'make', 'part', 'any', 'together', 'former', 'nine', 'done', 'over', 'they', 'ever', 'see', 'else', 'very', 'namely', 'down', 'eleven', 'anyway', 'from', 'be', 'many', 'thence', 'as', 'at', 'show', 'whenever', 'four', 'into', 'thereafter', 'even', 'been', 'keep', 'no', 'full', 'unless', 'once', 'fifty', 'seem', 'this', 'under', 'she', 'side', 'not', 'using', 'already', 'there', 'or', 'can', 'one', 'themselves', 'much', 'and', 'around', 'every', 'whence', 'behind', 'ours', 'twenty', 'was', 'afterwards', 'in', 'across', 'herein', 'ourselves', 'sometime', 'though', 'we', 'call', 'although', 'hundred', 'is', 'within', 'that', 'last', 'her', 'while', 'further', 'due', 'few', 'these', 'however', 'its', 'whereas', 'anything', 'whole', 'might', 'yours', 'both', 'used', 'am', 'except', 'well', 'fifteen', 'several', 'on', 'must', 'latter', 'everyone', 'how', 'still', 'about', 'below', 'most', 'somehow', 'yet', 'after', 'eight', 'whither', 'front', 'none', 'whereupon', 'it', 'never', 'hereafter', 'third', 'out', 'off', 'besides', 'somewhere', 'what', 'elsewhere', 'of', 'being', 'say', 'so', 'towards', 'alone', 'again', 'had', 'he', 'my', 'either', 'something', 'ten', 'thru', 'your', 'empty', 'were', 'twelve', 'an', 'neither', 'rather', 'all', 'itself', 'those', 'upon', 'made', 'moreover', 'will', 'you', 'because', 'along', 'anyhow', 'nor', 'does', 'than', 'whether', 'go', 'someone', 'have', 'toward', 'anyone', 'move', 'me', 'latterly', 'herself', 'otherwise', 'seemed', 'take', 'various', 'sometimes', 'name', 'anywhere', 'seeming', 'forty', 'him', 'myself', 'the', 'wherein', 'between', 'throughout', 'seems', 'each', 'until', 'who', 'nowhere', 're', 'whom', 'formerly', 'should', 'beyond', 'hence', 'meanwhile', 'whoever', 'where', 'became', 'among', 'hereupon', 'whereafter', 'with', 'only', 'therefore', 'almost', 'through', 'which', 'become', 'why', 'their', 'us', 'hereby', 'get', 'perhaps', 'regarding', 'when', 'beforehand', 'himself', 'least', 'also', 'becoming', 'whereby', 'whose', 'thereby', 'a', 'five', 'sixty', 'just', 'since', 'now', 'per', 'are', 'up', 'others', 'without', 'amount', 'doing', 'six']}
# Best fit 3-fold cross validation score: 0.970
# Nontrigger f1 Train score: 0.993
# Nontrigger f1 Test score: 0.983
#
#
# Loan Default: creating Train-Test split
# Number of labeled instances within the full sentence data set: 459
# Model fit in progress: {'target': 'loan_default', 'model': 'lr', 'metric': 'accuracy', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 175.678
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 100, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 4), 'cvec__stop_words': ['the', 'to', 'of', 'be', 'and', 'in', 'a']}
# Best fit 3-fold cross validation score: 0.982
# Loan Default accuracy Train score: 0.992
# Loan Default accuracy Test score: 0.979
#
#
# Unspecified: creating Train-Test split
# Number of labeled instances within the full sentence data set: 356
# Model fit in progress: {'target': 'unspecified', 'model': 'lr', 'metric': 'accuracy', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 184.524
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 600, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 4), 'cvec__stop_words': ['the', 'to', 'of', 'be', 'and', 'in', 'a']}
# Best fit 3-fold cross validation score: 0.956
# Unspecified accuracy Train score: 0.998
# Unspecified accuracy Test score: 0.954
#
#
# Debt Yield Fall: creating Train-Test split
# Number of labeled instances within the full sentence data set: 204
# Model fit in progress: {'target': 'debt_yield_fall', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 182.640
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 1000, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 3), 'cvec__stop_words': None}
# Best fit 3-fold cross validation score: 0.954
# Debt Yield Fall f1 Train score: 1.000
# Debt Yield Fall f1 Test score: 0.967
#
#
# Mezzanine Default: creating Train-Test split
# Number of labeled instances within the full sentence data set: 105
# Model fit in progress: {'target': 'mezzanine_default', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 175.254
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 100, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 3), 'cvec__stop_words': ['the', 'to', 'of', 'be', 'and', 'in', 'a']}
# Best fit 3-fold cross validation score: 0.965
# Mezzanine Default f1 Train score: 0.993
# Mezzanine Default f1 Test score: 0.918
#
#
# Tenant Failure: creating Train-Test split
# Number of labeled instances within the full sentence data set: 37
# Model fit in progress: {'target': 'tenant_failure', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 177.288
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 400, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 2), 'cvec__stop_words': ['the', 'to', 'of', 'be', 'and', 'in', 'a']}
# Best fit 3-fold cross validation score: 0.886
# Tenant Failure f1 Train score: 1.000
# Tenant Failure f1 Test score: 0.857
#
#
# Bankruptcy: creating Train-Test split
# Number of labeled instances within the full sentence data set: 77
# Model fit in progress: {'target': 'bankruptcy', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 179.168
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 1000, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 4), 'cvec__stop_words': ['mostly', 'before', 'i', 'noone', 'has', 'nobody', 'top', 'whatever', 'another', 'really', 'some', 'onto', 'please', 'them', 'bottom', 'less', 'always', 'same', 'nothing', 'did', 'put', 'indeed', 'two', 'yourself', 'yourselves', 'here', 'amongst', 'his', 'serious', 'give', 'by', 'thereupon', 'own', 'mine', 'thus', 'for', 'during', 'cannot', 'three', 'could', 'would', 'against', 'our', 'enough', 'but', 'ca', 'hers', 'nevertheless', 'next', 'quite', 'may', 'back', 'everywhere', 'wherever', 'above', 'everything', 'becomes', 'often', 'beside', 'via', 'first', 'more', 'if', 'such', 'to', 'too', 'do', 'other', 'then', 'therein', 'make', 'part', 'any', 'together', 'former', 'nine', 'done', 'over', 'they', 'ever', 'see', 'else', 'very', 'namely', 'down', 'eleven', 'anyway', 'from', 'be', 'many', 'thence', 'as', 'at', 'show', 'whenever', 'four', 'into', 'thereafter', 'even', 'been', 'keep', 'no', 'full', 'unless', 'once', 'fifty', 'seem', 'this', 'under', 'she', 'side', 'not', 'using', 'already', 'there', 'or', 'can', 'one', 'themselves', 'much', 'and', 'around', 'every', 'whence', 'behind', 'ours', 'twenty', 'was', 'afterwards', 'in', 'across', 'herein', 'ourselves', 'sometime', 'though', 'we', 'call', 'although', 'hundred', 'is', 'within', 'that', 'last', 'her', 'while', 'further', 'due', 'few', 'these', 'however', 'its', 'whereas', 'anything', 'whole', 'might', 'yours', 'both', 'used', 'am', 'except', 'well', 'fifteen', 'several', 'on', 'must', 'latter', 'everyone', 'how', 'still', 'about', 'below', 'most', 'somehow', 'yet', 'after', 'eight', 'whither', 'front', 'none', 'whereupon', 'it', 'never', 'hereafter', 'third', 'out', 'off', 'besides', 'somewhere', 'what', 'elsewhere', 'of', 'being', 'say', 'so', 'towards', 'alone', 'again', 'had', 'he', 'my', 'either', 'something', 'ten', 'thru', 'your', 'empty', 'were', 'twelve', 'an', 'neither', 'rather', 'all', 'itself', 'those', 'upon', 'made', 'moreover', 'will', 'you', 'because', 'along', 'anyhow', 'nor', 'does', 'than', 'whether', 'go', 'someone', 'have', 'toward', 'anyone', 'move', 'me', 'latterly', 'herself', 'otherwise', 'seemed', 'take', 'various', 'sometimes', 'name', 'anywhere', 'seeming', 'forty', 'him', 'myself', 'the', 'wherein', 'between', 'throughout', 'seems', 'each', 'until', 'who', 'nowhere', 're', 'whom', 'formerly', 'should', 'beyond', 'hence', 'meanwhile', 'whoever', 'where', 'became', 'among', 'hereupon', 'whereafter', 'with', 'only', 'therefore', 'almost', 'through', 'which', 'become', 'why', 'their', 'us', 'hereby', 'get', 'perhaps', 'regarding', 'when', 'beforehand', 'himself', 'least', 'also', 'becoming', 'whereby', 'whose', 'thereby', 'a', 'five', 'sixty', 'just', 'since', 'now', 'per', 'are', 'up', 'others', 'without', 'amount', 'doing', 'six']}
# Best fit 3-fold cross validation score: 0.900
# Bankruptcy f1 Train score: 0.991
# Bankruptcy f1 Test score: 0.878
#
#
# Aggregate Debt Yield Fall: creating Train-Test split
# Number of labeled instances within the full sentence data set: 18
# Model fit in progress: {'target': 'aggregate_debt_yield_fall', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 177.654
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 200, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 2), 'cvec__stop_words': ['mostly', 'before', 'i', 'noone', 'has', 'nobody', 'top', 'whatever', 'another', 'really', 'some', 'onto', 'please', 'them', 'bottom', 'less', 'always', 'same', 'nothing', 'did', 'put', 'indeed', 'two', 'yourself', 'yourselves', 'here', 'amongst', 'his', 'serious', 'give', 'by', 'thereupon', 'own', 'mine', 'thus', 'for', 'during', 'cannot', 'three', 'could', 'would', 'against', 'our', 'enough', 'but', 'ca', 'hers', 'nevertheless', 'next', 'quite', 'may', 'back', 'everywhere', 'wherever', 'above', 'everything', 'becomes', 'often', 'beside', 'via', 'first', 'more', 'if', 'such', 'to', 'too', 'do', 'other', 'then', 'therein', 'make', 'part', 'any', 'together', 'former', 'nine', 'done', 'over', 'they', 'ever', 'see', 'else', 'very', 'namely', 'down', 'eleven', 'anyway', 'from', 'be', 'many', 'thence', 'as', 'at', 'show', 'whenever', 'four', 'into', 'thereafter', 'even', 'been', 'keep', 'no', 'full', 'unless', 'once', 'fifty', 'seem', 'this', 'under', 'she', 'side', 'not', 'using', 'already', 'there', 'or', 'can', 'one', 'themselves', 'much', 'and', 'around', 'every', 'whence', 'behind', 'ours', 'twenty', 'was', 'afterwards', 'in', 'across', 'herein', 'ourselves', 'sometime', 'though', 'we', 'call', 'although', 'hundred', 'is', 'within', 'that', 'last', 'her', 'while', 'further', 'due', 'few', 'these', 'however', 'its', 'whereas', 'anything', 'whole', 'might', 'yours', 'both', 'used', 'am', 'except', 'well', 'fifteen', 'several', 'on', 'must', 'latter', 'everyone', 'how', 'still', 'about', 'below', 'most', 'somehow', 'yet', 'after', 'eight', 'whither', 'front', 'none', 'whereupon', 'it', 'never', 'hereafter', 'third', 'out', 'off', 'besides', 'somewhere', 'what', 'elsewhere', 'of', 'being', 'say', 'so', 'towards', 'alone', 'again', 'had', 'he', 'my', 'either', 'something', 'ten', 'thru', 'your', 'empty', 'were', 'twelve', 'an', 'neither', 'rather', 'all', 'itself', 'those', 'upon', 'made', 'moreover', 'will', 'you', 'because', 'along', 'anyhow', 'nor', 'does', 'than', 'whether', 'go', 'someone', 'have', 'toward', 'anyone', 'move', 'me', 'latterly', 'herself', 'otherwise', 'seemed', 'take', 'various', 'sometimes', 'name', 'anywhere', 'seeming', 'forty', 'him', 'myself', 'the', 'wherein', 'between', 'throughout', 'seems', 'each', 'until', 'who', 'nowhere', 're', 'whom', 'formerly', 'should', 'beyond', 'hence', 'meanwhile', 'whoever', 'where', 'became', 'among', 'hereupon', 'whereafter', 'with', 'only', 'therefore', 'almost', 'through', 'which', 'become', 'why', 'their', 'us', 'hereby', 'get', 'perhaps', 'regarding', 'when', 'beforehand', 'himself', 'least', 'also', 'becoming', 'whereby', 'whose', 'thereby', 'a', 'five', 'sixty', 'just', 'since', 'now', 'per', 'are', 'up', 'others', 'without', 'amount', 'doing', 'six']}
# Best fit 3-fold cross validation score: 0.619
# Aggregate Debt Yield Fall f1 Train score: 1.000
# Aggregate Debt Yield Fall f1 Test score: 0.889
#
#
# Dscr Fall: creating Train-Test split
# Number of labeled instances within the full sentence data set: 25
# Model fit in progress: {'target': 'dscr_fall', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 178.914
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 400, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 2), 'cvec__stop_words': ['mostly', 'before', 'i', 'noone', 'has', 'nobody', 'top', 'whatever', 'another', 'really', 'some', 'onto', 'please', 'them', 'bottom', 'less', 'always', 'same', 'nothing', 'did', 'put', 'indeed', 'two', 'yourself', 'yourselves', 'here', 'amongst', 'his', 'serious', 'give', 'by', 'thereupon', 'own', 'mine', 'thus', 'for', 'during', 'cannot', 'three', 'could', 'would', 'against', 'our', 'enough', 'but', 'ca', 'hers', 'nevertheless', 'next', 'quite', 'may', 'back', 'everywhere', 'wherever', 'above', 'everything', 'becomes', 'often', 'beside', 'via', 'first', 'more', 'if', 'such', 'to', 'too', 'do', 'other', 'then', 'therein', 'make', 'part', 'any', 'together', 'former', 'nine', 'done', 'over', 'they', 'ever', 'see', 'else', 'very', 'namely', 'down', 'eleven', 'anyway', 'from', 'be', 'many', 'thence', 'as', 'at', 'show', 'whenever', 'four', 'into', 'thereafter', 'even', 'been', 'keep', 'no', 'full', 'unless', 'once', 'fifty', 'seem', 'this', 'under', 'she', 'side', 'not', 'using', 'already', 'there', 'or', 'can', 'one', 'themselves', 'much', 'and', 'around', 'every', 'whence', 'behind', 'ours', 'twenty', 'was', 'afterwards', 'in', 'across', 'herein', 'ourselves', 'sometime', 'though', 'we', 'call', 'although', 'hundred', 'is', 'within', 'that', 'last', 'her', 'while', 'further', 'due', 'few', 'these', 'however', 'its', 'whereas', 'anything', 'whole', 'might', 'yours', 'both', 'used', 'am', 'except', 'well', 'fifteen', 'several', 'on', 'must', 'latter', 'everyone', 'how', 'still', 'about', 'below', 'most', 'somehow', 'yet', 'after', 'eight', 'whither', 'front', 'none', 'whereupon', 'it', 'never', 'hereafter', 'third', 'out', 'off', 'besides', 'somewhere', 'what', 'elsewhere', 'of', 'being', 'say', 'so', 'towards', 'alone', 'again', 'had', 'he', 'my', 'either', 'something', 'ten', 'thru', 'your', 'empty', 'were', 'twelve', 'an', 'neither', 'rather', 'all', 'itself', 'those', 'upon', 'made', 'moreover', 'will', 'you', 'because', 'along', 'anyhow', 'nor', 'does', 'than', 'whether', 'go', 'someone', 'have', 'toward', 'anyone', 'move', 'me', 'latterly', 'herself', 'otherwise', 'seemed', 'take', 'various', 'sometimes', 'name', 'anywhere', 'seeming', 'forty', 'him', 'myself', 'the', 'wherein', 'between', 'throughout', 'seems', 'each', 'until', 'who', 'nowhere', 're', 'whom', 'formerly', 'should', 'beyond', 'hence', 'meanwhile', 'whoever', 'where', 'became', 'among', 'hereupon', 'whereafter', 'with', 'only', 'therefore', 'almost', 'through', 'which', 'become', 'why', 'their', 'us', 'hereby', 'get', 'perhaps', 'regarding', 'when', 'beforehand', 'himself', 'least', 'also', 'becoming', 'whereby', 'whose', 'thereby', 'a', 'five', 'sixty', 'just', 'since', 'now', 'per', 'are', 'up', 'others', 'without', 'amount', 'doing', 'six']}
# Best fit 3-fold cross validation score: 0.902
# Dscr Fall f1 Train score: 1.000
# Dscr Fall f1 Test score: 0.857
#
#
# Renovations: creating Train-Test split
# Number of labeled instances within the full sentence data set: 24
# Model fit in progress: {'target': 'renovations', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 183.679
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 100, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 3), 'cvec__stop_words': ['mostly', 'before', 'i', 'noone', 'has', 'nobody', 'top', 'whatever', 'another', 'really', 'some', 'onto', 'please', 'them', 'bottom', 'less', 'always', 'same', 'nothing', 'did', 'put', 'indeed', 'two', 'yourself', 'yourselves', 'here', 'amongst', 'his', 'serious', 'give', 'by', 'thereupon', 'own', 'mine', 'thus', 'for', 'during', 'cannot', 'three', 'could', 'would', 'against', 'our', 'enough', 'but', 'ca', 'hers', 'nevertheless', 'next', 'quite', 'may', 'back', 'everywhere', 'wherever', 'above', 'everything', 'becomes', 'often', 'beside', 'via', 'first', 'more', 'if', 'such', 'to', 'too', 'do', 'other', 'then', 'therein', 'make', 'part', 'any', 'together', 'former', 'nine', 'done', 'over', 'they', 'ever', 'see', 'else', 'very', 'namely', 'down', 'eleven', 'anyway', 'from', 'be', 'many', 'thence', 'as', 'at', 'show', 'whenever', 'four', 'into', 'thereafter', 'even', 'been', 'keep', 'no', 'full', 'unless', 'once', 'fifty', 'seem', 'this', 'under', 'she', 'side', 'not', 'using', 'already', 'there', 'or', 'can', 'one', 'themselves', 'much', 'and', 'around', 'every', 'whence', 'behind', 'ours', 'twenty', 'was', 'afterwards', 'in', 'across', 'herein', 'ourselves', 'sometime', 'though', 'we', 'call', 'although', 'hundred', 'is', 'within', 'that', 'last', 'her', 'while', 'further', 'due', 'few', 'these', 'however', 'its', 'whereas', 'anything', 'whole', 'might', 'yours', 'both', 'used', 'am', 'except', 'well', 'fifteen', 'several', 'on', 'must', 'latter', 'everyone', 'how', 'still', 'about', 'below', 'most', 'somehow', 'yet', 'after', 'eight', 'whither', 'front', 'none', 'whereupon', 'it', 'never', 'hereafter', 'third', 'out', 'off', 'besides', 'somewhere', 'what', 'elsewhere', 'of', 'being', 'say', 'so', 'towards', 'alone', 'again', 'had', 'he', 'my', 'either', 'something', 'ten', 'thru', 'your', 'empty', 'were', 'twelve', 'an', 'neither', 'rather', 'all', 'itself', 'those', 'upon', 'made', 'moreover', 'will', 'you', 'because', 'along', 'anyhow', 'nor', 'does', 'than', 'whether', 'go', 'someone', 'have', 'toward', 'anyone', 'move', 'me', 'latterly', 'herself', 'otherwise', 'seemed', 'take', 'various', 'sometimes', 'name', 'anywhere', 'seeming', 'forty', 'him', 'myself', 'the', 'wherein', 'between', 'throughout', 'seems', 'each', 'until', 'who', 'nowhere', 're', 'whom', 'formerly', 'should', 'beyond', 'hence', 'meanwhile', 'whoever', 'where', 'became', 'among', 'hereupon', 'whereafter', 'with', 'only', 'therefore', 'almost', 'through', 'which', 'become', 'why', 'their', 'us', 'hereby', 'get', 'perhaps', 'regarding', 'when', 'beforehand', 'himself', 'least', 'also', 'becoming', 'whereby', 'whose', 'thereby', 'a', 'five', 'sixty', 'just', 'since', 'now', 'per', 'are', 'up', 'others', 'without', 'amount', 'doing', 'six']}
# Best fit 3-fold cross validation score: 0.886
# Renovations f1 Train score: 0.970
# Renovations f1 Test score: 0.800
#
#
# Operator Termination: creating Train-Test split
# Number of labeled instances within the full sentence data set: 19
# Model fit in progress: {'target': 'operator_termination', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 178.254
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 200, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 2), 'cvec__stop_words': ['mostly', 'before', 'i', 'noone', 'has', 'nobody', 'top', 'whatever', 'another', 'really', 'some', 'onto', 'please', 'them', 'bottom', 'less', 'always', 'same', 'nothing', 'did', 'put', 'indeed', 'two', 'yourself', 'yourselves', 'here', 'amongst', 'his', 'serious', 'give', 'by', 'thereupon', 'own', 'mine', 'thus', 'for', 'during', 'cannot', 'three', 'could', 'would', 'against', 'our', 'enough', 'but', 'ca', 'hers', 'nevertheless', 'next', 'quite', 'may', 'back', 'everywhere', 'wherever', 'above', 'everything', 'becomes', 'often', 'beside', 'via', 'first', 'more', 'if', 'such', 'to', 'too', 'do', 'other', 'then', 'therein', 'make', 'part', 'any', 'together', 'former', 'nine', 'done', 'over', 'they', 'ever', 'see', 'else', 'very', 'namely', 'down', 'eleven', 'anyway', 'from', 'be', 'many', 'thence', 'as', 'at', 'show', 'whenever', 'four', 'into', 'thereafter', 'even', 'been', 'keep', 'no', 'full', 'unless', 'once', 'fifty', 'seem', 'this', 'under', 'she', 'side', 'not', 'using', 'already', 'there', 'or', 'can', 'one', 'themselves', 'much', 'and', 'around', 'every', 'whence', 'behind', 'ours', 'twenty', 'was', 'afterwards', 'in', 'across', 'herein', 'ourselves', 'sometime', 'though', 'we', 'call', 'although', 'hundred', 'is', 'within', 'that', 'last', 'her', 'while', 'further', 'due', 'few', 'these', 'however', 'its', 'whereas', 'anything', 'whole', 'might', 'yours', 'both', 'used', 'am', 'except', 'well', 'fifteen', 'several', 'on', 'must', 'latter', 'everyone', 'how', 'still', 'about', 'below', 'most', 'somehow', 'yet', 'after', 'eight', 'whither', 'front', 'none', 'whereupon', 'it', 'never', 'hereafter', 'third', 'out', 'off', 'besides', 'somewhere', 'what', 'elsewhere', 'of', 'being', 'say', 'so', 'towards', 'alone', 'again', 'had', 'he', 'my', 'either', 'something', 'ten', 'thru', 'your', 'empty', 'were', 'twelve', 'an', 'neither', 'rather', 'all', 'itself', 'those', 'upon', 'made', 'moreover', 'will', 'you', 'because', 'along', 'anyhow', 'nor', 'does', 'than', 'whether', 'go', 'someone', 'have', 'toward', 'anyone', 'move', 'me', 'latterly', 'herself', 'otherwise', 'seemed', 'take', 'various', 'sometimes', 'name', 'anywhere', 'seeming', 'forty', 'him', 'myself', 'the', 'wherein', 'between', 'throughout', 'seems', 'each', 'until', 'who', 'nowhere', 're', 'whom', 'formerly', 'should', 'beyond', 'hence', 'meanwhile', 'whoever', 'where', 'became', 'among', 'hereupon', 'whereafter', 'with', 'only', 'therefore', 'almost', 'through', 'which', 'become', 'why', 'their', 'us', 'hereby', 'get', 'perhaps', 'regarding', 'when', 'beforehand', 'himself', 'least', 'also', 'becoming', 'whereby', 'whose', 'thereby', 'a', 'five', 'sixty', 'just', 'since', 'now', 'per', 'are', 'up', 'others', 'without', 'amount', 'doing', 'six']}
# Best fit 3-fold cross validation score: 0.804
# Operator Termination f1 Train score: 1.000
# Operator Termination f1 Test score: 0.500
#
#
# Sponsor Termination: creating Train-Test split
# Number of labeled instances within the full sentence data set: 14
# Model fit in progress: {'target': 'sponsor_termination', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 181.247
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 1000, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 4), 'cvec__stop_words': ['mostly', 'before', 'i', 'noone', 'has', 'nobody', 'top', 'whatever', 'another', 'really', 'some', 'onto', 'please', 'them', 'bottom', 'less', 'always', 'same', 'nothing', 'did', 'put', 'indeed', 'two', 'yourself', 'yourselves', 'here', 'amongst', 'his', 'serious', 'give', 'by', 'thereupon', 'own', 'mine', 'thus', 'for', 'during', 'cannot', 'three', 'could', 'would', 'against', 'our', 'enough', 'but', 'ca', 'hers', 'nevertheless', 'next', 'quite', 'may', 'back', 'everywhere', 'wherever', 'above', 'everything', 'becomes', 'often', 'beside', 'via', 'first', 'more', 'if', 'such', 'to', 'too', 'do', 'other', 'then', 'therein', 'make', 'part', 'any', 'together', 'former', 'nine', 'done', 'over', 'they', 'ever', 'see', 'else', 'very', 'namely', 'down', 'eleven', 'anyway', 'from', 'be', 'many', 'thence', 'as', 'at', 'show', 'whenever', 'four', 'into', 'thereafter', 'even', 'been', 'keep', 'no', 'full', 'unless', 'once', 'fifty', 'seem', 'this', 'under', 'she', 'side', 'not', 'using', 'already', 'there', 'or', 'can', 'one', 'themselves', 'much', 'and', 'around', 'every', 'whence', 'behind', 'ours', 'twenty', 'was', 'afterwards', 'in', 'across', 'herein', 'ourselves', 'sometime', 'though', 'we', 'call', 'although', 'hundred', 'is', 'within', 'that', 'last', 'her', 'while', 'further', 'due', 'few', 'these', 'however', 'its', 'whereas', 'anything', 'whole', 'might', 'yours', 'both', 'used', 'am', 'except', 'well', 'fifteen', 'several', 'on', 'must', 'latter', 'everyone', 'how', 'still', 'about', 'below', 'most', 'somehow', 'yet', 'after', 'eight', 'whither', 'front', 'none', 'whereupon', 'it', 'never', 'hereafter', 'third', 'out', 'off', 'besides', 'somewhere', 'what', 'elsewhere', 'of', 'being', 'say', 'so', 'towards', 'alone', 'again', 'had', 'he', 'my', 'either', 'something', 'ten', 'thru', 'your', 'empty', 'were', 'twelve', 'an', 'neither', 'rather', 'all', 'itself', 'those', 'upon', 'made', 'moreover', 'will', 'you', 'because', 'along', 'anyhow', 'nor', 'does', 'than', 'whether', 'go', 'someone', 'have', 'toward', 'anyone', 'move', 'me', 'latterly', 'herself', 'otherwise', 'seemed', 'take', 'various', 'sometimes', 'name', 'anywhere', 'seeming', 'forty', 'him', 'myself', 'the', 'wherein', 'between', 'throughout', 'seems', 'each', 'until', 'who', 'nowhere', 're', 'whom', 'formerly', 'should', 'beyond', 'hence', 'meanwhile', 'whoever', 'where', 'became', 'among', 'hereupon', 'whereafter', 'with', 'only', 'therefore', 'almost', 'through', 'which', 'become', 'why', 'their', 'us', 'hereby', 'get', 'perhaps', 'regarding', 'when', 'beforehand', 'himself', 'least', 'also', 'becoming', 'whereby', 'whose', 'thereby', 'a', 'five', 'sixty', 'just', 'since', 'now', 'per', 'are', 'up', 'others', 'without', 'amount', 'doing', 'six']}
# Best fit 3-fold cross validation score: 0.719
# Sponsor Termination f1 Train score: 1.000
# Sponsor Termination f1 Test score: 0.889
#
#
# Mezzanine Outstanding: creating Train-Test split
# Number of labeled instances within the full sentence data set: 10
# Model fit in progress: {'target': 'mezzanine_outstanding', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 180.267
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 1000, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 3), 'cvec__stop_words': None}
# Best fit 3-fold cross validation score: 0.444
# Mezzanine Outstanding f1 Train score: 1.000
# Mezzanine Outstanding f1 Test score: 0.500
#
#
# Aggregate Dscr Fall: creating Train-Test split
# Number of labeled instances within the full sentence data set: 5
# Model fit in progress: {'target': 'aggregate_dscr_fall', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 190.311
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 100, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 2), 'cvec__stop_words': None}
# Best fit 3-fold cross validation score: 0.000
# Aggregate Dscr Fall f1 Train score: 1.000
# Aggregate Dscr Fall f1 Test score: 0.000
#
#
# Sff: creating Train-Test split
# Number of labeled instances within the full sentence data set: 9
# Model fit in progress: {'target': 'sff', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 200.808
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 400, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 2), 'cvec__stop_words': ['mostly', 'before', 'i', 'noone', 'has', 'nobody', 'top', 'whatever', 'another', 'really', 'some', 'onto', 'please', 'them', 'bottom', 'less', 'always', 'same', 'nothing', 'did', 'put', 'indeed', 'two', 'yourself', 'yourselves', 'here', 'amongst', 'his', 'serious', 'give', 'by', 'thereupon', 'own', 'mine', 'thus', 'for', 'during', 'cannot', 'three', 'could', 'would', 'against', 'our', 'enough', 'but', 'ca', 'hers', 'nevertheless', 'next', 'quite', 'may', 'back', 'everywhere', 'wherever', 'above', 'everything', 'becomes', 'often', 'beside', 'via', 'first', 'more', 'if', 'such', 'to', 'too', 'do', 'other', 'then', 'therein', 'make', 'part', 'any', 'together', 'former', 'nine', 'done', 'over', 'they', 'ever', 'see', 'else', 'very', 'namely', 'down', 'eleven', 'anyway', 'from', 'be', 'many', 'thence', 'as', 'at', 'show', 'whenever', 'four', 'into', 'thereafter', 'even', 'been', 'keep', 'no', 'full', 'unless', 'once', 'fifty', 'seem', 'this', 'under', 'she', 'side', 'not', 'using', 'already', 'there', 'or', 'can', 'one', 'themselves', 'much', 'and', 'around', 'every', 'whence', 'behind', 'ours', 'twenty', 'was', 'afterwards', 'in', 'across', 'herein', 'ourselves', 'sometime', 'though', 'we', 'call', 'although', 'hundred', 'is', 'within', 'that', 'last', 'her', 'while', 'further', 'due', 'few', 'these', 'however', 'its', 'whereas', 'anything', 'whole', 'might', 'yours', 'both', 'used', 'am', 'except', 'well', 'fifteen', 'several', 'on', 'must', 'latter', 'everyone', 'how', 'still', 'about', 'below', 'most', 'somehow', 'yet', 'after', 'eight', 'whither', 'front', 'none', 'whereupon', 'it', 'never', 'hereafter', 'third', 'out', 'off', 'besides', 'somewhere', 'what', 'elsewhere', 'of', 'being', 'say', 'so', 'towards', 'alone', 'again', 'had', 'he', 'my', 'either', 'something', 'ten', 'thru', 'your', 'empty', 'were', 'twelve', 'an', 'neither', 'rather', 'all', 'itself', 'those', 'upon', 'made', 'moreover', 'will', 'you', 'because', 'along', 'anyhow', 'nor', 'does', 'than', 'whether', 'go', 'someone', 'have', 'toward', 'anyone', 'move', 'me', 'latterly', 'herself', 'otherwise', 'seemed', 'take', 'various', 'sometimes', 'name', 'anywhere', 'seeming', 'forty', 'him', 'myself', 'the', 'wherein', 'between', 'throughout', 'seems', 'each', 'until', 'who', 'nowhere', 're', 'whom', 'formerly', 'should', 'beyond', 'hence', 'meanwhile', 'whoever', 'where', 'became', 'among', 'hereupon', 'whereafter', 'with', 'only', 'therefore', 'almost', 'through', 'which', 'become', 'why', 'their', 'us', 'hereby', 'get', 'perhaps', 'regarding', 'when', 'beforehand', 'himself', 'least', 'also', 'becoming', 'whereby', 'whose', 'thereby', 'a', 'five', 'sixty', 'just', 'since', 'now', 'per', 'are', 'up', 'others', 'without', 'amount', 'doing', 'six']}
# Best fit 3-fold cross validation score: 0.389
# Sff f1 Train score: 1.000
# Sff f1 Test score: 0.000
# Modeling complete!

# %%
# Print a summary table with all fitting results
results_df
# Out:
#                        target model    metric     model_input  \
# 0                  nontrigger    lr        f1  SentenceLemmas
# 1                loan_default    lr  accuracy  SentenceLemmas
# 2                 unspecified    lr  accuracy  SentenceLemmas
# 3             debt_yield_fall    lr        f1  SentenceLemmas
# 4           mezzanine_default    lr        f1  SentenceLemmas
# 5              tenant_failure    lr        f1  SentenceLemmas
# 6                  bankruptcy    lr        f1  SentenceLemmas
# 7   aggregate_debt_yield_fall    lr        f1  SentenceLemmas
# 8                   dscr_fall    lr        f1  SentenceLemmas
# 9                 renovations    lr        f1  SentenceLemmas
# 10       operator_termination    lr        f1  SentenceLemmas
# 11        sponsor_termination    lr        f1  SentenceLemmas
# 12      mezzanine_outstanding    lr        f1  SentenceLemmas
# 13        aggregate_dscr_fall    lr        f1  SentenceLemmas
# 14                        sff    lr        f1  SentenceLemmas
#
#                                            split_data  \
# 0   {'X_train': ['" true up payment " mean a payme...
# 1   {'X_train': ['because some fund may be receive...
# 2   {'X_train': ['however , the inability of the b...
# 3   {'X_train': ['all interest in the required ren...
# 4   {'X_train': ['amount deposit in the replacemen...
# 5   {'X_train': ['there be a risk that the borrowe...
# 6   {'X_train': ['during the continuance of a mort...
# 7   {'X_train': ['if the amount of the condo asses...
# 8   {'X_train': ['pursuant to the cash management ...
# 9   {'X_train': ['pursuant to the cash management ...
# 10  {'X_train': ['to the extent that a trigger per...
# 11  {'X_train': ['" cash sweep event cure " mean (...
# 12  {'X_train': ['any low cash flow period thresho...
# 13  {'X_train': ['" eligible institution " mean ( ...
# 14  {'X_train': ['a " low cash flow period " have ...
#
#                                          model_result  \
# 0   GridSearchCV(cv=3, error_score=nan,\n         ...
# 1   GridSearchCV(cv=3, error_score=nan,\n         ...
# 2   GridSearchCV(cv=3, error_score=nan,\n         ...
# 3   GridSearchCV(cv=3, error_score=nan,\n         ...
# 4   GridSearchCV(cv=3, error_score=nan,\n         ...
# 5   GridSearchCV(cv=3, error_score=nan,\n         ...
# 6   GridSearchCV(cv=3, error_score=nan,\n         ...
# 7   GridSearchCV(cv=3, error_score=nan,\n         ...
# 8   GridSearchCV(cv=3, error_score=nan,\n         ...
# 9   GridSearchCV(cv=3, error_score=nan,\n         ...
# 10  GridSearchCV(cv=3, error_score=nan,\n         ...
# 11  GridSearchCV(cv=3, error_score=nan,\n         ...
# 12  GridSearchCV(cv=3, error_score=nan,\n         ...
# 13  GridSearchCV(cv=3, error_score=nan,\n         ...
# 14  GridSearchCV(cv=3, error_score=nan,\n         ...
#
#                                           best_params  count  \
# 0   {'cvec__max_df': 0.99, 'cvec__max_features': 1...   1056
# 1   {'cvec__max_df': 0.99, 'cvec__max_features': 1...    459
# 2   {'cvec__max_df': 0.99, 'cvec__max_features': 6...    356
# 3   {'cvec__max_df': 0.99, 'cvec__max_features': 1...    204
# 4   {'cvec__max_df': 0.99, 'cvec__max_features': 1...    105
# 5   {'cvec__max_df': 0.99, 'cvec__max_features': 4...     37
# 6   {'cvec__max_df': 0.99, 'cvec__max_features': 1...     77
# 7   {'cvec__max_df': 0.99, 'cvec__max_features': 2...     18
# 8   {'cvec__max_df': 0.99, 'cvec__max_features': 4...     25
# 9   {'cvec__max_df': 0.99, 'cvec__max_features': 1...     24
# 10  {'cvec__max_df': 0.99, 'cvec__max_features': 2...     19
# 11  {'cvec__max_df': 0.99, 'cvec__max_features': 1...     14
# 12  {'cvec__max_df': 0.99, 'cvec__max_features': 1...     10
# 13  {'cvec__max_df': 0.99, 'cvec__max_features': 1...      5
# 14  {'cvec__max_df': 0.99, 'cvec__max_features': 4...      9
#
#     best_crossval_score  train_score  test_score
# 0              0.970211     0.992512    0.982732
# 1              0.981793     0.991597    0.978793
# 2              0.955882     0.997899    0.954323
# 3              0.953550     1.000000    0.966667
# 4              0.965390     0.993197    0.918033
# 5              0.885714     1.000000    0.857143
# 6              0.900348     0.990826    0.878049
# 7              0.619048     1.000000    0.888889
# 8              0.902357     1.000000    0.857143
# 9              0.886364     0.969697    0.800000
# 10             0.804233     1.000000    0.500000
# 11             0.719048     1.000000    0.888889
# 12             0.444444     1.000000    0.500000
# 13             0.000000     1.000000    0.000000
# 14             0.388889     1.000000    0.000000

# %% [markdown]
# ## Plotting functions: features and confusion matrices

# %%
def coefficient_plots(results_df):
    '''
    Plots the top 10 and bottom 10 coefficients for each category
    '''
    for row in results_df.itertuples(index = True, name = 'Pandas'):
        names = getattr(row, "model_result").best_estimator_.steps[0][1].get_feature_names()
        betas = getattr(row, "model_result").best_estimator_.named_steps['lr']
        coef = np.array(betas.coef_).tolist()[0]
        top_words = list(zip(names, coef))
        df_coefs = pd.DataFrame(top_words).rename(columns = {0: 'word', 1: 'coef'}).sort_values(by = 'coef', ascending = True)
        

        coefs_1 = df_coefs.sort_values(by = 'coef', ascending=False).tail(10) # getting the top 10 coefficients
        coefs_2 = df_coefs.sort_values(by = 'coef', ascending=False).head(10) # getting the bottom 10 coefficients
        coefs = pd.concat([coefs_2, coefs_1], axis = 0) # merging the two into one
        # plotting importance
        plt.figure(figsize=(10, 8)) # plotting the coefficients
        plt.title(f'Feature Coefficients for {getattr(row,"target").replace("_", " ").title()}', fontsize=25)
        sns.set_style("darkgrid")
        sns.barplot(data=coefs,
                    x= 'coef',
                    y='word',
                    orient='h',
                    palette = 'PuBuGn_d')
        plt.xlabel('coefficient', fontsize=15)
        plt.ylabel('feature', fontsize=15)
        plt.tick_params(labelsize=15)

# %%
# Call the coefficient plot function
coefficient_plots(results_df)

# %%
def create_confusion_matrix(results_df):
    '''
    Plots the top 10 and bottom 10 coefficients for each category
    '''
    for row in results_df.itertuples(index = True, name = 'Pandas'):
        best_model = getattr(row, "model_result").best_estimator_
        preds = best_model.predict(getattr(row, "split_data")['X_test'])
        
        cm_test = confusion_matrix(getattr(row, "split_data")['y_test'], preds)
        cm_test = pd.DataFrame(cm_test, columns=['Predicted Negative','Predicted Positive'], 
                       index=['Actual Negative','Actual Positive'])
        plt.figure(figsize = (6,6))
        ax = plt.subplot()
        sns.heatmap(cm_test, 
            annot=True, 
            ax = ax, 
            fmt='g', 
            cbar=False,
            cmap="Blues"); #annot=True to annotate cells

        # labels, title and ticks
        ax.set_title(f'Confusion Matrix - {getattr(row,"target").replace("_", " ").title()}', size=16)
        ax.set_xlabel('Predicted', size=14)
        ax.set_ylabel('Actual', size=14)
        ax.xaxis.set_ticklabels(['Negative', 'Positive'])
        ax.yaxis.set_ticklabels(['Negative', 'Positive']);

# %%
create_confusion_matrix(results_df)

# %%
# To allow us to better read the Sentences
pd.set_option('display.max_colwidth', None)

# %%
results_df.reset_index(inplace = True)

# %%
def create_summary_result_table(results_df):
    
    global final_misclassified_as_true
    global final_misclassified_as_false
    
    target_list = results_df['target'].values.tolist()
    final_columns = ['prediction', 'actual'] + target_list
    
    final_misclassified_as_true = pd.DataFrame(columns = final_columns)
    final_misclassified_as_false = pd.DataFrame(columns = final_columns)

    for row in results_df.itertuples(index = True, name = 'Pandas'):
        best_model = getattr(row, "model_result").best_estimator_
        preds = best_model.predict(getattr(row, "split_data")['X_test'])
        
        index_list = list(getattr(row, "split_data")['indices_test'])
        preds_list = list(preds.astype(int))
        actuals_list = list(getattr(row, "split_data")['y_test'].astype(int))
        
        results = pd.DataFrame({'index': index_list, 'prediction': preds_list, 'actual': actuals_list})
        results.set_index('index', inplace = True)
        
        misclassified = results[results['prediction'] != results['actual']]
        misclassified = misclassified.merge(df, how = 'left', left_index = True, right_index = True)
        misclassified_as_true = misclassified.loc[misclassified['prediction'] == 1]
        misclassified_as_false = misclassified.loc[misclassified['prediction'] == 0]
        
        misclassified_as_true_summary = misclassified_as_true.drop(columns = ['Document', 'Sentence', 'SentenceTokens', 'SentenceLemmas'])
        misclassified_as_false_summary = misclassified_as_false.drop(columns = ['Document', 'Sentence', 'SentenceTokens', 'SentenceLemmas'])
        
        
        misclassified_as_true_summary.loc[f'{getattr(row, "target")}',:] = misclassified_as_true.sum(axis = 0).copy(deep = True)
        misclassified_as_false_summary.loc[f'{getattr(row, "target")}',:] = misclassified_as_false.sum(axis = 0).copy(deep = True)

        
        final_misclassified_as_true = final_misclassified_as_true.append(misclassified_as_true_summary.iloc[-1], ignore_index = False)
        final_misclassified_as_false = final_misclassified_as_false.append(misclassified_as_false_summary.iloc[-1], ignore_index = False)
        
    return final_misclassified_as_true
    return final_misclassified_as_false

# %%
create_summary_result_table(results_df)
# Out:
#                            prediction  actual nontrigger loan_default  \
# nontrigger                        7.0     0.0          0            3
# loan_default                      8.0     0.0          4            0
# unspecified                      11.0     0.0          5            3
# debt_yield_fall                   1.0     0.0          0            1
# mezzanine_default                 1.0     0.0          0            0
# tenant_failure                    1.0     0.0          0            1
# bankruptcy                        0.0     0.0          0            0
# aggregate_debt_yield_fall         0.0     0.0          0            0
# dscr_fall                         0.0     0.0          0            0
# renovations                       2.0     0.0          2            0
# operator_termination              0.0     0.0          0            0
# sponsor_termination               1.0     0.0          0            0
# mezzanine_outstanding             0.0     0.0          0            0
# aggregate_dscr_fall               0.0     0.0          0            0
# sff                               0.0     0.0          0            0
#
#                           unspecified debt_yield_fall mezzanine_default  \
# nontrigger                          0               0                 0
# loan_default                        1               0                 0
# unspecified                         0               0                 0
# debt_yield_fall                     0               0                 0
# mezzanine_default                   1               0                 0
# tenant_failure                      0               0                 0
# bankruptcy                          0               0                 0
# aggregate_debt_yield_fall           0               0                 0
# dscr_fall                           0               0                 0
# renovations                         0               0                 0
# operator_termination                0               0                 0
# sponsor_termination                 1               0                 0
# mezzanine_outstanding               0               0                 0
# aggregate_dscr_fall                 0               0                 0
# sff                                 0               0                 0
#
#                           tenant_failure bankruptcy aggregate_debt_yield_fall  \
# nontrigger                             0          0                         0
# loan_default                           2          0                         0
# unspecified                            0          0                         0
# debt_yield_fall                        0          0                         0
# mezzanine_default                      0          0                         0
# tenant_failure                         0          0                         0
# bankruptcy                             0          0                         0
# aggregate_debt_yield_fall              0          0                         0
# dscr_fall                              0          0                         0
# renovations                            0          0                         0
# operator_termination                   0          0                         0
# sponsor_termination                    0          0                         0
# mezzanine_outstanding                  0          0                         0
# aggregate_dscr_fall                    0          0                         0
# sff                                    0          0                         0
#
#                           dscr_fall renovations operator_termination  \
# nontrigger                        0           2                    1
# loan_default                      0           0                    0
# unspecified                       0           0                    2
# debt_yield_fall                   0           0                    0
# mezzanine_default                 0           0                    0
# tenant_failure                    0           0                    0
# bankruptcy                        0           0                    0
# aggregate_debt_yield_fall         0           0                    0
# dscr_fall                         0           0                    0
# renovations                       0           0                    0
# operator_termination              0           0                    0
# sponsor_termination               0           0                    0
# mezzanine_outstanding             0           0                    0
# aggregate_dscr_fall               0           0                    0
# sff                               0           0                    0
#
#                           sponsor_termination mezzanine_outstanding  \
# nontrigger                                  0                     0
# loan_default                                0                     0
# unspecified                                 0                     0
# debt_yield_fall                             0                     0
# mezzanine_default                           0                     0
# tenant_failure                              0                     0
# bankruptcy                                  0                     0
# aggregate_debt_yield_fall                   0                     0
# dscr_fall                                   0                     0
# renovations                                 0                     0
# operator_termination                        0                     0
# sponsor_termination                         0                     0
# mezzanine_outstanding                       0                     0
# aggregate_dscr_fall                         0                     0
# sff                                         0                     0
#
#                           aggregate_dscr_fall sff
# nontrigger                                  0   1
# loan_default                                0   1
# unspecified                                 0   1
# debt_yield_fall                             0   0
# mezzanine_default                           0   0
# tenant_failure                              0   0
# bankruptcy                                  0   0
# aggregate_debt_yield_fall                   0   0
# dscr_fall                                   0   0
# renovations                                 0   0
# operator_termination                        0   0
# sponsor_termination                         0   0
# mezzanine_outstanding                       0   0
# aggregate_dscr_fall                         0   0
# sff                                         0   0

# %%
results_df.set_index('target', inplace = True)

# %%
final_misclassified_as_true
# Out:
#                            prediction  actual nontrigger loan_default  \
# nontrigger                        7.0     0.0          0            3
# loan_default                      8.0     0.0          4            0
# unspecified                      11.0     0.0          5            3
# debt_yield_fall                   1.0     0.0          0            1
# mezzanine_default                 1.0     0.0          0            0
# tenant_failure                    1.0     0.0          0            1
# bankruptcy                        0.0     0.0          0            0
# aggregate_debt_yield_fall         0.0     0.0          0            0
# dscr_fall                         0.0     0.0          0            0
# renovations                       2.0     0.0          2            0
# operator_termination              0.0     0.0          0            0
# sponsor_termination               1.0     0.0          0            0
# mezzanine_outstanding             0.0     0.0          0            0
# aggregate_dscr_fall               0.0     0.0          0            0
# sff                               0.0     0.0          0            0
#
#                           unspecified debt_yield_fall mezzanine_default  \
# nontrigger                          0               0                 0
# loan_default                        1               0                 0
# unspecified                         0               0                 0
# debt_yield_fall                     0               0                 0
# mezzanine_default                   1               0                 0
# tenant_failure                      0               0                 0
# bankruptcy                          0               0                 0
# aggregate_debt_yield_fall           0               0                 0
# dscr_fall                           0               0                 0
# renovations                         0               0                 0
# operator_termination                0               0                 0
# sponsor_termination                 1               0                 0
# mezzanine_outstanding               0               0                 0
# aggregate_dscr_fall                 0               0                 0
# sff                                 0               0                 0
#
#                           tenant_failure bankruptcy aggregate_debt_yield_fall  \
# nontrigger                             0          0                         0
# loan_default                           2          0                         0
# unspecified                            0          0                         0
# debt_yield_fall                        0          0                         0
# mezzanine_default                      0          0                         0
# tenant_failure                         0          0                         0
# bankruptcy                             0          0                         0
# aggregate_debt_yield_fall              0          0                         0
# dscr_fall                              0          0                         0
# renovations                            0          0                         0
# operator_termination                   0          0                         0
# sponsor_termination                    0          0                         0
# mezzanine_outstanding                  0          0                         0
# aggregate_dscr_fall                    0          0                         0
# sff                                    0          0                         0
#
#                           dscr_fall renovations operator_termination  \
# nontrigger                        0           2                    1
# loan_default                      0           0                    0
# unspecified                       0           0                    2
# debt_yield_fall                   0           0                    0
# mezzanine_default                 0           0                    0
# tenant_failure                    0           0                    0
# bankruptcy                        0           0                    0
# aggregate_debt_yield_fall         0           0                    0
# dscr_fall                         0           0                    0
# renovations                       0           0                    0
# operator_termination              0           0                    0
# sponsor_termination               0           0                    0
# mezzanine_outstanding             0           0                    0
# aggregate_dscr_fall               0           0                    0
# sff                               0           0                    0
#
#                           sponsor_termination mezzanine_outstanding  \
# nontrigger                                  0                     0
# loan_default                                0                     0
# unspecified                                 0                     0
# debt_yield_fall                             0                     0
# mezzanine_default                           0                     0
# tenant_failure                              0                     0
# bankruptcy                                  0                     0
# aggregate_debt_yield_fall                   0                     0
# dscr_fall                                   0                     0
# renovations                                 0                     0
# operator_termination                        0                     0
# sponsor_termination                         0                     0
# mezzanine_outstanding                       0                     0
# aggregate_dscr_fall                         0                     0
# sff                                         0                     0
#
#                           aggregate_dscr_fall sff
# nontrigger                                  0   1
# loan_default                                0   1
# unspecified                                 0   1
# debt_yield_fall                             0   0
# mezzanine_default                           0   0
# tenant_failure                              0   0
# bankruptcy                                  0   0
# aggregate_debt_yield_fall                   0   0
# dscr_fall                                   0   0
# renovations                                 0   0
# operator_termination                        0   0
# sponsor_termination                         0   0
# mezzanine_outstanding                       0   0
# aggregate_dscr_fall                         0   0
# sff                                         0   0

# %%
final_misclassified_as_false = results_df[['count', 'train_score', 'test_score']].merge(final_misclassified_as_false, left_index = True, right_index = True)
final_misclassified_as_false
# Out:
#                            count  train_score  test_score  prediction  actual  \
# nontrigger                  1056     0.992512    0.982732         0.0     4.0
# loan_default                 459     0.991597    0.978793         0.0     5.0
# unspecified                  356     0.997899    0.954323         0.0    17.0
# debt_yield_fall              204     1.000000    0.966667         0.0     3.0
# mezzanine_default            105     0.993197    0.918033         0.0     4.0
# tenant_failure                37     1.000000    0.857143         0.0     2.0
# bankruptcy                    77     0.990826    0.878049         0.0     5.0
# aggregate_debt_yield_fall     18     1.000000    0.888889         0.0     1.0
# dscr_fall                     25     1.000000    0.857143         0.0     2.0
# renovations                   24     0.969697    0.800000         0.0     1.0
# operator_termination          19     1.000000    0.500000         0.0     4.0
# sponsor_termination           14     1.000000    0.888889         0.0     0.0
# mezzanine_outstanding         10     1.000000    0.500000         0.0     2.0
# aggregate_dscr_fall            5     1.000000    0.000000         0.0     2.0
# sff                            9     1.000000    0.000000         0.0     3.0
#
#                           nontrigger loan_default unspecified debt_yield_fall  \
# nontrigger                         4            0           0               0
# loan_default                       0            5           0               2
# unspecified                        0            0          17               0
# debt_yield_fall                    0            2           0               3
# mezzanine_default                  0            4           0               3
# tenant_failure                     0            2           0               1
# bankruptcy                         0            5           0               4
# aggregate_debt_yield_fall          0            0           0               1
# dscr_fall                          0            1           0               0
# renovations                        0            1           0               1
# operator_termination               1            1           0               1
# sponsor_termination                0            0           0               0
# mezzanine_outstanding              0            0           0               0
# aggregate_dscr_fall                0            2           0               0
# sff                                0            1           0               1
#
#                           mezzanine_default tenant_failure bankruptcy  \
# nontrigger                                0              0          0
# loan_default                              2              2          0
# unspecified                               0              0          0
# debt_yield_fall                           1              0          0
# mezzanine_default                         4              0          0
# tenant_failure                            1              2          0
# bankruptcy                                0              0          5
# aggregate_debt_yield_fall                 0              0          0
# dscr_fall                                 1              0          1
# renovations                               0              0          1
# operator_termination                      1              1          0
# sponsor_termination                       0              0          0
# mezzanine_outstanding                     0              0          0
# aggregate_dscr_fall                       0              0          2
# sff                                       1              1          0
#
#                           aggregate_debt_yield_fall dscr_fall renovations  \
# nontrigger                                        0         0           0
# loan_default                                      0         0           0
# unspecified                                       0         0           0
# debt_yield_fall                                   0         0           0
# mezzanine_default                                 1         0           0
# tenant_failure                                    0         0           0
# bankruptcy                                        0         0           1
# aggregate_debt_yield_fall                         1         0           0
# dscr_fall                                         0         2           0
# renovations                                       0         0           1
# operator_termination                              0         0           0
# sponsor_termination                               0         0           0
# mezzanine_outstanding                             0         0           0
# aggregate_dscr_fall                               0         0           0
# sff                                               0         0           0
#
#                           operator_termination sponsor_termination  \
# nontrigger                                   0                   0
# loan_default                                 0                   0
# unspecified                                  0                   0
# debt_yield_fall                              0                   0
# mezzanine_default                            0                   0
# tenant_failure                               1                   0
# bankruptcy                                   0                   0
# aggregate_debt_yield_fall                    0                   0
# dscr_fall                                    0                   0
# renovations                                  0                   0
# operator_termination                         4                   0
# sponsor_termination                          0                   0
# mezzanine_outstanding                        0                   0
# aggregate_dscr_fall                          0                   0
# sff                                          1                   0
#
#                           mezzanine_outstanding aggregate_dscr_fall sff
# nontrigger                                    0                   0   0
# loan_default                                  0                   0   0
# unspecified                                   0                   0   0
# debt_yield_fall                               0                   0   2
# mezzanine_default                             0                   0   1
# tenant_failure                                0                   0   1
# bankruptcy                                    0                   1   0
# aggregate_debt_yield_fall                     0                   0   0
# dscr_fall                                     0                   0   0
# renovations                                   0                   0   0
# operator_termination                          1                   0   1
# sponsor_termination                           0                   0   0
# mezzanine_outstanding                         2                   0   0
# aggregate_dscr_fall                           0                   2   0
# sff                                           0                   0   3

# %%
final_misclassified_as_true = results_df[['count', 'train_score', 'test_score']].merge(final_misclassified_as_true, left_index = True, right_index = True)
final_misclassified_as_true
# Out:
#                            count  train_score  test_score  prediction  actual  \
# nontrigger                  1056     0.992512    0.982732         7.0     0.0
# loan_default                 459     0.991597    0.978793         8.0     0.0
# unspecified                  356     0.997899    0.954323        11.0     0.0
# debt_yield_fall              204     1.000000    0.966667         1.0     0.0
# mezzanine_default            105     0.993197    0.918033         1.0     0.0
# tenant_failure                37     1.000000    0.857143         1.0     0.0
# bankruptcy                    77     0.990826    0.878049         0.0     0.0
# aggregate_debt_yield_fall     18     1.000000    0.888889         0.0     0.0
# dscr_fall                     25     1.000000    0.857143         0.0     0.0
# renovations                   24     0.969697    0.800000         2.0     0.0
# operator_termination          19     1.000000    0.500000         0.0     0.0
# sponsor_termination           14     1.000000    0.888889         1.0     0.0
# mezzanine_outstanding         10     1.000000    0.500000         0.0     0.0
# aggregate_dscr_fall            5     1.000000    0.000000         0.0     0.0
# sff                            9     1.000000    0.000000         0.0     0.0
#
#                           nontrigger loan_default unspecified debt_yield_fall  \
# nontrigger                         0            3           0               0
# loan_default                       4            0           1               0
# unspecified                        5            3           0               0
# debt_yield_fall                    0            1           0               0
# mezzanine_default                  0            0           1               0
# tenant_failure                     0            1           0               0
# bankruptcy                         0            0           0               0
# aggregate_debt_yield_fall          0            0           0               0
# dscr_fall                          0            0           0               0
# renovations                        2            0           0               0
# operator_termination               0            0           0               0
# sponsor_termination                0            0           1               0
# mezzanine_outstanding              0            0           0               0
# aggregate_dscr_fall                0            0           0               0
# sff                                0            0           0               0
#
#                           mezzanine_default tenant_failure bankruptcy  \
# nontrigger                                0              0          0
# loan_default                              0              2          0
# unspecified                               0              0          0
# debt_yield_fall                           0              0          0
# mezzanine_default                         0              0          0
# tenant_failure                            0              0          0
# bankruptcy                                0              0          0
# aggregate_debt_yield_fall                 0              0          0
# dscr_fall                                 0              0          0
# renovations                               0              0          0
# operator_termination                      0              0          0
# sponsor_termination                       0              0          0
# mezzanine_outstanding                     0              0          0
# aggregate_dscr_fall                       0              0          0
# sff                                       0              0          0
#
#                           aggregate_debt_yield_fall dscr_fall renovations  \
# nontrigger                                        0         0           2
# loan_default                                      0         0           0
# unspecified                                       0         0           0
# debt_yield_fall                                   0         0           0
# mezzanine_default                                 0         0           0
# tenant_failure                                    0         0           0
# bankruptcy                                        0         0           0
# aggregate_debt_yield_fall                         0         0           0
# dscr_fall                                         0         0           0
# renovations                                       0         0           0
# operator_termination                              0         0           0
# sponsor_termination                               0         0           0
# mezzanine_outstanding                             0         0           0
# aggregate_dscr_fall                               0         0           0
# sff                                               0         0           0
#
#                           operator_termination sponsor_termination  \
# nontrigger                                   1                   0
# loan_default                                 0                   0
# unspecified                                  2                   0
# debt_yield_fall                              0                   0
# mezzanine_default                            0                   0
# tenant_failure                               0                   0
# bankruptcy                                   0                   0
# aggregate_debt_yield_fall                    0                   0
# dscr_fall                                    0                   0
# renovations                                  0                   0
# operator_termination                         0                   0
# sponsor_termination                          0                   0
# mezzanine_outstanding                        0                   0
# aggregate_dscr_fall                          0                   0
# sff                                          0                   0
#
#                           mezzanine_outstanding aggregate_dscr_fall sff
# nontrigger                                    0                   0   1
# loan_default                                  0                   0   1
# unspecified                                   0                   0   1
# debt_yield_fall                               0                   0   0
# mezzanine_default                             0                   0   0
# tenant_failure                                0                   0   0
# bankruptcy                                    0                   0   0
# aggregate_debt_yield_fall                     0                   0   0
# dscr_fall                                     0                   0   0
# renovations                                   0                   0   0
# operator_termination                          0                   0   0
# sponsor_termination                           0                   0   0
# mezzanine_outstanding                         0                   0   0
# aggregate_dscr_fall                           0                   0   0
# sff                                           0                   0   0

# %% [markdown]
# ## BREAK: OLD CODE BELOW

# %% [markdown]
# ## Import Data

# %%
# Import the CSV file
# raw_df = pd.read_csv('../data/sasb_cash_trap_triggers.csv')

# %%
# Import the CSV file
raw_df = pd.read_csv('../data/sasb_cash_trap_triggers_06_04_20.csv')

# %%
# Review the first few rows of the data set
raw_df.head()

# %%
# Check size of the data set
raw_df.shape

# %%
raw_df = raw_df[['Document', 'Sentence', 'Trigger', 'Multiclass']]

# %%
# Check for null values
raw_df.isnull().sum()

# %%
raw_df.dropna()
raw_df.shape

# %%
raw_df.head()

# %% [markdown]
# ## Data Cleaning

# %%
# Review number of Trigger types
raw_df['Trigger'].value_counts()

# %%
# Convert each category to Title format (to remove discrepancies based on capitalization)
raw_df['Trigger'] = raw_df['Trigger'].str.title()

# %%
# Some data fixes
raw_df['Trigger'] = raw_df['Trigger'].str.replace('Falll', 'Fall')
raw_df.loc[raw_df['Trigger'] == 'Aggregate Debt Yield', 'Trigger'] = 'Aggregate Debt Yield Fall'

# %%
# Some dollar sign symbols are causing problems - will remove them here
raw_df['Sentence'] = raw_df['Sentence'].replace({'\$':''}, regex = True)

# %%
# Review clean Trigger Types
raw_df['Trigger'].value_counts()

# %%
# Drop Multiclass column since it isn't needed
raw_df = raw_df.drop('Multiclass', axis = 1)
raw_df.head()

# %%
raw_df.shape

# %%
# Count the number of distinct documents
num_docs = raw_df['Document'].nunique()
print(f'{num_docs} unique documents have been included in the data set')

# %%
# Review the distinct documents and the number of Trigger events identified for each
raw_df['Document'].value_counts()

# %%
# Summarize the trigger counts for the existing Document set
max_triggers = raw_df['Document'].value_counts().max()
min_triggers = raw_df['Document'].value_counts().min()
print(f'The {num_docs} Documents have tag counts that range from {min_triggers} to {max_triggers}.')

# %%
raw_df.head()

# %%
# Review new number of Trigger types
raw_df['Trigger'].value_counts()

# %%
trigger_order = raw_df['Trigger'].value_counts().sort_values(ascending = False).index

fig = plt.gcf()
fig.set_size_inches(8, 8)
ax = sns.countplot(y=raw_df['Trigger'], data=raw_df, orient = 'h', order = trigger_order)
ax.set_title('Number of Trigger Types');

for p in ax.patches:
    ax.annotate(int(p.get_width()),((p.get_x() + p.get_width()), p.get_y()), xytext=(17, -15),fontsize=9,textcoords='offset points', horizontalalignment='right')
    
#https://stackoverflow.com/questions/50190409/how-to-annotate-horizontal-seaborn-countplots

# %%
# Review new distinct documents and the number of Trigger events identified for each
raw_df['Document'].value_counts()

# %%
raw_df.dtypes

# %% [markdown]
# ## Reshape the Data

# %% [markdown]
# In this section, we'll reshape the data, such that each sentence is represented once, with separate categorization columns for each Trigger type

# %%
# Reshape our original dataframe
df = reshape_trigger_representation(raw_df)

# %%
df.head(5)

# %%
# Export reshaped to CSV file
#df.to_csv('../data/reshaped_06_04_20.csv')

# %%
# Create list of tag types (for later modeling)
trigger_list = list(df.columns)
trigger_list

# %%
if 'Document' in trigger_list: trigger_list.remove('Document')
if 'Sentence' in trigger_list: trigger_list.remove('Sentence')
trigger_list

# %%
# Create a dataframe showing the document tagging details (removing sentence details)
doc_view = df.groupby('Document').sum()

# %%
doc_view.T

# %%
number_tag_types = doc_view.astype(bool).sum(axis=1)
number_tag_types

# %%
print(f'The number of tags per document ranges from {number_tag_types.min()} to {number_tag_types.max()}.')

# %%
# Create a sum column
doc_view['sum'] = doc_view.sum(axis = 1)
doc_view

# %%
# Export reshaped to CSV file
#doc_view.to_csv('../data/doc_view_06_04_20.csv')

# %%
# Isolate documents that don't have any Trigger tags (only nontriggers)
no_trigger_tags = list(doc_view.loc[doc_view['sum'] == doc_view['nontrigger']].index)
no_trigger_tags # Save document names to a list

# %%
# we will remove any documents that have 0 Cash Trap Trigger clauses within the data set

to_remove = df[df['Document'].isin(no_trigger_tags)]
df = df.drop(to_remove.index)

# %%
doc_view.T

# %% [markdown]
# ## Natural Language Processing / Feature Engineering

# %%
# Create a column with length of Sentence
df['sentence_char_count'] = df['Sentence'].str.len()

# %%
df.head()

# %%
nlp = spacy.load('en_core_web_sm', disable = ['ner', 'parser'])

# %%
# Review a tokenized sample Sentence
[token.text for token in nlp(df['Sentence'][2])]

# %%
# Review a lemmatized sample Sentence
[token.lemma_ for token in nlp(df['Sentence'][2])]

# %%
def tokenize(text):
    doc = nlp(text)
    tokens = [token.text for token in doc]
    return ' '.join(tokens)

df['SentenceTokens'] = df['Sentence'].apply(tokenize)

# %%
def lemmatize(text):
    doc = nlp(text)
    lemmas = [token.lemma_ for token in doc]
    return ' '.join(lemmas)

df['SentenceLemmas'] = df['Sentence'].apply(lemmatize)

# %%
df.head()

# %%
# Put all sentences into a list of review tokens
all_sentence_tokens = ' '.join(df['SentenceTokens'])
all_sentence_tokens[:75]

# %%
# Put all sentences into a list of review lemmas
all_sentence_lemmas = ' '.join(df['SentenceLemmas'])
all_sentence_lemmas[:75]

# %%
sentence_token_list = [token for token in all_sentence_tokens.split(' ')]
sentence_lemma_list = [lemma for lemma in all_sentence_lemmas.split(' ')]

# %%
token_df = pd.Series(sentence_token_list)
lemma_df = pd.Series(sentence_lemma_list)

# %%
# Plotting the raw token count
token_series = token_df.value_counts().head(15).sort_values(ascending = True)
ax = token_series.plot.barh(figsize = (6,6))
ax.set_xlabel('count')
ax.set_ylabel('token')
ax.set_title('Sentences: Raw Token Count');

# %%
# Plotting the raw lemma count
lemma_series = lemma_df.value_counts().head(15).sort_values(ascending = True)
ax = lemma_series.plot.barh(figsize = (6,6))
ax.set_xlabel('count')
ax.set_ylabel('lemma')
ax.set_title('Sentences: Raw Lemma Count');

# %%
# Remove punctuation, maintain letters and numbers
df['SentenceLemmas_nopunc'] = df['SentenceLemmas'].str.replace("[^a-zA-Z0-9#']", " ")

# %%
# Put all SentenceLemmas_nopunc into a list
all_lemmas_nopunc = ' '.join(df['SentenceLemmas_nopunc'])
lemma_list_nopunc = [lemma for lemma in all_lemmas_nopunc.split(' ')]
lemma_list_nopunc = [lemma for lemma in lemma_list_nopunc if lemma not in ['']]
lemma_list_nopunc[:10]

# %%
# Create a data series containing the list of words
lemma_df_nopunc = pd.Series(lemma_list_nopunc)
lemma_series_nopunc = lemma_df_nopunc.value_counts().head(15).sort_values(ascending = True)
ax = lemma_series_nopunc.plot.barh(figsize = (6,6))
ax.set_xlabel('count')
ax.set_ylabel('lemma')
ax.set_title('Sentences: Lemma Count, no punctuation');

# %%
df['SentenceLemmas_nopunc'].head()

# %%
df['SentenceLemmas_nopunc'] = df['SentenceLemmas_nopunc'].str.replace('\s{2,}', ' ')

# %%
df['SentenceLemmas_nopunc'].head()

# %% [markdown]
# ## Preprocessing and Preparation for Modeling

# %%
short_stopwords = ['the', 'to', 'of', 'be', 'and', 'in', 'a']
short_stopwords2 = ['the', 'and', 'a', 'to', 'it', 'be', 'for', 'with', 'that']

# %%
# Look at original stopword list
stopwords = list(STOP_WORDS)
stopwords

# %% [markdown]
# ## Train/Test Split

# %%
df.head()

# %%
# Check our previously defined trigger list
trigger_list

# %%
def prepare_train_test_split(dataframe_sentence_column, trigger_list):
    for trigger_type in trigger_list:
        target = trigger_type
        X = dataframe_sentence_column
        y=df[target]
        indices = df.index
        y = y.astype('int')
        X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(X, y, indices, test_size = 0.3, stratify = y, random_state = RANDOM_STATE)

# %%
# Start by predicting Loan Default trigger

#target = 'loan_default'


#X = df['Sentence']
#y = df[target]
#indices = df.index

#y = y.astype('int')

# %%
#y.dtypes

# %%
# Checking shape of X and y 
#print(f'X shape is {X.shape}')
#print(f'y shape is {y.shape}')

# %%
#y.value_counts()

# %%
#X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(X, y, indices, test_size = 0.3, stratify = y, random_state = RANDOM_STATE)
#print(X_train.shape, y_train.shape)
#print(X_test.shape, y_test.shape)
#print(indices_train.shape, indices_test.shape)

# %%
#X.head()

# %%
#X_train.shape[0]

# %%
#y_train.shape[0]

# %% [markdown]
# ## Modeling

# %%
def modeling_function(target):
    pipe_cvec_lr = Pipeline([('cvec', CountVectorizer()), ('lr', LogisticRegression(solver = 'liblinear', random_state = RANDOM_STATE))])
    lr_params = {
        'lr__ngram_range': [(1,2), (1,3), (1,4), (1,5), (1,6), (1,7), (1,8)],
        'lr__stop_words': [None, short_stopwords, short_stopwords2, stopwords],  
        'lr__max_features': [100, 200, 400, 600, 1000],
        'lr__min_df': [2],
        'lr__max_df': [.99],
        }

    gs_lr = GridSearchCV(pipe_cvec_lr, param_grid = lr_params, cv = 3, scoring = 'f1')

    # Start the timer.
    t0 = time.time()

    results_lr = gs_lr.fit(X_train, y_train)

    print(f'Seconds elapsed for fitting: {(time.time() - t0):.3f}') # How many seconds elapsed.

# %% [markdown]
# ### CountVectorizer + Logistic Regression GridSearch and modeling

# %%
# Define CVEC + Logistic Regression Pipeline
pipe_cvec = Pipeline([('cvec', CountVectorizer()), ('lr', LogisticRegression(solver = 'liblinear', random_state = RANDOM_STATE))])
cvec_params = {
    'cvec__ngram_range': [(1,2), (1,3), (1,4), (1,5), (1,6), (1,7), (1,8)],
    'cvec__stop_words': [None, short_stopwords, short_stopwords2, stopwords],  
    'cvec__max_features': [100, 200, 400, 600, 1000],
    'cvec__min_df': [2],
    'cvec__max_df': [.99],
    }

gs_cvec = GridSearchCV(pipe_cvec, param_grid = cvec_params, cv = 3, scoring = 'f1')

# Start the timer.
t0 = time.time()

results_cvec = gs_cvec.fit(X_train, y_train)

print(f'Seconds elapsed for fitting: {(time.time() - t0):.3f}') # How many seconds elapsed.

# %%
t0 = time.time()
print(f'Training score is {results_cvec.score(X_train, y_train):.3f}')
print(f'Test score is {results_cvec.score(X_test, y_test):.3f}')
print(f'Cross Validation score is {cross_val_score(results_cvec.best_estimator_, X, y, cv = 3).mean():.3f}')
print(f'Seconds elapsed for score calculation: {(time.time() - t0):.3f}') # How many seconds elapsed.

# %%
print(f'Best Score:{(results_cvec.best_score_):.3f}')
print(f'Best Parameters :{results_cvec.best_params_}')

# %% [markdown]
# ### 5: CountVectorizor + Random Forest

# %%
'''
# Define CVEC + Logistic Regression Pipeline
pipe_rf = Pipeline([('cvec', CountVectorizer()), ('rf', RandomForestClassifier(random_state = RANDOM_STATE, n_jobs = 2))])
rf_params = {
    'cvec__ngram_range': [(1,2), (1,3), (1,4), (1,5)],
    'cvec__stop_words': [None, short_stopwords, short_stopwords2],  
    'cvec__max_features': [100, 200, 400, 800],
    'cvec__min_df': [2],
    'cvec__max_df': [.99],
    'rf__max_depth': [4,5, 6],
    'rf__min_samples_split': [2,3],
    'rf__min_samples_leaf': [10, 12]
    }

gs_rf = GridSearchCV(pipe_rf, param_grid = rf_params, cv = 3, scoring = 'f1')

# Start the timer.
t0 = time.time()

results_rf = gs_rf.fit(X_train, y_train)

print(f'Seconds elapsed for fitting: {(time.time() - t0):.3f}') # How many seconds elapsed.

'''

# %%
'''
t0 = time.time()
print(f'Training score is {results_rf.score(X_train, y_train):.3f}')
print(f'Test score is {results_rf.score(X_test, y_test):.3f}')
print(f'Cross Validation score is {cross_val_score(results_rf.best_estimator_, X, y, cv = 3).mean():.3f}')
print(f'Seconds elapsed for score calculation: {(time.time() - t0):.3f}') # How many seconds elapsed.
'''

# %%
'''
print(f'Best Score: {results_rf.best_score_}')
print(f'Best Parameters: {results_rf.best_params_}')
'''

# %% [markdown]
# ## Model Selection
# - In this section we compare the Train and Test scores across the various models

# %%
# Check Training Scores across all models
print(f'Baseline Score:                                {y_test.value_counts(normalize=True)[0]:.3f}')
print(f'CountVectorizer + LogisticRegression Accuracy: {results_cvec.score(X_train, y_train):.3f}')
# print(f'CountVectorizer + Random Forest Accuracy:      {results_rf.score(X_train, y_train):.3f}')

# %%
# Check Testing Scores across all models
print(f'Baseline Score:                                {y_test.value_counts(normalize=True)[0]:.3f}')
print(f'CountVectorizer + LogisticRegression Accuracy: {results_cvec.score(X_test, y_test):.3f}')
# print(f'CountVectorizer + Random Forest Accuracy:      {results_rf.score(X_test, y_test):.3f}')

# %% [markdown]
# ## Model Evaluation - Logistic Regression

# %%
# Isolate the individual words and their coefficients
# Feature names (i.e., words in the Sentences):
names = results_cvec.best_estimator_.steps[0][1].get_feature_names()

# classifier (betas):
classifier = results_cvec.best_estimator_.named_steps['lr']

# https://stackoverflow.com/questions/43856280/return-coefficients-from-pipeline-object-in-sklearn

# %%
# Extract coefficients from the classifier defined above
coef_cvec = np.array(classifier.coef_).tolist()[0]
coef_cvec[:10] #Look at 10 coefficients

# %%
# Create zipped list of the word names with their corresponding beta coefficients
cvec_top_words = list(zip(names, coef_cvec))

# %%
# Create final dataframe of words with their corresponding coefficients
df_cvec_coefs = pd.DataFrame(cvec_top_words).rename(columns = {0: 'word', 1: 'coef'}).sort_values(by = 'coef', ascending = True)

# %%
# Top differentiating words and phrases for this Trigger type
df_cvec_coefs.tail(20).sort_values('coef', ascending = False)

# %%
# Display top opposing words and phrases for this Trigger type
df_cvec_coefs.head(20)

# %%
def coef_plot(category):
    '''
    Plots the top 10 and bottom 10 coefficients for the complexity category specified
    '''
    coefs_1 = df_cvec_coefs.sort_values(by=category, ascending=False).tail(10) # getting the top 10 coefficients
    coefs_2 = df_cvec_coefs.sort_values(by=category, ascending=False).head(10) # getting the bottom 10 coefficients
    coefs = pd.concat([coefs_2, coefs_1], axis = 0) # merging the two into one
    # plotting importance
    plt.figure(figsize=(10, 8)) # plotting the coefficients
    plt.title(f'Feature Coefficients for {target.replace("_", " ").title()}', fontsize=25)
    sns.set_style("darkgrid")
    sns.barplot(data=coefs,
                x=category,
                y='word',
                orient='h',
                palette = 'PuBuGn_d')
    plt.xlabel('coefficient', fontsize=15)
    plt.ylabel('feature', fontsize=15)
    plt.tick_params(labelsize=15)
coef_plot('coef')

# %% [markdown]
# ## Calculating predictions and Confusion Matrix

# %%
# Here, we isolate our best model & make predictions based on our test data
best_model = results_cvec.best_estimator_
preds = best_model.predict(X_test)

# %%
# Checking our predictions
preds[:10]

# %%
## Create a confusion matrix

cm_test = confusion_matrix(y_test, preds)
print('This is a confusion matrix for our test data vs predictions:')
print(cm_test)

# %%
# Converting our confusion matrix into a dataframe
cm_test = pd.DataFrame(cm_test, columns=['Predicted Negative','Predicted Positive'], 
                       index=['Actual Negative','Actual Positive'])

# %%
cm_test

# %%
# Plot our confusion matrix
plt.figure(figsize = (6,6))
ax = plt.subplot()
sns.heatmap(cm_test, 
            annot=True, 
            ax = ax, 
            fmt='g', 
            cbar=False,
            cmap="Blues"); #annot=True to annotate cells

# labels, title and ticks
ax.set_title('Confusion Matrix - Trigger Prediction', size=16)
ax.set_xlabel('Predicted', size=14)
ax.set_ylabel('Actual', size=14)
ax.xaxis.set_ticklabels(['Negative', 'Positive'])
ax.yaxis.set_ticklabels(['Negative', 'Positive']);

# %%
# Setting up probabilities for the ROC curve
pred_proba = results_cvec.predict_proba(X_test)
preds = results_cvec.predict(X_test)

# %%
fpr, tpr, _= roc_curve(y_test, pred_proba[:,1])
roc_auc = auc(fpr, tpr)
# Plot of a ROC curve for a specific class
plt.figure(figsize = (8,8))
plt.plot(fpr, tpr, label='ROC curve (area = %0.4f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--', label='baseline')
plt.xlim([-0.01, 1.0])
plt.ylim([0.0, 1.01])
plt.xlabel('False Positive Rate', fontsize =20)
plt.ylabel('True Positive Rate', fontsize = 20)
plt.title('Receiver Operating Characteristic Curve', fontsize=18)
plt.legend(loc="lower right");

# %%
# To allow us to better read the Sentences
pd.set_option('display.max_colwidth', None)

# %%
result_cols = ['index', 'prediction', 'actual', 'model_input']
results = pd.DataFrame({'index': list(indices_test),'prediction': list(preds), 'actual': list(y_test), 'model_input': list(X_test)})

# %%
# set index as index column
results.set_index('index', inplace = True)
results.head()

# %%
misclassified = results[results['prediction'] != results['actual']]

# %%
misclassified = misclassified.merge(df, how = 'left', left_index = True, right_index = True)

# %%
misclassified = misclassified[['prediction', 'actual', 'model_input', 'Document', 'Sentence',
       'loan_default', 'aggregate_dscr_fall', 'dscr_fall', 'unspecified',
       'debt_yield_fall', 'aggregate_debt_yield_fall', 'mezzanine_default',
       'tenant_failure', 'mezzanine_outstanding', 'operator_termination',
       'bankruptcy', 'sponsor_termination', 'renovations', 'nontrigger']]

# %%
misclassified.head()

# %%
# misclassified['prediction'].astype('Int64')
# misclassified['actual'].astype('Int64')

# %%
print(f'We incorrectly predicted the trigger type for {misclassified.shape[0]} sentences.')

# %%
# Show the split of the misclassified predictions
misclassified['prediction'].value_counts()

# %% [markdown]
# ## Review the Incorrect Predictions

# %% [markdown]
# ### Misclassifications: wrongly predicted to be the trigger category

# %%
misclassified_as_true = misclassified.loc[misclassified['prediction'] == 1]
misclassified_as_true

# %%
misclassified_as_true_summary = misclassified_as_true[['prediction', 'actual', 'loan_default', 'aggregate_dscr_fall', 'dscr_fall', 'unspecified',
       'debt_yield_fall', 'aggregate_debt_yield_fall', 'mezzanine_default',
       'tenant_failure', 'mezzanine_outstanding', 'operator_termination',
       'bankruptcy', 'sponsor_termination', 'renovations', 'nontrigger']]

# %%
misclassified_as_true_count = misclassified_as_true_summary.shape[0]
print(f'{misclassified_as_true_count} sentences were predicted to be the trigger category, but in fact were not this category.')

# %%
misclassified_as_true_summary.loc[f'{target}_sum',:] = misclassified_as_true.sum(axis = 0).copy(deep = True)

# %%
misclassified_as_true_summary

# %% [markdown]
# ### Misclassifications: wrongly predicted NOT to be the trigger category

# %%
misclassified_as_false = misclassified.loc[misclassified['prediction'] == 0]
misclassified_as_false

# %%
misclassified_as_false_summary = misclassified_as_false[['prediction', 'actual', 'loan_default', 'aggregate_dscr_fall', 'dscr_fall', 'unspecified',
       'debt_yield_fall', 'aggregate_debt_yield_fall', 'mezzanine_default',
       'tenant_failure', 'mezzanine_outstanding', 'operator_termination',
       'bankruptcy', 'sponsor_termination', 'renovations', 'nontrigger']]

# %%
misclassified_as_false_count = misclassified_as_false.shape[0]
print(f'{misclassified_as_false_count} sentences were predicted not to be the trigger category, but in fact were this trigger category.')

# %%
misclassified_as_false_summary.loc[f'{target}_sum',:] = misclassified_as_false.sum(axis = 0).copy(deep = True)
misclassified_as_false_summary

# %% [markdown]
# ### Export Misclassification summaries

# %%
# Export to CSV file
#misclassified_as_false_summary.to_csv(f'../data/misclassified/{target}_misclassified_as_false_06_04_20.csv')
#misclassified_as_true_summary.to_csv(f'../data/misclassified/{target}_misclassified_as_true_06_04_20.csv')
