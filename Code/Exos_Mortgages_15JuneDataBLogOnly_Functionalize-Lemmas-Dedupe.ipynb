# %% [markdown]
# # Claira Project: Mortgage Contracts

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
import string
import numpy as np
import gzip
import seaborn as sns
np.random.seed(99)
RANDOM_STATE = 99
import datetime
pd.set_option('display.max_rows', 151)
pd.set_option('display.max_columns', 30)


# Import vectorizing and modeling tools in preparation for modeling steps
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.feature_extraction import text, stop_words
from sklearn.naive_bayes import MultinomialNB, GaussianNB, BernoulliNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
import time
import pickle

from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer

import spacy
import en_core_web_lg
from spacy.lang.en import English
from spacy.lang.en.stop_words import STOP_WORDS
nlp = spacy.load('en_core_web_lg', disable = 'parser')

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, cross_val_predict
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import roc_curve, auc

# Import CountVectorizer and TFIDFVectorizer from feature_extraction.text.
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
# Out:
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_extraction.stop_words module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_extraction.text. Anything that cannot be imported from sklearn.feature_extraction.text is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## Define sub-functions

# %%
# printing functions
def explore_data_cleaning(raw_df):
    trigger_order = raw_df['Trigger'].value_counts().sort_values(ascending = False).index

    fig = plt.gcf()
    fig.set_size_inches(8, 8)
    ax = sns.countplot(y=raw_df['Trigger'], data=raw_df, orient = 'h', order = trigger_order)
    ax.set_title('Number of Trigger Types');

    for p in ax.patches:
        ax.annotate(int(p.get_width()),((p.get_x() + p.get_width()), p.get_y()), xytext=(17, -15),fontsize=9,textcoords='offset points', horizontalalignment='right')

    #https://stackoverflow.com/questions/50190409/how-to-annotate-horizontal-seaborn-countplots
    return

# %%
# function to get data 
def get_data():
    # Import the CSV file
    raw_df = pd.read_csv('../data/sasb_cash_trap_triggers_06_15_20.csv', encoding='latin-1')
    raw_df = raw_df.dropna(how='all')
    return raw_df

# function to clean data
def clean_data(raw_df, print_fns=False):
    # project out extra columns
    raw_df = raw_df[['Document', 'Sentence', 'Trigger', 'Multiclass']]
    
    # Convert each category to Title format (to remove discrepancies based on capitalization)
    raw_df['Trigger'] = raw_df['Trigger'].str.title()

    # Some data fixes
    raw_df['Trigger'] = raw_df['Trigger'].str.replace('Falll', 'Fall')
    raw_df.loc[raw_df['Trigger'] == 'Aggregate Debt Yield', 'Trigger'] = 'Aggregate Debt Yield Fall'

    # Some dollar sign symbols are causing problems - will remove them here
    raw_df['Sentence'] = raw_df['Sentence'].replace({'\$':''}, regex = True)

    # Drop Multiclass column since it isn't needed
    raw_df = raw_df.drop('Multiclass', axis = 1)
    
    # Count the number of distinct documents
    num_docs = raw_df['Document'].nunique()
    print(f'{num_docs} unique documents have been included in the data set')
    
    # Summarize the trigger counts for the existing Document set
    max_triggers = raw_df['Document'].value_counts().max()
    min_triggers = raw_df['Document'].value_counts().min()
    print(f'The {num_docs} Documents have tag counts that range from {min_triggers} to {max_triggers}.')

    # run the extra code that analyzes the data
    if print_fns:
        explore_data_cleaning(raw_df)
        
    return raw_df

# %%
# function to reshape the dataframe such that the triggers are 0/1 columns. Remove duplicates
def reshape_trigger_representation(dataframe):
    # select trigger types
    trigger_types = list(dataframe['Trigger'].unique())
    trigger_types = [x for x in trigger_types if str(x) != 'nan']

    # create new dataframe with unique document-sentence pairs (no duplicates)
    reshaped = dataframe.drop('Trigger', axis = 1).drop_duplicates().reset_index().drop('index', axis = 1)

    # select rows by trigger, reassign as 1 or 0 (for True or False)
    for tt in trigger_types:
        # select part that is trigger_type
        temp = dataframe.loc[dataframe['Trigger'] == tt].copy()

        # create a new column of true with trigger name
        temp[tt.lower().replace(' ', '_')] = np.int64(1)
        temp.drop('Trigger', axis=1, inplace=True)
        temp[tt.lower().replace(' ', '_')] = temp[tt.lower().replace(' ', '_')].astype('Int64')

        # left join this adjusted column to the unique data
        reshaped = reshaped.merge(temp, how='left', left_on=['Document', 'Sentence'], right_on=['Document', 'Sentence'])
        reshaped = reshaped.drop_duplicates().reset_index().drop('index', axis = 1)
        
    # replace nulls with False
    reshaped = reshaped.fillna(0)  
    
    return reshaped

# %%
# Shall we create doc view and remove the extraneous document without tags?

# %%
def tokenize(text):
    doc = nlp(text)
    tokens = [token.text for token in doc]
    return ' '.join(tokens)

# %%
def lemmatize(text):
    doc = nlp(text)
    lemmas = [token.lemma_ for token in doc]
    return ' '.join(lemmas)

# %%
# NLP processing the sentence columns to prep for models
def tokenize_sentences(dataframe):
    print('Tokenizing the input sentences...')
    dataframe['SentenceTokens'] = dataframe['Sentence'].apply(tokenize).str.replace("[^a-zA-Z0-9#']", " ").str.replace('\s{2,}', ' ')
    dataframe['SentenceLemmas'] = dataframe['Sentence'].apply(lemmatize).str.replace("[^a-zA-Z0-9#']", " ").str.replace('\s{2,}', ' ')
    print(f"{len(dataframe['Sentence'])} sentences have been tokenized and lemmatized.")
    print("\n")
    return dataframe

# %%
# Incorporate Stopwords
def get_stopwords():
    # might need space
    short_stopwords = ['the', 'to', 'of', 'be', 'and', 'in', 'a', 'marriott']
    short_stopwords2 = ['the', 'and', 'a', 'to', 'it', 'be', 'for', 'with', 'that', 'marriott']
    stopwords = list(STOP_WORDS) + ['marriott']

    return short_stopwords, short_stopwords2, stopwords

# %%
# function to split data for each target column (trigger type)
def get_split_data(df, target_info):
    # extract target name
    target = target_info['target']
    model_input  = target_info['model_input']
    
    # create X, Y
    X = df[model_input]
    y = df[target]
    indices = df.index

    print(f"Number of distinct labeled document/sentence combinations within the full data set: {y.value_counts()[1]}")   
    
    y = y.astype('int')

    # run test, train split
    X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(X, y, indices, test_size = 0.3, stratify = y, random_state = RANDOM_STATE)

    
    # create output dictionary
    split_data = {}
    split_data['X_train'] = X_train
    split_data['X_test'] = X_test
    split_data['y_train'] = y_train
    split_data['y_test'] = y_test
    split_data['indices_train'] = indices_train
    split_data['indices_test'] = indices_test
    
    return split_data

# %%
# run the model with the chosen model and metric
def run_model(split_data, target_info):

    # get stopwords
    short_stopwords, short_stopwords2, stopwords = get_stopwords()
    
    # set pipeline according to the selected model:
    if target_info['model'] == 'lr':
        # Define CVEC + Logistic Regression Pipeline
        pipe = Pipeline([('cvec', CountVectorizer()), ('lr', LogisticRegression(solver = 'liblinear', random_state = RANDOM_STATE))])
        params = {
            'cvec__ngram_range': [(1,2), (1,3), (1,4), (1,5), (1,6), (1,7)],
            'cvec__stop_words': [None, short_stopwords, short_stopwords2, stopwords],  
            'cvec__max_features': [100, 200, 400, 600, 1000],
            'cvec__min_df': [2],
            'cvec__max_df': [.99],
            }

    elif target_info['model'] == 'rf':
        # Define CVEC + Logistic Regression Pipeline
        pipe = Pipeline([('cvec', CountVectorizer()), ('rf', RandomForestClassifier(random_state = RANDOM_STATE, n_jobs = 2))])
        params = {
            'cvec__ngram_range': [(1,2), (1,3), (1,4), (1,5)],
            'cvec__stop_words': [None, short_stopwords, short_stopwords2],  
            'cvec__max_features': [100, 200, 400, 800],
            'cvec__min_df': [2],
            'cvec__max_df': [.99],
            'rf__max_depth': [4,5, 6],
            'rf__min_samples_split': [2,3],
            'rf__min_samples_leaf': [10, 12]
            }

    
    else:
        print('did not specify model throw error')

    # define pipeline
    gs_model = GridSearchCV(pipe, param_grid = params, cv = 3, scoring = target_info['metric'])

    # Start the timer.
    t0 = time.time()

    # extract X_train and y_train
    X_train = split_data['X_train']
    y_train = split_data['y_train']
    
    # run pipeline
    model_result = gs_model.fit(X_train, y_train)

    print(f"Seconds elapsed for fitting: {(time.time() - t0):.3f}") # How many seconds elapsed.   
    return model_result

# %% [markdown]
# ## Main Control Function - runs the full model for all target types

# %%
# Control of the main project

# define dictionary of targets contains: tag, model, metric, input, order
target_dict = {}
target_dict['nontrigger'] = {'target': 'nontrigger', 'model': 'lr', 'metric': 'accuracy', 'model_input': 'SentenceLemmas'}
target_dict['loan_default'] = {'target': 'loan_default', 'model': 'lr', 'metric':'accuracy', 'model_input':'SentenceLemmas'}
target_dict['unspecified'] = {'target': 'unspecified', 'model': 'lr', 'metric':'accuracy', 'model_input':'SentenceLemmas'}
target_dict['debt_yield_fall'] = {'target': 'debt_yield_fall', 'model': 'lr', 'metric': 'accuracy', 'model_input': 'SentenceLemmas'}
target_dict['mezzanine_default'] = {'target': 'mezzanine_default', 'model': 'lr', 'metric': 'accuracy', 'model_input': 'SentenceLemmas'}
target_dict['bankruptcy'] = {'target': 'bankruptcy', 'model': 'lr', 'metric': 'accuracy', 'model_input': 'SentenceLemmas'}
target_dict['tenant_failure'] = {'target': 'tenant_failure', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['renovations'] = {'target': 'renovations', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['aggregate_debt_yield_fall'] = {'target': 'aggregate_debt_yield_fall', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['dscr_fall'] = {'target': 'dscr_fall', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['operator_termination'] = {'target': 'operator_termination', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['sponsor_termination'] = {'target': 'sponsor_termination', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['sff'] = {'target': 'sff', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['mezzanine_outstanding'] = {'target': 'mezzanine_outstanding', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['aggregate_dscr_fall'] = {'target': 'aggregate_dscr_fall', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
target_dict['delayed_repayment'] = {'target': 'delayed_repayment', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}

# set output_dict - will contain target + output of calculations
output_dict = {}

# get data
raw_df = get_data()
raw_df = clean_data(raw_df)

# Reshape our original dataframe and tokenize to prepare sentences for models
df = reshape_trigger_representation(raw_df)
df = tokenize_sentences(df)

# run for each model definition
for k,v in target_dict.items():
    
    print(f"{target_dict[k]['target'].replace('_', ' ').title()}: creating Train-Test split")
    # get split data
    split_data = get_split_data(df, v)
    
    print(f"Model fit in progress: {target_dict[k]}")
    # run model
    model_result = run_model(split_data, v)
    
    # make the output dictionary
    output_dict[k] = v
    output_dict[k]['split_data'] = split_data
    output_dict[k]['model_result'] = model_result

    
    print(f"Best fit parameters: {model_result.best_params_}")
    print(f"Best fit 3-fold cross validation score: {model_result.best_score_:.3f}")
    print(f"{target_dict[k]['target'].replace('_', ' ').title()} {target_dict[k]['metric']} Train score: {model_result.score(split_data['X_train'], split_data['y_train']):.3f}")
    print(f"{target_dict[k]['target'].replace('_', ' ').title()} {target_dict[k]['metric']} Test score: {model_result.score(split_data['X_test'], split_data['y_test']):.3f}")
    print("\n")
    
    output_dict[k]['best_params'] = model_result.best_params_
    output_dict[k]['count_deduplicated'] = df[target_dict[k]['target']].value_counts()[1]
    output_dict[k]['test_data_count'] = output_dict[k]['split_data']['y_test'].value_counts()[1]
    output_dict[k]['best_crossval_score'] = model_result.best_score_
    output_dict[k]['train_score'] = model_result.score(split_data['X_train'], split_data['y_train'])
    output_dict[k]['test_score'] = model_result.score(split_data['X_test'], split_data['y_test'])                                                  
    
    '''
    outfile = open(f"../data/models/{target_dict[k]['target']}_pickle", 'wb')
    pickle.dump(model_result, outfile)
    outfile.close()
    '''
    

full_output_dict = [output_dict[key] for key in output_dict.keys()]
results_df = pd.DataFrame.from_dict(full_output_dict)
    
print("Modeling complete!")
# Out:
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 35 unique documents have been included in the data set
# The 35 Documents have tag counts that range from 25 to 176.
# Tokenizing the input sentences...
# 2240 sentences have been tokenized and lemmatized.
#
#
# Nontrigger: creating Train-Test split
# Number of distinct labeled document/sentence combinations within the full data set: 1030
# Model fit in progress: {'target': 'nontrigger', 'model': 'lr', 'metric': 'accuracy', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 223.832
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 1000, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 6), 'cvec__stop_words': ['along', 'after', 'hundred', 'ca', 'keep', 'more', 'of', 'take', 'up', 'between', 'everything', 'had', 'go', 'we', 'which', 'could', 'became', 'empty', 'much', 'neither', 'thus', 'give', 'all', 'just', 'already', 'formerly', 'amongst', 'afterwards', 'but', 'four', 'may', 'off', 'what', 'i', 'in', 'some', 'sometime', 'wherever', 'both', 'elsewhere', 'everywhere', 'first', 'therein', 'until', 'really', 'upon', 'someone', 'who', 'others', 'under', 'across', 'below', 'top', 'for', 'eleven', 'enough', 'any', 'here', 'twenty', 'none', 'seeming', 'forty', 'on', 'are', 'me', 'never', 'see', 'thereupon', 'this', 'almost', 'not', 'part', 'beside', 'fifteen', 'at', 'how', 'than', 'though', 'anyway', 'us', 'various', 'ours', 'whence', 'whereafter', 'own', 'these', 'becoming', 'now', 'your', 'always', 'and', 'an', 'quite', 'them', 'does', 'or', 'hence', 'amount', 'it', 'moreover', 'rather', 'used', 'his', 'her', 'as', 'otherwise', 'himself', 'through', 'do', 'whenever', 'where', 'with', 'whoever', 'everyone', 'noone', 'whole', 'seems', 'behind', 'my', 'bottom', 'therefore', 'once', 'too', 'due', 'front', 'during', 'towards', 'since', 'anywhere', 'less', 'to', 'again', 'latter', 'then', 'nobody', 'itself', 'two', 'using', 'whither', 'wherein', 'those', 'name', 'beyond', 'from', 'even', 'perhaps', 'third', 'latterly', 'nowhere', 'down', 'thereafter', 'done', 'same', 'toward', 'five', 'show', 'that', 'yet', 'whereby', 'being', 'their', 'become', 'whereupon', 'against', 'twelve', 'still', 'within', 'throughout', 'often', 'has', 'he', 'is', 'thence', 'move', 'so', 'anything', 'ten', 'either', 'was', 'you', 'doing', 'next', 'regarding', 'seem', 'yourselves', 'made', 'whom', 'might', 'get', 'something', 'themselves', 'further', 'whatever', 'hereby', 'indeed', 'thereby', 'nor', 'would', 'via', 'besides', 'least', 'if', 'out', 'around', 'our', 'onto', 'put', 'somewhere', 'hereupon', 'namely', 'cannot', 'its', 'else', 'will', 'three', 'one', 'because', 'ever', 'no', 're', 'back', 'mine', 'six', 'another', 'there', 'without', 'before', 'each', 'whereas', 'meanwhile', 'nothing', 'yours', 'been', 'hereafter', 'several', 'also', 'every', 'the', 'by', 'sixty', 'were', 'among', 'while', 'yourself', 'why', 'ourselves', 'alone', 'anyone', 'except', 'seemed', 'hers', 'make', 'above', 'unless', 'myself', 'when', 'mostly', 'must', 'a', 'only', 'over', 'did', 'well', 'such', 'anyhow', 'thru', 'becomes', 'serious', 'eight', 'side', 'about', 'into', 'sometimes', 'together', 'can', 'be', 'per', 'him', 'whose', 'fifty', 'few', 'former', 'herself', 'should', 'they', 'although', 'however', 'somehow', 'herein', 'most', 'whether', 'full', 'many', 'she', 'beforehand', 'other', 'have', 'please', 'very', 'am', 'nevertheless', 'nine', 'call', 'last', 'say', 'marriott']}
# Best fit 3-fold cross validation score: 0.976
# Nontrigger accuracy Train score: 0.992
# Nontrigger accuracy Test score: 0.976
#
#
# Loan Default: creating Train-Test split
# Number of distinct labeled document/sentence combinations within the full data set: 531
# Model fit in progress: {'target': 'loan_default', 'model': 'lr', 'metric': 'accuracy', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 208.199
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 100, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 3), 'cvec__stop_words': ['along', 'after', 'hundred', 'ca', 'keep', 'more', 'of', 'take', 'up', 'between', 'everything', 'had', 'go', 'we', 'which', 'could', 'became', 'empty', 'much', 'neither', 'thus', 'give', 'all', 'just', 'already', 'formerly', 'amongst', 'afterwards', 'but', 'four', 'may', 'off', 'what', 'i', 'in', 'some', 'sometime', 'wherever', 'both', 'elsewhere', 'everywhere', 'first', 'therein', 'until', 'really', 'upon', 'someone', 'who', 'others', 'under', 'across', 'below', 'top', 'for', 'eleven', 'enough', 'any', 'here', 'twenty', 'none', 'seeming', 'forty', 'on', 'are', 'me', 'never', 'see', 'thereupon', 'this', 'almost', 'not', 'part', 'beside', 'fifteen', 'at', 'how', 'than', 'though', 'anyway', 'us', 'various', 'ours', 'whence', 'whereafter', 'own', 'these', 'becoming', 'now', 'your', 'always', 'and', 'an', 'quite', 'them', 'does', 'or', 'hence', 'amount', 'it', 'moreover', 'rather', 'used', 'his', 'her', 'as', 'otherwise', 'himself', 'through', 'do', 'whenever', 'where', 'with', 'whoever', 'everyone', 'noone', 'whole', 'seems', 'behind', 'my', 'bottom', 'therefore', 'once', 'too', 'due', 'front', 'during', 'towards', 'since', 'anywhere', 'less', 'to', 'again', 'latter', 'then', 'nobody', 'itself', 'two', 'using', 'whither', 'wherein', 'those', 'name', 'beyond', 'from', 'even', 'perhaps', 'third', 'latterly', 'nowhere', 'down', 'thereafter', 'done', 'same', 'toward', 'five', 'show', 'that', 'yet', 'whereby', 'being', 'their', 'become', 'whereupon', 'against', 'twelve', 'still', 'within', 'throughout', 'often', 'has', 'he', 'is', 'thence', 'move', 'so', 'anything', 'ten', 'either', 'was', 'you', 'doing', 'next', 'regarding', 'seem', 'yourselves', 'made', 'whom', 'might', 'get', 'something', 'themselves', 'further', 'whatever', 'hereby', 'indeed', 'thereby', 'nor', 'would', 'via', 'besides', 'least', 'if', 'out', 'around', 'our', 'onto', 'put', 'somewhere', 'hereupon', 'namely', 'cannot', 'its', 'else', 'will', 'three', 'one', 'because', 'ever', 'no', 're', 'back', 'mine', 'six', 'another', 'there', 'without', 'before', 'each', 'whereas', 'meanwhile', 'nothing', 'yours', 'been', 'hereafter', 'several', 'also', 'every', 'the', 'by', 'sixty', 'were', 'among', 'while', 'yourself', 'why', 'ourselves', 'alone', 'anyone', 'except', 'seemed', 'hers', 'make', 'above', 'unless', 'myself', 'when', 'mostly', 'must', 'a', 'only', 'over', 'did', 'well', 'such', 'anyhow', 'thru', 'becomes', 'serious', 'eight', 'side', 'about', 'into', 'sometimes', 'together', 'can', 'be', 'per', 'him', 'whose', 'fifty', 'few', 'former', 'herself', 'should', 'they', 'although', 'however', 'somehow', 'herein', 'most', 'whether', 'full', 'many', 'she', 'beforehand', 'other', 'have', 'please', 'very', 'am', 'nevertheless', 'nine', 'call', 'last', 'say', 'marriott']}
# Best fit 3-fold cross validation score: 0.973
# Loan Default accuracy Train score: 0.985
# Loan Default accuracy Test score: 0.948
#
#
# Unspecified: creating Train-Test split
# Number of distinct labeled document/sentence combinations within the full data set: 485
# Model fit in progress: {'target': 'unspecified', 'model': 'lr', 'metric': 'accuracy', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 208.793
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 1000, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 3), 'cvec__stop_words': ['along', 'after', 'hundred', 'ca', 'keep', 'more', 'of', 'take', 'up', 'between', 'everything', 'had', 'go', 'we', 'which', 'could', 'became', 'empty', 'much', 'neither', 'thus', 'give', 'all', 'just', 'already', 'formerly', 'amongst', 'afterwards', 'but', 'four', 'may', 'off', 'what', 'i', 'in', 'some', 'sometime', 'wherever', 'both', 'elsewhere', 'everywhere', 'first', 'therein', 'until', 'really', 'upon', 'someone', 'who', 'others', 'under', 'across', 'below', 'top', 'for', 'eleven', 'enough', 'any', 'here', 'twenty', 'none', 'seeming', 'forty', 'on', 'are', 'me', 'never', 'see', 'thereupon', 'this', 'almost', 'not', 'part', 'beside', 'fifteen', 'at', 'how', 'than', 'though', 'anyway', 'us', 'various', 'ours', 'whence', 'whereafter', 'own', 'these', 'becoming', 'now', 'your', 'always', 'and', 'an', 'quite', 'them', 'does', 'or', 'hence', 'amount', 'it', 'moreover', 'rather', 'used', 'his', 'her', 'as', 'otherwise', 'himself', 'through', 'do', 'whenever', 'where', 'with', 'whoever', 'everyone', 'noone', 'whole', 'seems', 'behind', 'my', 'bottom', 'therefore', 'once', 'too', 'due', 'front', 'during', 'towards', 'since', 'anywhere', 'less', 'to', 'again', 'latter', 'then', 'nobody', 'itself', 'two', 'using', 'whither', 'wherein', 'those', 'name', 'beyond', 'from', 'even', 'perhaps', 'third', 'latterly', 'nowhere', 'down', 'thereafter', 'done', 'same', 'toward', 'five', 'show', 'that', 'yet', 'whereby', 'being', 'their', 'become', 'whereupon', 'against', 'twelve', 'still', 'within', 'throughout', 'often', 'has', 'he', 'is', 'thence', 'move', 'so', 'anything', 'ten', 'either', 'was', 'you', 'doing', 'next', 'regarding', 'seem', 'yourselves', 'made', 'whom', 'might', 'get', 'something', 'themselves', 'further', 'whatever', 'hereby', 'indeed', 'thereby', 'nor', 'would', 'via', 'besides', 'least', 'if', 'out', 'around', 'our', 'onto', 'put', 'somewhere', 'hereupon', 'namely', 'cannot', 'its', 'else', 'will', 'three', 'one', 'because', 'ever', 'no', 're', 'back', 'mine', 'six', 'another', 'there', 'without', 'before', 'each', 'whereas', 'meanwhile', 'nothing', 'yours', 'been', 'hereafter', 'several', 'also', 'every', 'the', 'by', 'sixty', 'were', 'among', 'while', 'yourself', 'why', 'ourselves', 'alone', 'anyone', 'except', 'seemed', 'hers', 'make', 'above', 'unless', 'myself', 'when', 'mostly', 'must', 'a', 'only', 'over', 'did', 'well', 'such', 'anyhow', 'thru', 'becomes', 'serious', 'eight', 'side', 'about', 'into', 'sometimes', 'together', 'can', 'be', 'per', 'him', 'whose', 'fifty', 'few', 'former', 'herself', 'should', 'they', 'although', 'however', 'somehow', 'herein', 'most', 'whether', 'full', 'many', 'she', 'beforehand', 'other', 'have', 'please', 'very', 'am', 'nevertheless', 'nine', 'call', 'last', 'say', 'marriott']}
# Best fit 3-fold cross validation score: 0.952
# Unspecified accuracy Train score: 0.995
# Unspecified accuracy Test score: 0.955
#
#
# Debt Yield Fall: creating Train-Test split
# Number of distinct labeled document/sentence combinations within the full data set: 184
# Model fit in progress: {'target': 'debt_yield_fall', 'model': 'lr', 'metric': 'accuracy', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 196.333
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 600, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 5), 'cvec__stop_words': None}
# Best fit 3-fold cross validation score: 0.992
# Debt Yield Fall accuracy Train score: 1.000
# Debt Yield Fall accuracy Test score: 0.991
#
#
# Mezzanine Default: creating Train-Test split
# Number of distinct labeled document/sentence combinations within the full data set: 67
# Model fit in progress: {'target': 'mezzanine_default', 'model': 'lr', 'metric': 'accuracy', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 218.026
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 600, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 3), 'cvec__stop_words': ['along', 'after', 'hundred', 'ca', 'keep', 'more', 'of', 'take', 'up', 'between', 'everything', 'had', 'go', 'we', 'which', 'could', 'became', 'empty', 'much', 'neither', 'thus', 'give', 'all', 'just', 'already', 'formerly', 'amongst', 'afterwards', 'but', 'four', 'may', 'off', 'what', 'i', 'in', 'some', 'sometime', 'wherever', 'both', 'elsewhere', 'everywhere', 'first', 'therein', 'until', 'really', 'upon', 'someone', 'who', 'others', 'under', 'across', 'below', 'top', 'for', 'eleven', 'enough', 'any', 'here', 'twenty', 'none', 'seeming', 'forty', 'on', 'are', 'me', 'never', 'see', 'thereupon', 'this', 'almost', 'not', 'part', 'beside', 'fifteen', 'at', 'how', 'than', 'though', 'anyway', 'us', 'various', 'ours', 'whence', 'whereafter', 'own', 'these', 'becoming', 'now', 'your', 'always', 'and', 'an', 'quite', 'them', 'does', 'or', 'hence', 'amount', 'it', 'moreover', 'rather', 'used', 'his', 'her', 'as', 'otherwise', 'himself', 'through', 'do', 'whenever', 'where', 'with', 'whoever', 'everyone', 'noone', 'whole', 'seems', 'behind', 'my', 'bottom', 'therefore', 'once', 'too', 'due', 'front', 'during', 'towards', 'since', 'anywhere', 'less', 'to', 'again', 'latter', 'then', 'nobody', 'itself', 'two', 'using', 'whither', 'wherein', 'those', 'name', 'beyond', 'from', 'even', 'perhaps', 'third', 'latterly', 'nowhere', 'down', 'thereafter', 'done', 'same', 'toward', 'five', 'show', 'that', 'yet', 'whereby', 'being', 'their', 'become', 'whereupon', 'against', 'twelve', 'still', 'within', 'throughout', 'often', 'has', 'he', 'is', 'thence', 'move', 'so', 'anything', 'ten', 'either', 'was', 'you', 'doing', 'next', 'regarding', 'seem', 'yourselves', 'made', 'whom', 'might', 'get', 'something', 'themselves', 'further', 'whatever', 'hereby', 'indeed', 'thereby', 'nor', 'would', 'via', 'besides', 'least', 'if', 'out', 'around', 'our', 'onto', 'put', 'somewhere', 'hereupon', 'namely', 'cannot', 'its', 'else', 'will', 'three', 'one', 'because', 'ever', 'no', 're', 'back', 'mine', 'six', 'another', 'there', 'without', 'before', 'each', 'whereas', 'meanwhile', 'nothing', 'yours', 'been', 'hereafter', 'several', 'also', 'every', 'the', 'by', 'sixty', 'were', 'among', 'while', 'yourself', 'why', 'ourselves', 'alone', 'anyone', 'except', 'seemed', 'hers', 'make', 'above', 'unless', 'myself', 'when', 'mostly', 'must', 'a', 'only', 'over', 'did', 'well', 'such', 'anyhow', 'thru', 'becomes', 'serious', 'eight', 'side', 'about', 'into', 'sometimes', 'together', 'can', 'be', 'per', 'him', 'whose', 'fifty', 'few', 'former', 'herself', 'should', 'they', 'although', 'however', 'somehow', 'herein', 'most', 'whether', 'full', 'many', 'she', 'beforehand', 'other', 'have', 'please', 'very', 'am', 'nevertheless', 'nine', 'call', 'last', 'say', 'marriott']}
# Best fit 3-fold cross validation score: 0.992
# Mezzanine Default accuracy Train score: 0.999
# Mezzanine Default accuracy Test score: 0.987
#
#
# Bankruptcy: creating Train-Test split
# Number of distinct labeled document/sentence combinations within the full data set: 44
# Model fit in progress: {'target': 'bankruptcy', 'model': 'lr', 'metric': 'accuracy', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 247.872
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 1000, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 3), 'cvec__stop_words': ['the', 'and', 'a', 'to', 'it', 'be', 'for', 'with', 'that', 'marriott']}
# Best fit 3-fold cross validation score: 0.992
# Bankruptcy accuracy Train score: 0.999
# Bankruptcy accuracy Test score: 0.999
#
#
# Tenant Failure: creating Train-Test split
# Number of distinct labeled document/sentence combinations within the full data set: 74
# Model fit in progress: {'target': 'tenant_failure', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 243.121
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 400, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 4), 'cvec__stop_words': ['along', 'after', 'hundred', 'ca', 'keep', 'more', 'of', 'take', 'up', 'between', 'everything', 'had', 'go', 'we', 'which', 'could', 'became', 'empty', 'much', 'neither', 'thus', 'give', 'all', 'just', 'already', 'formerly', 'amongst', 'afterwards', 'but', 'four', 'may', 'off', 'what', 'i', 'in', 'some', 'sometime', 'wherever', 'both', 'elsewhere', 'everywhere', 'first', 'therein', 'until', 'really', 'upon', 'someone', 'who', 'others', 'under', 'across', 'below', 'top', 'for', 'eleven', 'enough', 'any', 'here', 'twenty', 'none', 'seeming', 'forty', 'on', 'are', 'me', 'never', 'see', 'thereupon', 'this', 'almost', 'not', 'part', 'beside', 'fifteen', 'at', 'how', 'than', 'though', 'anyway', 'us', 'various', 'ours', 'whence', 'whereafter', 'own', 'these', 'becoming', 'now', 'your', 'always', 'and', 'an', 'quite', 'them', 'does', 'or', 'hence', 'amount', 'it', 'moreover', 'rather', 'used', 'his', 'her', 'as', 'otherwise', 'himself', 'through', 'do', 'whenever', 'where', 'with', 'whoever', 'everyone', 'noone', 'whole', 'seems', 'behind', 'my', 'bottom', 'therefore', 'once', 'too', 'due', 'front', 'during', 'towards', 'since', 'anywhere', 'less', 'to', 'again', 'latter', 'then', 'nobody', 'itself', 'two', 'using', 'whither', 'wherein', 'those', 'name', 'beyond', 'from', 'even', 'perhaps', 'third', 'latterly', 'nowhere', 'down', 'thereafter', 'done', 'same', 'toward', 'five', 'show', 'that', 'yet', 'whereby', 'being', 'their', 'become', 'whereupon', 'against', 'twelve', 'still', 'within', 'throughout', 'often', 'has', 'he', 'is', 'thence', 'move', 'so', 'anything', 'ten', 'either', 'was', 'you', 'doing', 'next', 'regarding', 'seem', 'yourselves', 'made', 'whom', 'might', 'get', 'something', 'themselves', 'further', 'whatever', 'hereby', 'indeed', 'thereby', 'nor', 'would', 'via', 'besides', 'least', 'if', 'out', 'around', 'our', 'onto', 'put', 'somewhere', 'hereupon', 'namely', 'cannot', 'its', 'else', 'will', 'three', 'one', 'because', 'ever', 'no', 're', 'back', 'mine', 'six', 'another', 'there', 'without', 'before', 'each', 'whereas', 'meanwhile', 'nothing', 'yours', 'been', 'hereafter', 'several', 'also', 'every', 'the', 'by', 'sixty', 'were', 'among', 'while', 'yourself', 'why', 'ourselves', 'alone', 'anyone', 'except', 'seemed', 'hers', 'make', 'above', 'unless', 'myself', 'when', 'mostly', 'must', 'a', 'only', 'over', 'did', 'well', 'such', 'anyhow', 'thru', 'becomes', 'serious', 'eight', 'side', 'about', 'into', 'sometimes', 'together', 'can', 'be', 'per', 'him', 'whose', 'fifty', 'few', 'former', 'herself', 'should', 'they', 'although', 'however', 'somehow', 'herein', 'most', 'whether', 'full', 'many', 'she', 'beforehand', 'other', 'have', 'please', 'very', 'am', 'nevertheless', 'nine', 'call', 'last', 'say', 'marriott']}
# Best fit 3-fold cross validation score: 0.858
# Tenant Failure f1 Train score: 1.000
# Tenant Failure f1 Test score: 0.933
#
#
# Renovations: creating Train-Test split
# Number of distinct labeled document/sentence combinations within the full data set: 24
# Model fit in progress: {'target': 'renovations', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 230.430
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 100, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 2), 'cvec__stop_words': None}
# Best fit 3-fold cross validation score: 0.912
# Renovations f1 Train score: 0.970
# Renovations f1 Test score: 0.667
#
#
# Aggregate Debt Yield Fall: creating Train-Test split
# Number of distinct labeled document/sentence combinations within the full data set: 18
# Model fit in progress: {'target': 'aggregate_debt_yield_fall', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 234.978
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 200, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 2), 'cvec__stop_words': None}
# Best fit 3-fold cross validation score: 0.490
# Aggregate Debt Yield Fall f1 Train score: 1.000
# Aggregate Debt Yield Fall f1 Test score: 0.667
#
#
# Dscr Fall: creating Train-Test split
# Number of distinct labeled document/sentence combinations within the full data set: 23
# Model fit in progress: {'target': 'dscr_fall', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 240.848
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 200, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 2), 'cvec__stop_words': None}
# Best fit 3-fold cross validation score: 0.709
# Dscr Fall f1 Train score: 0.968
# Dscr Fall f1 Test score: 0.444
#
#
# Operator Termination: creating Train-Test split
# Number of distinct labeled document/sentence combinations within the full data set: 17
# Model fit in progress: {'target': 'operator_termination', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 247.109
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 600, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 2), 'cvec__stop_words': ['along', 'after', 'hundred', 'ca', 'keep', 'more', 'of', 'take', 'up', 'between', 'everything', 'had', 'go', 'we', 'which', 'could', 'became', 'empty', 'much', 'neither', 'thus', 'give', 'all', 'just', 'already', 'formerly', 'amongst', 'afterwards', 'but', 'four', 'may', 'off', 'what', 'i', 'in', 'some', 'sometime', 'wherever', 'both', 'elsewhere', 'everywhere', 'first', 'therein', 'until', 'really', 'upon', 'someone', 'who', 'others', 'under', 'across', 'below', 'top', 'for', 'eleven', 'enough', 'any', 'here', 'twenty', 'none', 'seeming', 'forty', 'on', 'are', 'me', 'never', 'see', 'thereupon', 'this', 'almost', 'not', 'part', 'beside', 'fifteen', 'at', 'how', 'than', 'though', 'anyway', 'us', 'various', 'ours', 'whence', 'whereafter', 'own', 'these', 'becoming', 'now', 'your', 'always', 'and', 'an', 'quite', 'them', 'does', 'or', 'hence', 'amount', 'it', 'moreover', 'rather', 'used', 'his', 'her', 'as', 'otherwise', 'himself', 'through', 'do', 'whenever', 'where', 'with', 'whoever', 'everyone', 'noone', 'whole', 'seems', 'behind', 'my', 'bottom', 'therefore', 'once', 'too', 'due', 'front', 'during', 'towards', 'since', 'anywhere', 'less', 'to', 'again', 'latter', 'then', 'nobody', 'itself', 'two', 'using', 'whither', 'wherein', 'those', 'name', 'beyond', 'from', 'even', 'perhaps', 'third', 'latterly', 'nowhere', 'down', 'thereafter', 'done', 'same', 'toward', 'five', 'show', 'that', 'yet', 'whereby', 'being', 'their', 'become', 'whereupon', 'against', 'twelve', 'still', 'within', 'throughout', 'often', 'has', 'he', 'is', 'thence', 'move', 'so', 'anything', 'ten', 'either', 'was', 'you', 'doing', 'next', 'regarding', 'seem', 'yourselves', 'made', 'whom', 'might', 'get', 'something', 'themselves', 'further', 'whatever', 'hereby', 'indeed', 'thereby', 'nor', 'would', 'via', 'besides', 'least', 'if', 'out', 'around', 'our', 'onto', 'put', 'somewhere', 'hereupon', 'namely', 'cannot', 'its', 'else', 'will', 'three', 'one', 'because', 'ever', 'no', 're', 'back', 'mine', 'six', 'another', 'there', 'without', 'before', 'each', 'whereas', 'meanwhile', 'nothing', 'yours', 'been', 'hereafter', 'several', 'also', 'every', 'the', 'by', 'sixty', 'were', 'among', 'while', 'yourself', 'why', 'ourselves', 'alone', 'anyone', 'except', 'seemed', 'hers', 'make', 'above', 'unless', 'myself', 'when', 'mostly', 'must', 'a', 'only', 'over', 'did', 'well', 'such', 'anyhow', 'thru', 'becomes', 'serious', 'eight', 'side', 'about', 'into', 'sometimes', 'together', 'can', 'be', 'per', 'him', 'whose', 'fifty', 'few', 'former', 'herself', 'should', 'they', 'although', 'however', 'somehow', 'herein', 'most', 'whether', 'full', 'many', 'she', 'beforehand', 'other', 'have', 'please', 'very', 'am', 'nevertheless', 'nine', 'call', 'last', 'say', 'marriott']}
# Best fit 3-fold cross validation score: 0.762
# Operator Termination f1 Train score: 1.000
# Operator Termination f1 Test score: 0.500
#
#
# Sponsor Termination: creating Train-Test split
# Number of distinct labeled document/sentence combinations within the full data set: 14
# Model fit in progress: {'target': 'sponsor_termination', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 253.596
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 100, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 3), 'cvec__stop_words': None}
# Best fit 3-fold cross validation score: 0.419
# Sponsor Termination f1 Train score: 1.000
# Sponsor Termination f1 Test score: 0.571
#
#
# Sff: creating Train-Test split
# Number of distinct labeled document/sentence combinations within the full data set: 9
# Model fit in progress: {'target': 'sff', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 243.671
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 1000, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 3), 'cvec__stop_words': ['along', 'after', 'hundred', 'ca', 'keep', 'more', 'of', 'take', 'up', 'between', 'everything', 'had', 'go', 'we', 'which', 'could', 'became', 'empty', 'much', 'neither', 'thus', 'give', 'all', 'just', 'already', 'formerly', 'amongst', 'afterwards', 'but', 'four', 'may', 'off', 'what', 'i', 'in', 'some', 'sometime', 'wherever', 'both', 'elsewhere', 'everywhere', 'first', 'therein', 'until', 'really', 'upon', 'someone', 'who', 'others', 'under', 'across', 'below', 'top', 'for', 'eleven', 'enough', 'any', 'here', 'twenty', 'none', 'seeming', 'forty', 'on', 'are', 'me', 'never', 'see', 'thereupon', 'this', 'almost', 'not', 'part', 'beside', 'fifteen', 'at', 'how', 'than', 'though', 'anyway', 'us', 'various', 'ours', 'whence', 'whereafter', 'own', 'these', 'becoming', 'now', 'your', 'always', 'and', 'an', 'quite', 'them', 'does', 'or', 'hence', 'amount', 'it', 'moreover', 'rather', 'used', 'his', 'her', 'as', 'otherwise', 'himself', 'through', 'do', 'whenever', 'where', 'with', 'whoever', 'everyone', 'noone', 'whole', 'seems', 'behind', 'my', 'bottom', 'therefore', 'once', 'too', 'due', 'front', 'during', 'towards', 'since', 'anywhere', 'less', 'to', 'again', 'latter', 'then', 'nobody', 'itself', 'two', 'using', 'whither', 'wherein', 'those', 'name', 'beyond', 'from', 'even', 'perhaps', 'third', 'latterly', 'nowhere', 'down', 'thereafter', 'done', 'same', 'toward', 'five', 'show', 'that', 'yet', 'whereby', 'being', 'their', 'become', 'whereupon', 'against', 'twelve', 'still', 'within', 'throughout', 'often', 'has', 'he', 'is', 'thence', 'move', 'so', 'anything', 'ten', 'either', 'was', 'you', 'doing', 'next', 'regarding', 'seem', 'yourselves', 'made', 'whom', 'might', 'get', 'something', 'themselves', 'further', 'whatever', 'hereby', 'indeed', 'thereby', 'nor', 'would', 'via', 'besides', 'least', 'if', 'out', 'around', 'our', 'onto', 'put', 'somewhere', 'hereupon', 'namely', 'cannot', 'its', 'else', 'will', 'three', 'one', 'because', 'ever', 'no', 're', 'back', 'mine', 'six', 'another', 'there', 'without', 'before', 'each', 'whereas', 'meanwhile', 'nothing', 'yours', 'been', 'hereafter', 'several', 'also', 'every', 'the', 'by', 'sixty', 'were', 'among', 'while', 'yourself', 'why', 'ourselves', 'alone', 'anyone', 'except', 'seemed', 'hers', 'make', 'above', 'unless', 'myself', 'when', 'mostly', 'must', 'a', 'only', 'over', 'did', 'well', 'such', 'anyhow', 'thru', 'becomes', 'serious', 'eight', 'side', 'about', 'into', 'sometimes', 'together', 'can', 'be', 'per', 'him', 'whose', 'fifty', 'few', 'former', 'herself', 'should', 'they', 'although', 'however', 'somehow', 'herein', 'most', 'whether', 'full', 'many', 'she', 'beforehand', 'other', 'have', 'please', 'very', 'am', 'nevertheless', 'nine', 'call', 'last', 'say', 'marriott']}
# Best fit 3-fold cross validation score: 0.778
# Sff f1 Train score: 1.000
# Sff f1 Test score: 0.500
#
#
# Mezzanine Outstanding: creating Train-Test split
# Number of distinct labeled document/sentence combinations within the full data set: 8
# Model fit in progress: {'target': 'mezzanine_outstanding', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 215.859
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 200, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 2), 'cvec__stop_words': None}
# Best fit 3-fold cross validation score: 0.333
# Mezzanine Outstanding f1 Train score: 0.909
# Mezzanine Outstanding f1 Test score: 0.000
#
#
# Aggregate Dscr Fall: creating Train-Test split
# Number of distinct labeled document/sentence combinations within the full data set: 8
# Model fit in progress: {'target': 'aggregate_dscr_fall', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# Seconds elapsed for fitting: 233.134
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 100, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 2), 'cvec__stop_words': None}
# Best fit 3-fold cross validation score: 0.889
# Aggregate Dscr Fall f1 Train score: 1.000
# Aggregate Dscr Fall f1 Test score: 0.667
#
#
# Delayed Repayment: creating Train-Test split
# Number of distinct labeled document/sentence combinations within the full data set: 3
# Model fit in progress: {'target': 'delayed_repayment', 'model': 'lr', 'metric': 'f1', 'model_input': 'SentenceLemmas'}
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)
# Seconds elapsed for fitting: 210.639
# Best fit parameters: {'cvec__max_df': 0.99, 'cvec__max_features': 100, 'cvec__min_df': 2, 'cvec__ngram_range': (1, 2), 'cvec__stop_words': None}
# Best fit 3-fold cross validation score: 0.000
# Delayed Repayment f1 Train score: 1.000
# Delayed Repayment f1 Test score: 0.000
#
#
# Modeling complete!

# %%
'''
outfile = open("output_dict_06_15_20", 'wb')
pickle.dump(output_dict, outfile)
outfile.close()
'''
# Out:
# '\noutfile = open("output_dict_06_15_20", \'wb\')\npickle.dump(output_dict, outfile)\noutfile.close()\n'

# %%
output_dict
# Out:
# {'nontrigger': {'target': 'nontrigger',
#   'model': 'lr',
#   'metric': 'accuracy',
#   'model_input': 'SentenceLemmas',
#   'split_data': {'X_train': 837     the lender be require to maintain an account f...
#    1565    on the origination date there exist with respe...
#    1240    any amount remain in the leasing reserve fund ...
#    898      eligible account mean a separate and identifi...
#    589     in the event borrower be require to make the m...
#                                  ...
#    1120    the mortgage lender may also establish subacco...
#    1448     approv extraordinary expense mean an operate ...
#    1407    if the amount of the tax and insurance funds e...
#    1311    upon enter into a franchise agreement borrower...
#    1039    fund from the pool a properties will be deposi...
#    Name: SentenceLemmas, Length: 1568, dtype: object,
#    'X_test': 990     the related loan documents require the borrowe...
#    1605    all interest in the required renovation reserv...
#    1646    the borrower establish a lockbox account the l...
#    1660    at any time the mortgaged property be subject ...
#    1096    the borrower be require to because all credit ...
#                                  ...
#    972      pip work mean any work to be perform pursuant...
#    2029    during the continuance of a mortgage loan even...
#    1860    notwithstanding anything to the contrary conta...
#    1979    provide no event of default have occur and be ...
#    2075     low dscr period will commence if as of any da...
#    Name: SentenceLemmas, Length: 672, dtype: object,
#    'y_train': 837     1
#    1565    1
#    1240    1
#    898     1
#    589     0
#           ..
#    1120    1
#    1448    1
#    1407    1
#    1311    1
#    1039    1
#    Name: nontrigger, Length: 1568, dtype: int64,
#    'y_test': 990     1
#    1605    1
#    1646    1
#    1660    1
#    1096    1
#           ..
#    972     1
#    2029    0
#    1860    0
#    1979    0
#    2075    0
#    Name: nontrigger, Length: 672, dtype: int64,
#    'indices_train': Int64Index([ 837, 1565, 1240,  898,  589, 1167,  715,  373,  999,  417,
#                ...
#                 717,  583, 2188,  561, 1608, 1120, 1448, 1407, 1311, 1039],
#               dtype='int64', length=1568),
#    'indices_test': Int64Index([ 990, 1605, 1646, 1660, 1096,  240, 1653, 1761, 1026, 1685,
#                ...
#                1648, 1607, 1418,  447,  123,  972, 2029, 1860, 1979, 2075],
#               dtype='int64', length=672)},
#   'model_result': GridSearchCV(cv=3, error_score=nan,
#                estimator=Pipeline(memory=None,
#                                   steps=[('cvec',
#                                           CountVectorizer(analyzer='word',
#                                                           binary=False,
#                                                           decode_error='strict',
#                                                           dtype=<class 'numpy.int64'>,
#                                                           encoding='utf-8',
#                                                           input='content',
#                                                           lowercase=True,
#                                                           max_df=1.0,
#                                                           max_features=None,
#                                                           min_df=1,
#                                                           ngram_range=(1, 1),
#                                                           preprocessor=None,
#                                                           stop_words=None,
#                                                           strip_accents=None,
#                                                           token_pattern='(?u)...
#                                                  'be', 'for', 'with', 'that',
#                                                  'marriott'],
#                                                 ['along', 'after', 'hundred',
#                                                  'ca', 'keep', 'more', 'of',
#                                                  'take', 'up', 'between',
#                                                  'everything', 'had', 'go', 'we',
#                                                  'which', 'could', 'became',
#                                                  'empty', 'much', 'neither',
#                                                  'thus', 'give', 'all', 'just',
#                                                  'already', 'formerly', 'amongst',
#                                                  'afterwards', 'but', 'four', ...]]},
#                pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#                scoring='accuracy', verbose=0),
#   'best_params': {'cvec__max_df': 0.99,
#    'cvec__max_features': 1000,
#    'cvec__min_df': 2,
#    'cvec__ngram_range': (1, 6),
#    'cvec__stop_words': ['along',
#     'after',
#     'hundred',
#     'ca',
#     'keep',
#     'more',
#     'of',
#     'take',
#     'up',
#     'between',
#     'everything',
#     'had',
#     'go',
#     'we',
#     'which',
#     'could',
#     'became',
#     'empty',
#     'much',
#     'neither',
#     'thus',
#     'give',
#     'all',
#     'just',
#     'already',
#     'formerly',
#     'amongst',
#     'afterwards',
#     'but',
#     'four',
#     'may',
#     'off',
#     'what',
#     'i',
#     'in',
#     'some',
#     'sometime',
#     'wherever',
#     'both',
#     'elsewhere',
#     'everywhere',
#     'first',
#     'therein',
#     'until',
#     'really',
#     'upon',
#     'someone',
#     'who',
#     'others',
#     'under',
#     'across',
#     'below',
#     'top',
#     'for',
#     'eleven',
#     'enough',
#     'any',
#     'here',
#     'twenty',
#     'none',
#     'seeming',
#     'forty',
#     'on',
#     'are',
#     'me',
#     'never',
#     'see',
#     'thereupon',
#     'this',
#     'almost',
#     'not',
#     'part',
#     'beside',
#     'fifteen',
#     'at',
#     'how',
#     'than',
#     'though',
#     'anyway',
#     'us',
#     'various',
#     'ours',
#     'whence',
#     'whereafter',
#     'own',
#     'these',
#     'becoming',
#     'now',
#     'your',
#     'always',
#     'and',
#     'an',
#     'quite',
#     'them',
#     'does',
#     'or',
#     'hence',
#     'amount',
#     'it',
#     'moreover',
#     'rather',
#     'used',
#     'his',
#     'her',
#     'as',
#     'otherwise',
#     'himself',
#     'through',
#     'do',
#     'whenever',
#     'where',
#     'with',
#     'whoever',
#     'everyone',
#     'noone',
#     'whole',
#     'seems',
#     'behind',
#     'my',
#     'bottom',
#     'therefore',
#     'once',
#     'too',
#     'due',
#     'front',
#     'during',
#     'towards',
#     'since',
#     'anywhere',
#     'less',
#     'to',
#     'again',
#     'latter',
#     'then',
#     'nobody',
#     'itself',
#     'two',
#     'using',
#     'whither',
#     'wherein',
#     'those',
#     'name',
#     'beyond',
#     'from',
#     'even',
#     'perhaps',
#     'third',
#     'latterly',
#     'nowhere',
#     'down',
#     'thereafter',
#     'done',
#     'same',
#     'toward',
#     'five',
#     'show',
#     'that',
#     'yet',
#     'whereby',
#     'being',
#     'their',
#     'become',
#     'whereupon',
#     'against',
#     'twelve',
#     'still',
#     'within',
#     'throughout',
#     'often',
#     'has',
#     'he',
#     'is',
#     'thence',
#     'move',
#     'so',
#     'anything',
#     'ten',
#     'either',
#     'was',
#     'you',
#     'doing',
#     'next',
#     'regarding',
#     'seem',
#     'yourselves',
#     'made',
#     'whom',
#     'might',
#     'get',
#     'something',
#     'themselves',
#     'further',
#     'whatever',
#     'hereby',
#     'indeed',
#     'thereby',
#     'nor',
#     'would',
#     'via',
#     'besides',
#     'least',
#     'if',
#     'out',
#     'around',
#     'our',
#     'onto',
#     'put',
#     'somewhere',
#     'hereupon',
#     'namely',
#     'cannot',
#     'its',
#     'else',
#     'will',
#     'three',
#     'one',
#     'because',
#     'ever',
#     'no',
#     're',
#     'back',
#     'mine',
#     'six',
#     'another',
#     'there',
#     'without',
#     'before',
#     'each',
#     'whereas',
#     'meanwhile',
#     'nothing',
#     'yours',
#     'been',
#     'hereafter',
#     'several',
#     'also',
#     'every',
#     'the',
#     'by',
#     'sixty',
#     'were',
#     'among',
#     'while',
#     'yourself',
#     'why',
#     'ourselves',
#     'alone',
#     'anyone',
#     'except',
#     'seemed',
#     'hers',
#     'make',
#     'above',
#     'unless',
#     'myself',
#     'when',
#     'mostly',
#     'must',
#     'a',
#     'only',
#     'over',
#     'did',
#     'well',
#     'such',
#     'anyhow',
#     'thru',
#     'becomes',
#     'serious',
#     'eight',
#     'side',
#     'about',
#     'into',
#     'sometimes',
#     'together',
#     'can',
#     'be',
#     'per',
#     'him',
#     'whose',
#     'fifty',
#     'few',
#     'former',
#     'herself',
#     'should',
#     'they',
#     'although',
#     'however',
#     'somehow',
#     'herein',
#     'most',
#     'whether',
#     'full',
#     'many',
#     'she',
#     'beforehand',
#     'other',
#     'have',
#     'please',
#     'very',
#     'am',
#     'nevertheless',
#     'nine',
#     'call',
#     'last',
#     'say',
#     'marriott']},
#   'count_deduplicated': 1030,
#   'test_data_count': 309,
#   'best_crossval_score': 0.9764107748547651,
#   'train_score': 0.9923469387755102,
#   'test_score': 0.9761904761904762},
#  'loan_default': {'target': 'loan_default',
#   'model': 'lr',
#   'metric': 'accuracy',
#   'model_input': 'SentenceLemmas',
#   'split_data': {'X_train': 623     provide there be sufficient amount in the tax ...
#    272     the mortgage lender will not be obligate to di...
#    2002    anything to the contrary herein or elsewhere n...
#    1923    mortgage lender will pay say item or disburse ...
#    1149    the mortgage lender will be require to disburs...
#                                  ...
#    1536     true up payment mean a payment into the appli...
#    1326    any excess cash flow reserve funds remain on d...
#    208     upon the request of the borrower at any time t...
#    1243    any amount remain in the operating expense fun...
#    2061    during the continuance of a loan event of defa...
#    Name: SentenceLemmas, Length: 1568, dtype: object,
#    'X_test': 203     so long as no mortgage loan event of default b...
#    378     upon the occurrence and during the continuance...
#    807     the lender be require to maintain an account f...
#    2119    provide no trigger period then exist all remai...
#    192      pool a trigger period mean a period a commenc...
#                                  ...
#    244     a trigger period will commence upon the occurr...
#    1248    the borrower be require to perform or because ...
#    629     upon the cure of any trigger period and provid...
#    777     with respect to each receipt from the property...
#    952     the deposit account be require to be maintain ...
#    Name: SentenceLemmas, Length: 672, dtype: object,
#    'y_train': 623     1
#    272     1
#    2002    1
#    1923    1
#    1149    0
#           ..
#    1536    0
#    1326    0
#    208     1
#    1243    0
#    2061    1
#    Name: loan_default, Length: 1568, dtype: int64,
#    'y_test': 203     1
#    378     1
#    807     0
#    2119    1
#    192     1
#           ..
#    244     1
#    1248    0
#    629     0
#    777     0
#    952     0
#    Name: loan_default, Length: 672, dtype: int64,
#    'indices_train': Int64Index([ 623,  272, 2002, 1923, 1149, 1835,  995, 1150, 1282, 1650,
#                ...
#                1635, 1586,  904, 1679, 1206, 1536, 1326,  208, 1243, 2061],
#               dtype='int64', length=1568),
#    'indices_test': Int64Index([ 203,  378,  807, 2119,  192, 1439, 1556,  809,  402,   70,
#                ...
#                2116,  365,  167,  200,  796,  244, 1248,  629,  777,  952],
#               dtype='int64', length=672)},
#   'model_result': GridSearchCV(cv=3, error_score=nan,
#                estimator=Pipeline(memory=None,
#                                   steps=[('cvec',
#                                           CountVectorizer(analyzer='word',
#                                                           binary=False,
#                                                           decode_error='strict',
#                                                           dtype=<class 'numpy.int64'>,
#                                                           encoding='utf-8',
#                                                           input='content',
#                                                           lowercase=True,
#                                                           max_df=1.0,
#                                                           max_features=None,
#                                                           min_df=1,
#                                                           ngram_range=(1, 1),
#                                                           preprocessor=None,
#                                                           stop_words=None,
#                                                           strip_accents=None,
#                                                           token_pattern='(?u)...
#                                                  'be', 'for', 'with', 'that',
#                                                  'marriott'],
#                                                 ['along', 'after', 'hundred',
#                                                  'ca', 'keep', 'more', 'of',
#                                                  'take', 'up', 'between',
#                                                  'everything', 'had', 'go', 'we',
#                                                  'which', 'could', 'became',
#                                                  'empty', 'much', 'neither',
#                                                  'thus', 'give', 'all', 'just',
#                                                  'already', 'formerly', 'amongst',
#                                                  'afterwards', 'but', 'four', ...]]},
#                pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#                scoring='accuracy', verbose=0),
#   'best_params': {'cvec__max_df': 0.99,
#    'cvec__max_features': 100,
#    'cvec__min_df': 2,
#    'cvec__ngram_range': (1, 3),
#    'cvec__stop_words': ['along',
#     'after',
#     'hundred',
#     'ca',
#     'keep',
#     'more',
#     'of',
#     'take',
#     'up',
#     'between',
#     'everything',
#     'had',
#     'go',
#     'we',
#     'which',
#     'could',
#     'became',
#     'empty',
#     'much',
#     'neither',
#     'thus',
#     'give',
#     'all',
#     'just',
#     'already',
#     'formerly',
#     'amongst',
#     'afterwards',
#     'but',
#     'four',
#     'may',
#     'off',
#     'what',
#     'i',
#     'in',
#     'some',
#     'sometime',
#     'wherever',
#     'both',
#     'elsewhere',
#     'everywhere',
#     'first',
#     'therein',
#     'until',
#     'really',
#     'upon',
#     'someone',
#     'who',
#     'others',
#     'under',
#     'across',
#     'below',
#     'top',
#     'for',
#     'eleven',
#     'enough',
#     'any',
#     'here',
#     'twenty',
#     'none',
#     'seeming',
#     'forty',
#     'on',
#     'are',
#     'me',
#     'never',
#     'see',
#     'thereupon',
#     'this',
#     'almost',
#     'not',
#     'part',
#     'beside',
#     'fifteen',
#     'at',
#     'how',
#     'than',
#     'though',
#     'anyway',
#     'us',
#     'various',
#     'ours',
#     'whence',
#     'whereafter',
#     'own',
#     'these',
#     'becoming',
#     'now',
#     'your',
#     'always',
#     'and',
#     'an',
#     'quite',
#     'them',
#     'does',
#     'or',
#     'hence',
#     'amount',
#     'it',
#     'moreover',
#     'rather',
#     'used',
#     'his',
#     'her',
#     'as',
#     'otherwise',
#     'himself',
#     'through',
#     'do',
#     'whenever',
#     'where',
#     'with',
#     'whoever',
#     'everyone',
#     'noone',
#     'whole',
#     'seems',
#     'behind',
#     'my',
#     'bottom',
#     'therefore',
#     'once',
#     'too',
#     'due',
#     'front',
#     'during',
#     'towards',
#     'since',
#     'anywhere',
#     'less',
#     'to',
#     'again',
#     'latter',
#     'then',
#     'nobody',
#     'itself',
#     'two',
#     'using',
#     'whither',
#     'wherein',
#     'those',
#     'name',
#     'beyond',
#     'from',
#     'even',
#     'perhaps',
#     'third',
#     'latterly',
#     'nowhere',
#     'down',
#     'thereafter',
#     'done',
#     'same',
#     'toward',
#     'five',
#     'show',
#     'that',
#     'yet',
#     'whereby',
#     'being',
#     'their',
#     'become',
#     'whereupon',
#     'against',
#     'twelve',
#     'still',
#     'within',
#     'throughout',
#     'often',
#     'has',
#     'he',
#     'is',
#     'thence',
#     'move',
#     'so',
#     'anything',
#     'ten',
#     'either',
#     'was',
#     'you',
#     'doing',
#     'next',
#     'regarding',
#     'seem',
#     'yourselves',
#     'made',
#     'whom',
#     'might',
#     'get',
#     'something',
#     'themselves',
#     'further',
#     'whatever',
#     'hereby',
#     'indeed',
#     'thereby',
#     'nor',
#     'would',
#     'via',
#     'besides',
#     'least',
#     'if',
#     'out',
#     'around',
#     'our',
#     'onto',
#     'put',
#     'somewhere',
#     'hereupon',
#     'namely',
#     'cannot',
#     'its',
#     'else',
#     'will',
#     'three',
#     'one',
#     'because',
#     'ever',
#     'no',
#     're',
#     'back',
#     'mine',
#     'six',
#     'another',
#     'there',
#     'without',
#     'before',
#     'each',
#     'whereas',
#     'meanwhile',
#     'nothing',
#     'yours',
#     'been',
#     'hereafter',
#     'several',
#     'also',
#     'every',
#     'the',
#     'by',
#     'sixty',
#     'were',
#     'among',
#     'while',
#     'yourself',
#     'why',
#     'ourselves',
#     'alone',
#     'anyone',
#     'except',
#     'seemed',
#     'hers',
#     'make',
#     'above',
#     'unless',
#     'myself',
#     'when',
#     'mostly',
#     'must',
#     'a',
#     'only',
#     'over',
#     'did',
#     'well',
#     'such',
#     'anyhow',
#     'thru',
#     'becomes',
#     'serious',
#     'eight',
#     'side',
#     'about',
#     'into',
#     'sometimes',
#     'together',
#     'can',
#     'be',
#     'per',
#     'him',
#     'whose',
#     'fifty',
#     'few',
#     'former',
#     'herself',
#     'should',
#     'they',
#     'although',
#     'however',
#     'somehow',
#     'herein',
#     'most',
#     'whether',
#     'full',
#     'many',
#     'she',
#     'beforehand',
#     'other',
#     'have',
#     'please',
#     'very',
#     'am',
#     'nevertheless',
#     'nine',
#     'call',
#     'last',
#     'say',
#     'marriott']},
#   'count_deduplicated': 531,
#   'test_data_count': 159,
#   'best_crossval_score': 0.973217926834331,
#   'train_score': 0.9853316326530612,
#   'test_score': 0.9479166666666666},
#  'unspecified': {'target': 'unspecified',
#   'model': 'lr',
#   'metric': 'accuracy',
#   'model_input': 'SentenceLemmas',
#   'split_data': {'X_train': 931     spring reserve for tax insurance ground rent a...
#    618     provide no mortgage loan event of default have...
#    493      low cash flow period mean a period a commence...
#    2118    provide that no mortgage loan event of default...
#    2191     debt yield cure mean a no mortgage loan event...
#                                  ...
#    702     the lockbox agreement will provide that the lo...
#    409     any low cash flow period threshold collateral ...
#    1580    interest accrue if any on the reserve fund wil...
#    1572                                         lockbox hard
#    2061    during the continuance of a loan event of defa...
#    Name: SentenceLemmas, Length: 1568, dtype: object,
#    'X_test': 1201    within thirty 30 day after the end of each cal...
#    1628    the mortgage lender be require to apply amount...
#    1950    the mortgage lender be require to disburse to ...
#    246     upon the occurrence and during the continuance...
#    1733    prior to the origination date the borrower hav...
#                                  ...
#    929     spring hard lockbox with in place cash managem...
#    2008     reit mean a real estate investment trust with...
#    1072    the borrower be require to because all credit ...
#    253      cash sweep cure date mean the first date foll...
#    2222    however the inability of the borrower to compl...
#    Name: SentenceLemmas, Length: 672, dtype: object,
#    'y_train': 931     0
#    618     0
#    493     0
#    2118    0
#    2191    0
#           ..
#    702     1
#    409     0
#    1580    0
#    1572    0
#    2061    0
#    Name: unspecified, Length: 1568, dtype: int64,
#    'y_test': 1201    0
#    1628    0
#    1950    0
#    246     0
#    1733    0
#           ..
#    929     0
#    2008    0
#    1072    0
#    253     0
#    2222    0
#    Name: unspecified, Length: 672, dtype: int64,
#    'indices_train': Int64Index([ 931,  618,  493, 2118, 2191, 1501,  483, 1158, 2171, 1361,
#                ...
#                 558,  125,  695, 1447, 2198,  702,  409, 1580, 1572, 2061],
#               dtype='int64', length=1568),
#    'indices_test': Int64Index([1201, 1628, 1950,  246, 1733, 1424, 1717,  767, 2009, 2233,
#                ...
#                 208, 2033, 1121, 2109,  380,  929, 2008, 1072,  253, 2222],
#               dtype='int64', length=672)},
#   'model_result': GridSearchCV(cv=3, error_score=nan,
#                estimator=Pipeline(memory=None,
#                                   steps=[('cvec',
#                                           CountVectorizer(analyzer='word',
#                                                           binary=False,
#                                                           decode_error='strict',
#                                                           dtype=<class 'numpy.int64'>,
#                                                           encoding='utf-8',
#                                                           input='content',
#                                                           lowercase=True,
#                                                           max_df=1.0,
#                                                           max_features=None,
#                                                           min_df=1,
#                                                           ngram_range=(1, 1),
#                                                           preprocessor=None,
#                                                           stop_words=None,
#                                                           strip_accents=None,
#                                                           token_pattern='(?u)...
#                                                  'be', 'for', 'with', 'that',
#                                                  'marriott'],
#                                                 ['along', 'after', 'hundred',
#                                                  'ca', 'keep', 'more', 'of',
#                                                  'take', 'up', 'between',
#                                                  'everything', 'had', 'go', 'we',
#                                                  'which', 'could', 'became',
#                                                  'empty', 'much', 'neither',
#                                                  'thus', 'give', 'all', 'just',
#                                                  'already', 'formerly', 'amongst',
#                                                  'afterwards', 'but', 'four', ...]]},
#                pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#                scoring='accuracy', verbose=0),
#   'best_params': {'cvec__max_df': 0.99,
#    'cvec__max_features': 1000,
#    'cvec__min_df': 2,
#    'cvec__ngram_range': (1, 3),
#    'cvec__stop_words': ['along',
#     'after',
#     'hundred',
#     'ca',
#     'keep',
#     'more',
#     'of',
#     'take',
#     'up',
#     'between',
#     'everything',
#     'had',
#     'go',
#     'we',
#     'which',
#     'could',
#     'became',
#     'empty',
#     'much',
#     'neither',
#     'thus',
#     'give',
#     'all',
#     'just',
#     'already',
#     'formerly',
#     'amongst',
#     'afterwards',
#     'but',
#     'four',
#     'may',
#     'off',
#     'what',
#     'i',
#     'in',
#     'some',
#     'sometime',
#     'wherever',
#     'both',
#     'elsewhere',
#     'everywhere',
#     'first',
#     'therein',
#     'until',
#     'really',
#     'upon',
#     'someone',
#     'who',
#     'others',
#     'under',
#     'across',
#     'below',
#     'top',
#     'for',
#     'eleven',
#     'enough',
#     'any',
#     'here',
#     'twenty',
#     'none',
#     'seeming',
#     'forty',
#     'on',
#     'are',
#     'me',
#     'never',
#     'see',
#     'thereupon',
#     'this',
#     'almost',
#     'not',
#     'part',
#     'beside',
#     'fifteen',
#     'at',
#     'how',
#     'than',
#     'though',
#     'anyway',
#     'us',
#     'various',
#     'ours',
#     'whence',
#     'whereafter',
#     'own',
#     'these',
#     'becoming',
#     'now',
#     'your',
#     'always',
#     'and',
#     'an',
#     'quite',
#     'them',
#     'does',
#     'or',
#     'hence',
#     'amount',
#     'it',
#     'moreover',
#     'rather',
#     'used',
#     'his',
#     'her',
#     'as',
#     'otherwise',
#     'himself',
#     'through',
#     'do',
#     'whenever',
#     'where',
#     'with',
#     'whoever',
#     'everyone',
#     'noone',
#     'whole',
#     'seems',
#     'behind',
#     'my',
#     'bottom',
#     'therefore',
#     'once',
#     'too',
#     'due',
#     'front',
#     'during',
#     'towards',
#     'since',
#     'anywhere',
#     'less',
#     'to',
#     'again',
#     'latter',
#     'then',
#     'nobody',
#     'itself',
#     'two',
#     'using',
#     'whither',
#     'wherein',
#     'those',
#     'name',
#     'beyond',
#     'from',
#     'even',
#     'perhaps',
#     'third',
#     'latterly',
#     'nowhere',
#     'down',
#     'thereafter',
#     'done',
#     'same',
#     'toward',
#     'five',
#     'show',
#     'that',
#     'yet',
#     'whereby',
#     'being',
#     'their',
#     'become',
#     'whereupon',
#     'against',
#     'twelve',
#     'still',
#     'within',
#     'throughout',
#     'often',
#     'has',
#     'he',
#     'is',
#     'thence',
#     'move',
#     'so',
#     'anything',
#     'ten',
#     'either',
#     'was',
#     'you',
#     'doing',
#     'next',
#     'regarding',
#     'seem',
#     'yourselves',
#     'made',
#     'whom',
#     'might',
#     'get',
#     'something',
#     'themselves',
#     'further',
#     'whatever',
#     'hereby',
#     'indeed',
#     'thereby',
#     'nor',
#     'would',
#     'via',
#     'besides',
#     'least',
#     'if',
#     'out',
#     'around',
#     'our',
#     'onto',
#     'put',
#     'somewhere',
#     'hereupon',
#     'namely',
#     'cannot',
#     'its',
#     'else',
#     'will',
#     'three',
#     'one',
#     'because',
#     'ever',
#     'no',
#     're',
#     'back',
#     'mine',
#     'six',
#     'another',
#     'there',
#     'without',
#     'before',
#     'each',
#     'whereas',
#     'meanwhile',
#     'nothing',
#     'yours',
#     'been',
#     'hereafter',
#     'several',
#     'also',
#     'every',
#     'the',
#     'by',
#     'sixty',
#     'were',
#     'among',
#     'while',
#     'yourself',
#     'why',
#     'ourselves',
#     'alone',
#     'anyone',
#     'except',
#     'seemed',
#     'hers',
#     'make',
#     'above',
#     'unless',
#     'myself',
#     'when',
#     'mostly',
#     'must',
#     'a',
#     'only',
#     'over',
#     'did',
#     'well',
#     'such',
#     'anyhow',
#     'thru',
#     'becomes',
#     'serious',
#     'eight',
#     'side',
#     'about',
#     'into',
#     'sometimes',
#     'together',
#     'can',
#     'be',
#     'per',
#     'him',
#     'whose',
#     'fifty',
#     'few',
#     'former',
#     'herself',
#     'should',
#     'they',
#     'although',
#     'however',
#     'somehow',
#     'herein',
#     'most',
#     'whether',
#     'full',
#     'many',
#     'she',
#     'beforehand',
#     'other',
#     'have',
#     'please',
#     'very',
#     'am',
#     'nevertheless',
#     'nine',
#     'call',
#     'last',
#     'say',
#     'marriott']},
#   'count_deduplicated': 485,
#   'test_data_count': 146,
#   'best_crossval_score': 0.9515322007574926,
#   'train_score': 0.9948979591836735,
#   'test_score': 0.9553571428571429},
#  'debt_yield_fall': {'target': 'debt_yield_fall',
#   'model': 'lr',
#   'metric': 'accuracy',
#   'model_input': 'SentenceLemmas',
#   'split_data': {'X_train': 817     the insufficiency of any balance in the ff e r...
#    572      reserve waiver revocation event period mean a...
#    548      default trigger period mean a period a commen...
#    763     a filing of a complaint in a court of competen...
#    2171    notwithstanding the foregoing a trigger period...
#                                  ...
#    1460    the borrower agree to notify mortgage lender p...
#    1279    the brand manager have agree to collect all fu...
#    1547    nothing with respect to capital expenditure re...
#    1561    provide there be sufficient amount in the grou...
#    690     during the continuance of a cash sweep period ...
#    Name: SentenceLemmas, Length: 1568, dtype: object,
#    'X_test': 223     on each monthly payment date the borrower be r...
#    1857     sff cap number mean a six at any time when th...
#    762      enforcement action mean any initiation by the...
#    851     the cash management account consist of various...
#    476     additionally if at any time during a trigger p...
#                                  ...
#    373      cash management period and cash sweep period ...
#    2176    a cash trap period cease if i in the event of ...
#    1075     cash management bank mean a depository instit...
#    1456    provide there be sufficient amount in the grou...
#    584     unless a mortgage loan event of default have o...
#    Name: SentenceLemmas, Length: 672, dtype: object,
#    'y_train': 817     0
#    572     0
#    548     0
#    763     0
#    2171    0
#           ..
#    1460    0
#    1279    0
#    1547    0
#    1561    0
#    690     0
#    Name: debt_yield_fall, Length: 1568, dtype: int64,
#    'y_test': 223     0
#    1857    0
#    762     0
#    851     0
#    476     0
#           ..
#    373     0
#    2176    1
#    1075    0
#    1456    0
#    584     0
#    Name: debt_yield_fall, Length: 672, dtype: int64,
#    'indices_train': Int64Index([ 817,  572,  548,  763, 2171, 2215, 2030, 1610,  446, 1549,
#                ...
#                1081, 1447, 1026, 1862,  525, 1460, 1279, 1547, 1561,  690],
#               dtype='int64', length=1568),
#    'indices_test': Int64Index([ 223, 1857,  762,  851,  476, 1135,  871, 1783, 1384, 1907,
#                ...
#                 379,  892, 1881, 2092, 1604,  373, 2176, 1075, 1456,  584],
#               dtype='int64', length=672)},
#   'model_result': GridSearchCV(cv=3, error_score=nan,
#                estimator=Pipeline(memory=None,
#                                   steps=[('cvec',
#                                           CountVectorizer(analyzer='word',
#                                                           binary=False,
#                                                           decode_error='strict',
#                                                           dtype=<class 'numpy.int64'>,
#                                                           encoding='utf-8',
#                                                           input='content',
#                                                           lowercase=True,
#                                                           max_df=1.0,
#                                                           max_features=None,
#                                                           min_df=1,
#                                                           ngram_range=(1, 1),
#                                                           preprocessor=None,
#                                                           stop_words=None,
#                                                           strip_accents=None,
#                                                           token_pattern='(?u)...
#                                                  'be', 'for', 'with', 'that',
#                                                  'marriott'],
#                                                 ['along', 'after', 'hundred',
#                                                  'ca', 'keep', 'more', 'of',
#                                                  'take', 'up', 'between',
#                                                  'everything', 'had', 'go', 'we',
#                                                  'which', 'could', 'became',
#                                                  'empty', 'much', 'neither',
#                                                  'thus', 'give', 'all', 'just',
#                                                  'already', 'formerly', 'amongst',
#                                                  'afterwards', 'but', 'four', ...]]},
#                pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#                scoring='accuracy', verbose=0),
#   'best_params': {'cvec__max_df': 0.99,
#    'cvec__max_features': 600,
#    'cvec__min_df': 2,
#    'cvec__ngram_range': (1, 5),
#    'cvec__stop_words': None},
#   'count_deduplicated': 184,
#   'test_data_count': 55,
#   'best_crossval_score': 0.9923469325460491,
#   'train_score': 1.0,
#   'test_score': 0.9910714285714286},
#  'mezzanine_default': {'target': 'mezzanine_default',
#   'model': 'lr',
#   'metric': 'accuracy',
#   'model_input': 'SentenceLemmas',
#   'split_data': {'X_train': 183     as the mortgage loan agreement do not require ...
#    517      priority payment cessation period mean the pe...
#    1036    the restricted account will be in the name of ...
#    667     upon the occurrence and during the continuance...
#    911      eligible account mean a separate and identifi...
#                                  ...
#    512     any trigger period that have commence solely a...
#    1264            hard lockbox with spring cash management
#    361     if no mortgage loan event of default have occu...
#    2044    a cash sweep period will commence upon the occ...
#    1179     restricted account mean one or more eligible ...
#    Name: SentenceLemmas, Length: 1568, dtype: object,
#    'X_test': 1111    the borrower be require to because all credit ...
#    1979    provide no event of default have occur and be ...
#    1877    provide no trigger period be continue all avai...
#    1165    unfunded obligations reserve on the originatio...
#    635      specified tenant trigger period mean a period...
#                                  ...
#    603     during the continuance of a mortgage loan even...
#    720     during the continuance of a mortgage loan even...
#    2028    upon the early to occur of i payment in full o...
#    71      if a hotel operating agreement cash trap perio...
#    11       budgeted operating expenses mean with respect...
#    Name: SentenceLemmas, Length: 672, dtype: object,
#    'y_train': 183     0
#    517     0
#    1036    0
#    667     0
#    911     0
#           ..
#    512     0
#    1264    0
#    361     0
#    2044    0
#    1179    0
#    Name: mezzanine_default, Length: 1568, dtype: int64,
#    'y_test': 1111    0
#    1979    0
#    1877    0
#    1165    0
#    635     0
#           ..
#    603     0
#    720     0
#    2028    0
#    71      0
#    11      0
#    Name: mezzanine_default, Length: 672, dtype: int64,
#    'indices_train': Int64Index([ 183,  517, 1036,  667,  911,   51,  513, 1153,  280,  752,
#                ...
#                 764,   30, 1543,  350, 2138,  512, 1264,  361, 2044, 1179],
#               dtype='int64', length=1568),
#    'indices_test': Int64Index([1111, 1979, 1877, 1165,  635, 1305,  344, 1327,  477,  455,
#                ...
#                1288, 1812, 1009, 1924,  178,  603,  720, 2028,   71,   11],
#               dtype='int64', length=672)},
#   'model_result': GridSearchCV(cv=3, error_score=nan,
#                estimator=Pipeline(memory=None,
#                                   steps=[('cvec',
#                                           CountVectorizer(analyzer='word',
#                                                           binary=False,
#                                                           decode_error='strict',
#                                                           dtype=<class 'numpy.int64'>,
#                                                           encoding='utf-8',
#                                                           input='content',
#                                                           lowercase=True,
#                                                           max_df=1.0,
#                                                           max_features=None,
#                                                           min_df=1,
#                                                           ngram_range=(1, 1),
#                                                           preprocessor=None,
#                                                           stop_words=None,
#                                                           strip_accents=None,
#                                                           token_pattern='(?u)...
#                                                  'be', 'for', 'with', 'that',
#                                                  'marriott'],
#                                                 ['along', 'after', 'hundred',
#                                                  'ca', 'keep', 'more', 'of',
#                                                  'take', 'up', 'between',
#                                                  'everything', 'had', 'go', 'we',
#                                                  'which', 'could', 'became',
#                                                  'empty', 'much', 'neither',
#                                                  'thus', 'give', 'all', 'just',
#                                                  'already', 'formerly', 'amongst',
#                                                  'afterwards', 'but', 'four', ...]]},
#                pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#                scoring='accuracy', verbose=0),
#   'best_params': {'cvec__max_df': 0.99,
#    'cvec__max_features': 600,
#    'cvec__min_df': 2,
#    'cvec__ngram_range': (1, 3),
#    'cvec__stop_words': ['along',
#     'after',
#     'hundred',
#     'ca',
#     'keep',
#     'more',
#     'of',
#     'take',
#     'up',
#     'between',
#     'everything',
#     'had',
#     'go',
#     'we',
#     'which',
#     'could',
#     'became',
#     'empty',
#     'much',
#     'neither',
#     'thus',
#     'give',
#     'all',
#     'just',
#     'already',
#     'formerly',
#     'amongst',
#     'afterwards',
#     'but',
#     'four',
#     'may',
#     'off',
#     'what',
#     'i',
#     'in',
#     'some',
#     'sometime',
#     'wherever',
#     'both',
#     'elsewhere',
#     'everywhere',
#     'first',
#     'therein',
#     'until',
#     'really',
#     'upon',
#     'someone',
#     'who',
#     'others',
#     'under',
#     'across',
#     'below',
#     'top',
#     'for',
#     'eleven',
#     'enough',
#     'any',
#     'here',
#     'twenty',
#     'none',
#     'seeming',
#     'forty',
#     'on',
#     'are',
#     'me',
#     'never',
#     'see',
#     'thereupon',
#     'this',
#     'almost',
#     'not',
#     'part',
#     'beside',
#     'fifteen',
#     'at',
#     'how',
#     'than',
#     'though',
#     'anyway',
#     'us',
#     'various',
#     'ours',
#     'whence',
#     'whereafter',
#     'own',
#     'these',
#     'becoming',
#     'now',
#     'your',
#     'always',
#     'and',
#     'an',
#     'quite',
#     'them',
#     'does',
#     'or',
#     'hence',
#     'amount',
#     'it',
#     'moreover',
#     'rather',
#     'used',
#     'his',
#     'her',
#     'as',
#     'otherwise',
#     'himself',
#     'through',
#     'do',
#     'whenever',
#     'where',
#     'with',
#     'whoever',
#     'everyone',
#     'noone',
#     'whole',
#     'seems',
#     'behind',
#     'my',
#     'bottom',
#     'therefore',
#     'once',
#     'too',
#     'due',
#     'front',
#     'during',
#     'towards',
#     'since',
#     'anywhere',
#     'less',
#     'to',
#     'again',
#     'latter',
#     'then',
#     'nobody',
#     'itself',
#     'two',
#     'using',
#     'whither',
#     'wherein',
#     'those',
#     'name',
#     'beyond',
#     'from',
#     'even',
#     'perhaps',
#     'third',
#     'latterly',
#     'nowhere',
#     'down',
#     'thereafter',
#     'done',
#     'same',
#     'toward',
#     'five',
#     'show',
#     'that',
#     'yet',
#     'whereby',
#     'being',
#     'their',
#     'become',
#     'whereupon',
#     'against',
#     'twelve',
#     'still',
#     'within',
#     'throughout',
#     'often',
#     'has',
#     'he',
#     'is',
#     'thence',
#     'move',
#     'so',
#     'anything',
#     'ten',
#     'either',
#     'was',
#     'you',
#     'doing',
#     'next',
#     'regarding',
#     'seem',
#     'yourselves',
#     'made',
#     'whom',
#     'might',
#     'get',
#     'something',
#     'themselves',
#     'further',
#     'whatever',
#     'hereby',
#     'indeed',
#     'thereby',
#     'nor',
#     'would',
#     'via',
#     'besides',
#     'least',
#     'if',
#     'out',
#     'around',
#     'our',
#     'onto',
#     'put',
#     'somewhere',
#     'hereupon',
#     'namely',
#     'cannot',
#     'its',
#     'else',
#     'will',
#     'three',
#     'one',
#     'because',
#     'ever',
#     'no',
#     're',
#     'back',
#     'mine',
#     'six',
#     'another',
#     'there',
#     'without',
#     'before',
#     'each',
#     'whereas',
#     'meanwhile',
#     'nothing',
#     'yours',
#     'been',
#     'hereafter',
#     'several',
#     'also',
#     'every',
#     'the',
#     'by',
#     'sixty',
#     'were',
#     'among',
#     'while',
#     'yourself',
#     'why',
#     'ourselves',
#     'alone',
#     'anyone',
#     'except',
#     'seemed',
#     'hers',
#     'make',
#     'above',
#     'unless',
#     'myself',
#     'when',
#     'mostly',
#     'must',
#     'a',
#     'only',
#     'over',
#     'did',
#     'well',
#     'such',
#     'anyhow',
#     'thru',
#     'becomes',
#     'serious',
#     'eight',
#     'side',
#     'about',
#     'into',
#     'sometimes',
#     'together',
#     'can',
#     'be',
#     'per',
#     'him',
#     'whose',
#     'fifty',
#     'few',
#     'former',
#     'herself',
#     'should',
#     'they',
#     'although',
#     'however',
#     'somehow',
#     'herein',
#     'most',
#     'whether',
#     'full',
#     'many',
#     'she',
#     'beforehand',
#     'other',
#     'have',
#     'please',
#     'very',
#     'am',
#     'nevertheless',
#     'nine',
#     'call',
#     'last',
#     'say',
#     'marriott']},
#   'count_deduplicated': 67,
#   'test_data_count': 20,
#   'best_crossval_score': 0.9917083629419623,
#   'train_score': 0.9993622448979592,
#   'test_score': 0.9866071428571429},
#  'bankruptcy': {'target': 'bankruptcy',
#   'model': 'lr',
#   'metric': 'accuracy',
#   'model_input': 'SentenceLemmas',
#   'split_data': {'X_train': 351      debt yield cure will mean a no mortgage event...
#    2191     debt yield cure mean a no mortgage loan event...
#    1104    the borrower have establish and be require to ...
#    1603    upon completion of the required renovation wor...
#    1914    upon the occurrence and during the continuance...
#                                  ...
#    265      debt yield trigger event cure mean i that the...
#    1662    in the event any such amount be mistakenly del...
#    751      eligible account mean an identifiable account...
#    603     during the continuance of a mortgage loan even...
#    1456    provide there be sufficient amount in the grou...
#    Name: SentenceLemmas, Length: 1568, dtype: object,
#    'X_test': 208     upon the request of the borrower at any time t...
#    923     the borrower be require to on or prior to the ...
#    577     unless a mortgage loan event of default have o...
#    1074    upon the occurrence of a casualty or condemnat...
#    465     mortgage lender will disburse to the borrower ...
#                                  ...
#    717     during the continuance of a mortgage loan even...
#    2013     debt yield failure mean the failure to satisf...
#    507     fund on deposit in the restricted account may ...
#    506     under the term of the mortgage loan documents ...
#    975     a ground rent reserve account have be establis...
#    Name: SentenceLemmas, Length: 672, dtype: object,
#    'y_train': 351     0
#    2191    0
#    1104    0
#    1603    0
#    1914    0
#           ..
#    265     0
#    1662    0
#    751     0
#    603     0
#    1456    0
#    Name: bankruptcy, Length: 1568, dtype: int64,
#    'y_test': 208     0
#    923     0
#    577     0
#    1074    0
#    465     0
#           ..
#    717     0
#    2013    0
#    507     0
#    506     0
#    975     0
#    Name: bankruptcy, Length: 672, dtype: int64,
#    'indices_train': Int64Index([ 351, 2191, 1104, 1603, 1914,  411, 1924,  702, 1816, 2197,
#                ...
#                2077, 1781, 1278,  730,  857,  265, 1662,  751,  603, 1456],
#               dtype='int64', length=1568),
#    'indices_test': Int64Index([ 208,  923,  577, 1074,  465,  346, 1432,  214,  895, 1671,
#                ...
#                2064,  180,  668,   59, 1980,  717, 2013,  507,  506,  975],
#               dtype='int64', length=672)},
#   'model_result': GridSearchCV(cv=3, error_score=nan,
#                estimator=Pipeline(memory=None,
#                                   steps=[('cvec',
#                                           CountVectorizer(analyzer='word',
#                                                           binary=False,
#                                                           decode_error='strict',
#                                                           dtype=<class 'numpy.int64'>,
#                                                           encoding='utf-8',
#                                                           input='content',
#                                                           lowercase=True,
#                                                           max_df=1.0,
#                                                           max_features=None,
#                                                           min_df=1,
#                                                           ngram_range=(1, 1),
#                                                           preprocessor=None,
#                                                           stop_words=None,
#                                                           strip_accents=None,
#                                                           token_pattern='(?u)...
#                                                  'be', 'for', 'with', 'that',
#                                                  'marriott'],
#                                                 ['along', 'after', 'hundred',
#                                                  'ca', 'keep', 'more', 'of',
#                                                  'take', 'up', 'between',
#                                                  'everything', 'had', 'go', 'we',
#                                                  'which', 'could', 'became',
#                                                  'empty', 'much', 'neither',
#                                                  'thus', 'give', 'all', 'just',
#                                                  'already', 'formerly', 'amongst',
#                                                  'afterwards', 'but', 'four', ...]]},
#                pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#                scoring='accuracy', verbose=0),
#   'best_params': {'cvec__max_df': 0.99,
#    'cvec__max_features': 1000,
#    'cvec__min_df': 2,
#    'cvec__ngram_range': (1, 3),
#    'cvec__stop_words': ['the',
#     'and',
#     'a',
#     'to',
#     'it',
#     'be',
#     'for',
#     'with',
#     'that',
#     'marriott']},
#   'count_deduplicated': 44,
#   'test_data_count': 13,
#   'best_crossval_score': 0.9917095839163487,
#   'train_score': 0.9987244897959183,
#   'test_score': 0.9985119047619048},
#  'tenant_failure': {'target': 'tenant_failure',
#   'model': 'lr',
#   'metric': 'f1',
#   'model_input': 'SentenceLemmas',
#   'split_data': {'X_train': 1078    additionally if at any time the lender reasona...
#    103     so long as no loan event of default be then co...
#    1387     true up payment mean a payment into the appli...
#    2176    a cash trap period cease if i in the event of ...
#    1151    the mortgage lender be require to release fund...
#                                  ...
#    1382    see description of the mortgage loan cash mana...
#    16      during a trigger period or while an event of d...
#    393     during a trigger period the money be require t...
#    1333    for a detailed description of the reserve acco...
#    1130     debt yield determination date mean the date o...
#    Name: SentenceLemmas, Length: 1568, dtype: object,
#    'X_test': 1684    the account in which the replacements reserve ...
#    2128    after payment of i all cost and expense of the...
#    211     in addition so long as no mortgage loan event ...
#    1473    all revenue derive from the property other tha...
#    1395    mortgage lender will disburse capital expendit...
#                                  ...
#    1845    pursuant to any excess cash flow guaranty guar...
#    1368    the borrower agree to notify mortgage lender p...
#    1129    the borrower and the property manager be requi...
#    586     notwithstanding anything in this tax and insur...
# ...
#     'myself',
#     'when',
#     'mostly',
#     'must',
#     'a',
#     'only',
#     'over',
#     'did',
#     'well',
#     'such',
#     'anyhow',
#     'thru',
#     'becomes',
#     'serious',
#     'eight',
#     'side',
#     'about',
#     'into',
#     'sometimes',
#     'together',
#     'can',
#     'be',
#     'per',
#     'him',
#     'whose',
#     'fifty',
#     'few',
#     'former',
#     'herself',
#     'should',
#     'they',
#     'although',
#     'however',
#     'somehow',
#     'herein',
#     'most',
#     'whether',
#     'full',
#     'many',
#     'she',
#     'beforehand',
#     'other',
#     'have',
#     'please',
#     'very',
#     'am',
#     'nevertheless',
#     'nine',
#     'call',
#     'last',
#     'say',
#     'marriott']},
#   'count_deduplicated': 9,
#   'test_data_count': 3,
#   'best_crossval_score': 0.7777777777777777,
#   'train_score': 1.0,
#   'test_score': 0.5},
#  'mezzanine_outstanding': {'target': 'mezzanine_outstanding',
#   'model': 'lr',
#   'metric': 'f1',
#   'model_input': 'SentenceLemmas',
#   'split_data': {'X_train': 351      debt yield cure will mean a no mortgage event...
#    1335    borrower be also require to i within 12 busine...
#    1436     approved leasing costs mean actual out of poc...
#    817     the insufficiency of any balance in the ff e r...
#    2069    however if a lease sweep period be continue du...
#                                  ...
#    1982    the lender will pay the insurance premium at t...
#    1260    all interest or other earning on the reserve a...
#    1278    borrower be require to because the brand manag...
#    550      trigger period mean a a default trigger perio...
#    791      eligible institution mean a federal or state ...
#    Name: SentenceLemmas, Length: 1568, dtype: object,
#    'X_test': 1190    the borrower will pay all sum due under and ot...
#    1814    during any cash management period the borrower...
#    158     provide that no mortgage loan event of default...
#    425     upon the cure of any trigger period and provid...
#    452     under the term of the mortgage loan documents ...
#                                  ...
#    2236    if a cash management period have not occur or ...
#    202     the mortgage loan documents require the borrow...
#    70      provide that no mortgage loan event of default...
#    260     upon the occurrence and during the continuance...
#    1241    in no instance will the borrower request nor w...
#    Name: SentenceLemmas, Length: 672, dtype: object,
#    'y_train': 351     0
#    1335    0
#    1436    0
#    817     0
#    2069    0
#           ..
#    1982    0
#    1260    0
#    1278    0
#    550     0
#    791     0
#    Name: mezzanine_outstanding, Length: 1568, dtype: int64,
#    'y_test': 1190    0
#    1814    0
#    158     0
#    425     0
#    452     0
#           ..
#    2236    0
#    202     0
#    70      0
#    260     0
#    1241    0
#    Name: mezzanine_outstanding, Length: 672, dtype: int64,
#    'indices_train': Int64Index([ 351, 1335, 1436,  817, 2069, 1741, 1818,  531,  455,  770,
#                ...
#                 570, 2058, 1214,   17,   14, 1982, 1260, 1278,  550,  791],
#               dtype='int64', length=1568),
#    'indices_test': Int64Index([1190, 1814,  158,  425,  452,  345, 1486,  437, 1757,  177,
#                ...
#                1253,  649, 1160, 1616,  637, 2236,  202,   70,  260, 1241],
#               dtype='int64', length=672)},
#   'model_result': GridSearchCV(cv=3, error_score=nan,
#                estimator=Pipeline(memory=None,
#                                   steps=[('cvec',
#                                           CountVectorizer(analyzer='word',
#                                                           binary=False,
#                                                           decode_error='strict',
#                                                           dtype=<class 'numpy.int64'>,
#                                                           encoding='utf-8',
#                                                           input='content',
#                                                           lowercase=True,
#                                                           max_df=1.0,
#                                                           max_features=None,
#                                                           min_df=1,
#                                                           ngram_range=(1, 1),
#                                                           preprocessor=None,
#                                                           stop_words=None,
#                                                           strip_accents=None,
#                                                           token_pattern='(?u)...
#                                                  'be', 'for', 'with', 'that',
#                                                  'marriott'],
#                                                 ['along', 'after', 'hundred',
#                                                  'ca', 'keep', 'more', 'of',
#                                                  'take', 'up', 'between',
#                                                  'everything', 'had', 'go', 'we',
#                                                  'which', 'could', 'became',
#                                                  'empty', 'much', 'neither',
#                                                  'thus', 'give', 'all', 'just',
#                                                  'already', 'formerly', 'amongst',
#                                                  'afterwards', 'but', 'four', ...]]},
#                pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#                scoring='f1', verbose=0),
#   'best_params': {'cvec__max_df': 0.99,
#    'cvec__max_features': 200,
#    'cvec__min_df': 2,
#    'cvec__ngram_range': (1, 2),
#    'cvec__stop_words': None},
#   'count_deduplicated': 8,
#   'test_data_count': 2,
#   'best_crossval_score': 0.3333333333333333,
#   'train_score': 0.9090909090909091,
#   'test_score': 0.0},
#  'aggregate_dscr_fall': {'target': 'aggregate_dscr_fall',
#   'model': 'lr',
#   'metric': 'f1',
#   'model_input': 'SentenceLemmas',
#   'split_data': {'X_train': 344     from and after the occurrence of the first cas...
#    1329    borrower be require to use commercially reason...
#    1430    borrower be require to deposit or because to b...
#    811             marriott mean marriott international inc
#    2066     occupancy conditions mean with respect to the...
#                                  ...
#    1979    provide no event of default have occur and be ...
#    1254    the reit subsidiary will be permit no less fre...
#    1272    unfunded obligations reserve on the originatio...
#    544     during a trigger period fund in the deposit ac...
#    785     in the event that the borrower receive a fee p...
#    Name: SentenceLemmas, Length: 1568, dtype: object,
#    'X_test': 1184    the cash management account will have a title ...
#    1809    upon the occurrence and during the continuance...
#    151     the loan documents require the borrower to mai...
#    419     on each payment date occur on and after the oc...
#    446     during the continuance of any trigger period o...
#                                  ...
#    2235    during a cash management period all amount in ...
#    195     notwithstanding the foregoing a pool b trigger...
#    69      if neither a cash trap period nor a hotel oper...
#    253      cash sweep cure date mean the first date foll...
#    1235    in addition the borrower be require to deposit...
#    Name: SentenceLemmas, Length: 672, dtype: object,
#    'y_train': 344     0
#    1329    0
#    1430    0
#    811     0
#    2066    0
#           ..
#    1979    0
#    1254    0
#    1272    0
#    544     0
#    785     0
#    Name: aggregate_dscr_fall, Length: 1568, dtype: int64,
#    'y_test': 1184    0
#    1809    0
#    151     0
#    419     0
#    446     0
#           ..
#    2235    0
#    195     0
#    69      0
#    253     0
#    1235    0
#    Name: aggregate_dscr_fall, Length: 672, dtype: int64,
#    'indices_train': Int64Index([ 344, 1329, 1430,  811, 2066, 1735, 1813,  525,  449,  764,
#                ...
#                 564, 2055, 1208,   18,   15, 1979, 1254, 1272,  544,  785],
#               dtype='int64', length=1568),
#    'indices_test': Int64Index([1184, 1809,  151,  419,  446,  338, 1480,  431, 1751,  170,
#                ...
#                1247,  643, 1154, 1610,  631, 2235,  195,   69,  253, 1235],
#               dtype='int64', length=672)},
#   'model_result': GridSearchCV(cv=3, error_score=nan,
#                estimator=Pipeline(memory=None,
#                                   steps=[('cvec',
#                                           CountVectorizer(analyzer='word',
#                                                           binary=False,
#                                                           decode_error='strict',
#                                                           dtype=<class 'numpy.int64'>,
#                                                           encoding='utf-8',
#                                                           input='content',
#                                                           lowercase=True,
#                                                           max_df=1.0,
#                                                           max_features=None,
#                                                           min_df=1,
#                                                           ngram_range=(1, 1),
#                                                           preprocessor=None,
#                                                           stop_words=None,
#                                                           strip_accents=None,
#                                                           token_pattern='(?u)...
#                                                  'be', 'for', 'with', 'that',
#                                                  'marriott'],
#                                                 ['along', 'after', 'hundred',
#                                                  'ca', 'keep', 'more', 'of',
#                                                  'take', 'up', 'between',
#                                                  'everything', 'had', 'go', 'we',
#                                                  'which', 'could', 'became',
#                                                  'empty', 'much', 'neither',
#                                                  'thus', 'give', 'all', 'just',
#                                                  'already', 'formerly', 'amongst',
#                                                  'afterwards', 'but', 'four', ...]]},
#                pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#                scoring='f1', verbose=0),
#   'best_params': {'cvec__max_df': 0.99,
#    'cvec__max_features': 100,
#    'cvec__min_df': 2,
#    'cvec__ngram_range': (1, 2),
#    'cvec__stop_words': None},
#   'count_deduplicated': 8,
#   'test_data_count': 2,
#   'best_crossval_score': 0.8888888888888888,
#   'train_score': 1.0,
#   'test_score': 0.6666666666666666},
#  'delayed_repayment': {'target': 'delayed_repayment',
#   'model': 'lr',
#   'metric': 'f1',
#   'model_input': 'SentenceLemmas',
#   'split_data': {'X_train': 1983    if such documentation relate to the pbo taxes ...
#    1374     specified tenant space mean that portion of t...
#    611     provide that no mortgage loan event of default...
#    825      ground lease mean that certain ground lease d...
#    1035    the borrower be require to establish a propert...
#                                  ...
#    193     notwithstanding the foregoing a pool a trigger...
#    403     upon the first occurrence of a trigger period ...
#    1234     university centre restoration budget mean the...
#    2092    a low debt yield period will commence if as of...
#    1251    the lender be not be require to disburse the u...
#    Name: SentenceLemmas, Length: 1568, dtype: object,
#    'X_test': 1846    the excess cash flow guaranty to the extent on...
#    765     each of the above describe reserve account be ...
#    931     spring reserve for tax insurance ground rent a...
#    1862    notwithstanding the foregoing or anything to t...
#    1664    for purpose of the foregoing any determination...
#                                  ...
#    1385    borrower be also require to i within 12 busine...
#    632     provide that no mortgage loan event of default...
#    1923    mortgage lender will pay say item or disburse ...
#    608     follow the termination of the trigger period d...
#    1233     university centre restoration costs mean thos...
#    Name: SentenceLemmas, Length: 672, dtype: object,
#    'y_train': 1983    0
#    1374    0
#    611     0
#    825     0
#    1035    0
#           ..
#    193     0
#    403     0
#    1234    0
#    2092    0
#    1251    0
#    Name: delayed_repayment, Length: 1568, dtype: int64,
#    'y_test': 1846    0
#    765     0
#    931     0
#    1862    0
#    1664    0
#           ..
#    1385    0
#    632     0
#    1923    0
#    608     0
#    1233    0
#    Name: delayed_repayment, Length: 672, dtype: int64,
#    'indices_train': Int64Index([1983, 1374,  611,  825, 1035, 1693, 1389, 1911,  657, 2208,
#                ...
#                1049, 1804, 1903, 1974, 1753,  193,  403, 1234, 2092, 1251],
#               dtype='int64', length=1568),
#    'indices_test': Int64Index([1846,  765,  931, 1862, 1664, 1663, 2119, 1172, 1467,  790,
#                ...
#                  59, 1209,  145,  691,  318, 1385,  632, 1923,  608, 1233],
#               dtype='int64', length=672)},
#   'model_result': GridSearchCV(cv=3, error_score=nan,
#                estimator=Pipeline(memory=None,
#                                   steps=[('cvec',
#                                           CountVectorizer(analyzer='word',
#                                                           binary=False,
#                                                           decode_error='strict',
#                                                           dtype=<class 'numpy.int64'>,
#                                                           encoding='utf-8',
#                                                           input='content',
#                                                           lowercase=True,
#                                                           max_df=1.0,
#                                                           max_features=None,
#                                                           min_df=1,
#                                                           ngram_range=(1, 1),
#                                                           preprocessor=None,
#                                                           stop_words=None,
#                                                           strip_accents=None,
#                                                           token_pattern='(?u)...
#                                                  'be', 'for', 'with', 'that',
#                                                  'marriott'],
#                                                 ['along', 'after', 'hundred',
#                                                  'ca', 'keep', 'more', 'of',
#                                                  'take', 'up', 'between',
#                                                  'everything', 'had', 'go', 'we',
#                                                  'which', 'could', 'became',
#                                                  'empty', 'much', 'neither',
#                                                  'thus', 'give', 'all', 'just',
#                                                  'already', 'formerly', 'amongst',
#                                                  'afterwards', 'but', 'four', ...]]},
#                pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#                scoring='f1', verbose=0),
#   'best_params': {'cvec__max_df': 0.99,
#    'cvec__max_features': 100,
#    'cvec__min_df': 2,
#    'cvec__ngram_range': (1, 2),
#    'cvec__stop_words': None},
#   'count_deduplicated': 3,
#   'test_data_count': 1,
#   'best_crossval_score': 0.0,
#   'train_score': 1.0,
#   'test_score': 0.0}}

# %%
# Print a summary table with all fitting results
results_df
# Out:
#                        target model    metric     model_input  \
# 0                  nontrigger    lr  accuracy  SentenceLemmas
# 1                loan_default    lr  accuracy  SentenceLemmas
# 2                 unspecified    lr  accuracy  SentenceLemmas
# 3             debt_yield_fall    lr  accuracy  SentenceLemmas
# 4           mezzanine_default    lr  accuracy  SentenceLemmas
# 5                  bankruptcy    lr  accuracy  SentenceLemmas
# 6              tenant_failure    lr        f1  SentenceLemmas
# 7                 renovations    lr        f1  SentenceLemmas
# 8   aggregate_debt_yield_fall    lr        f1  SentenceLemmas
# 9                   dscr_fall    lr        f1  SentenceLemmas
# 10       operator_termination    lr        f1  SentenceLemmas
# 11        sponsor_termination    lr        f1  SentenceLemmas
# 12                        sff    lr        f1  SentenceLemmas
# 13      mezzanine_outstanding    lr        f1  SentenceLemmas
# 14        aggregate_dscr_fall    lr        f1  SentenceLemmas
# 15          delayed_repayment    lr        f1  SentenceLemmas
#
#                                            split_data  \
# 0   {'X_train': ['the lender be require to maintai...
# 1   {'X_train': ['provide there be sufficient amou...
# 2   {'X_train': ['spring reserve for tax insurance...
# 3   {'X_train': ['the insufficiency of any balance...
# 4   {'X_train': ['as the mortgage loan agreement d...
# 5   {'X_train': [' debt yield cure will mean a no ...
# 6   {'X_train': ['additionally if at any time the ...
# 7   {'X_train': ['any excess cash flow reserve fun...
# 8   {'X_train': ['additionally if at any time duri...
# 9   {'X_train': ['the borrower have agree to notif...
# 10  {'X_train': ['the borrower will upon the openi...
# 11  {'X_train': ['the borrower be require to depos...
# 12  {'X_train': [' cash management bank mean a dep...
# 13  {'X_train': [' debt yield cure will mean a no ...
# 14  {'X_train': ['from and after the occurrence of...
# 15  {'X_train': ['if such documentation relate to ...
#
#                                          model_result  \
# 0   GridSearchCV(cv=3, error_score=nan,\n         ...
# 1   GridSearchCV(cv=3, error_score=nan,\n         ...
# 2   GridSearchCV(cv=3, error_score=nan,\n         ...
# 3   GridSearchCV(cv=3, error_score=nan,\n         ...
# 4   GridSearchCV(cv=3, error_score=nan,\n         ...
# 5   GridSearchCV(cv=3, error_score=nan,\n         ...
# 6   GridSearchCV(cv=3, error_score=nan,\n         ...
# 7   GridSearchCV(cv=3, error_score=nan,\n         ...
# 8   GridSearchCV(cv=3, error_score=nan,\n         ...
# 9   GridSearchCV(cv=3, error_score=nan,\n         ...
# 10  GridSearchCV(cv=3, error_score=nan,\n         ...
# 11  GridSearchCV(cv=3, error_score=nan,\n         ...
# 12  GridSearchCV(cv=3, error_score=nan,\n         ...
# 13  GridSearchCV(cv=3, error_score=nan,\n         ...
# 14  GridSearchCV(cv=3, error_score=nan,\n         ...
# 15  GridSearchCV(cv=3, error_score=nan,\n         ...
#
#                                           best_params  count_deduplicated  \
# 0   {'cvec__max_df': 0.99, 'cvec__max_features': 1...                1030
# 1   {'cvec__max_df': 0.99, 'cvec__max_features': 1...                 531
# 2   {'cvec__max_df': 0.99, 'cvec__max_features': 1...                 485
# 3   {'cvec__max_df': 0.99, 'cvec__max_features': 6...                 184
# 4   {'cvec__max_df': 0.99, 'cvec__max_features': 6...                  67
# 5   {'cvec__max_df': 0.99, 'cvec__max_features': 1...                  44
# 6   {'cvec__max_df': 0.99, 'cvec__max_features': 4...                  74
# 7   {'cvec__max_df': 0.99, 'cvec__max_features': 1...                  24
# 8   {'cvec__max_df': 0.99, 'cvec__max_features': 2...                  18
# 9   {'cvec__max_df': 0.99, 'cvec__max_features': 2...                  23
# 10  {'cvec__max_df': 0.99, 'cvec__max_features': 6...                  17
# 11  {'cvec__max_df': 0.99, 'cvec__max_features': 1...                  14
# 12  {'cvec__max_df': 0.99, 'cvec__max_features': 1...                   9
# 13  {'cvec__max_df': 0.99, 'cvec__max_features': 2...                   8
# 14  {'cvec__max_df': 0.99, 'cvec__max_features': 1...                   8
# 15  {'cvec__max_df': 0.99, 'cvec__max_features': 1...                   3
#
#     test_data_count  best_crossval_score  train_score  test_score
# 0               309             0.976411     0.992347    0.976190
# 1               159             0.973218     0.985332    0.947917
# 2               146             0.951532     0.994898    0.955357
# 3                55             0.992347     1.000000    0.991071
# 4                20             0.991708     0.999362    0.986607
# 5                13             0.991710     0.998724    0.998512
# 6                22             0.858462     1.000000    0.933333
# 7                 7             0.911681     0.969697    0.666667
# 8                 5             0.490476     1.000000    0.666667
# 9                 7             0.708995     0.967742    0.444444
# 10                5             0.761905     1.000000    0.500000
# 11                4             0.419048     1.000000    0.571429
# 12                3             0.777778     1.000000    0.500000
# 13                2             0.333333     0.909091    0.000000
# 14                2             0.888889     1.000000    0.666667
# 15                1             0.000000     1.000000    0.000000

# %%
# Export summary table
results_df.to_csv(f'../data/exported_data/results_df_06_15_20.csv')

# %% [markdown]
# ## Plotting functions: features and confusion matrices

# %%
def coefficient_plots(results_df):
    '''
    Plots the top 10 and bottom 10 coefficients for each category
    '''
    for row in results_df.itertuples(index = True, name = 'Pandas'):
        names = getattr(row, "model_result").best_estimator_.steps[0][1].get_feature_names()
        betas = getattr(row, "model_result").best_estimator_.named_steps['lr']
        coef = np.array(betas.coef_).tolist()[0]
        top_words = list(zip(names, coef))
        df_coefs = pd.DataFrame(top_words).rename(columns = {0: 'word', 1: 'coef'}).sort_values(by = 'coef', ascending = True)
        

        coefs_1 = df_coefs.sort_values(by = 'coef', ascending=False).tail(10) # getting the top 10 coefficients
        coefs_2 = df_coefs.sort_values(by = 'coef', ascending=False).head(10) # getting the bottom 10 coefficients
        coefs = pd.concat([coefs_2, coefs_1], axis = 0) # merging the two into one
        # plotting importance
        plt.figure(figsize=(10, 8)) # plotting the coefficients
        plt.title(f'Feature Coefficients for {getattr(row,"target").replace("_", " ").title()}', fontsize=25)
        sns.set_style("darkgrid")
        sns.barplot(data=coefs,
                    x= 'coef',
                    y='word',
                    orient='h',
                    palette = 'PuBuGn_d')
        plt.xlabel('coefficient', fontsize=15)
        plt.ylabel('feature', fontsize=15)
        plt.tick_params(labelsize=15)

# %%
# Call the coefficient plot function
coefficient_plots(results_df)

# %%
def create_confusion_matrix(results_df):
    '''
    Plots the top 10 and bottom 10 coefficients for each category
    '''
    for row in results_df.itertuples(index = True, name = 'Pandas'):
        best_model = getattr(row, "model_result").best_estimator_
        preds = best_model.predict(getattr(row, "split_data")['X_test'])
        
        cm_test = confusion_matrix(getattr(row, "split_data")['y_test'], preds)
        cm_test = pd.DataFrame(cm_test, columns=['Predicted Negative','Predicted Positive'], 
                       index=['Actual Negative','Actual Positive'])
        plt.figure(figsize = (6,6))
        ax = plt.subplot()
        sns.heatmap(cm_test, 
            annot=True, 
            ax = ax, 
            fmt='g', 
            cbar=False,
            cmap="Blues"); #annot=True to annotate cells

        # labels, title and ticks
        ax.set_title(f'Confusion Matrix - {getattr(row,"target").replace("_", " ").title()}', size=16)
        ax.set_xlabel('Predicted', size=14)
        ax.set_ylabel('Actual', size=14)
        ax.xaxis.set_ticklabels(['Negative', 'Positive'])
        ax.yaxis.set_ticklabels(['Negative', 'Positive']);

# %%
create_confusion_matrix(results_df)

# %%
# To allow us to better read the Sentences
pd.set_option('display.max_colwidth', None)

# %%
results_df.reset_index(inplace = True)

# %%
def create_summary_result_table(results_df):
    
    global final_misclassified_as_true
    global final_misclassified_as_false
    
    target_list = results_df['target'].values.tolist()
    final_columns = ['prediction', 'actual'] + target_list
    
    final_misclassified_as_true = pd.DataFrame(columns = final_columns)
    final_misclassified_as_false = pd.DataFrame(columns = final_columns)

    for row in results_df.itertuples(index = True, name = 'Pandas'):
        best_model = getattr(row, "model_result").best_estimator_
        preds = best_model.predict(getattr(row, "split_data")['X_test'])
        
        index_list = list(getattr(row, "split_data")['indices_test'])
        preds_list = list(preds.astype(int))
        actuals_list = list(getattr(row, "split_data")['y_test'].astype(int))
        
        results = pd.DataFrame({'index': index_list, 'prediction': preds_list, 'actual': actuals_list})
        results.set_index('index', inplace = True)
        
        misclassified = results[results['prediction'] != results['actual']]
        misclassified = misclassified.merge(df, how = 'left', left_index = True, right_index = True)
        misclassified_as_true = misclassified.loc[misclassified['prediction'] == 1]
        misclassified_as_false = misclassified.loc[misclassified['prediction'] == 0]
        
        misclassified_as_true_summary = misclassified_as_true.drop(columns = ['Document', 'Sentence', 'SentenceTokens', 'SentenceLemmas'])
        misclassified_as_false_summary = misclassified_as_false.drop(columns = ['Document', 'Sentence', 'SentenceTokens', 'SentenceLemmas'])
        
        
        misclassified_as_true_summary.loc[f'{getattr(row, "target")}',:] = misclassified_as_true.sum(axis = 0).copy(deep = True)
        misclassified_as_false_summary.loc[f'{getattr(row, "target")}',:] = misclassified_as_false.sum(axis = 0).copy(deep = True)

        
        final_misclassified_as_true = final_misclassified_as_true.append(misclassified_as_true_summary.iloc[-1], ignore_index = False)
        final_misclassified_as_false = final_misclassified_as_false.append(misclassified_as_false_summary.iloc[-1], ignore_index = False)
        
    return final_misclassified_as_true
    return final_misclassified_as_false

# %%
create_summary_result_table(results_df)
# Out:
#                            prediction  actual nontrigger loan_default  \
# nontrigger                        7.0     0.0          0            1
# loan_default                     15.0     0.0          3            0
# unspecified                      14.0     0.0          4            5
# debt_yield_fall                   2.0     0.0          0            2
# mezzanine_default                 5.0     0.0          1            2
# bankruptcy                        0.0     0.0          0            0
# tenant_failure                    2.0     0.0          0            1
# renovations                       1.0     0.0          1            0
# aggregate_debt_yield_fall         1.0     0.0          0            0
# dscr_fall                         0.0     0.0          0            0
# operator_termination              1.0     0.0          0            0
# sponsor_termination               1.0     0.0          0            1
# sff                               0.0     0.0          0            0
# mezzanine_outstanding             0.0     0.0          0            0
# aggregate_dscr_fall               0.0     0.0          0            0
# delayed_repayment                 0.0     0.0          0            0
#
#                           unspecified debt_yield_fall mezzanine_default  \
# nontrigger                          0               1                 0
# loan_default                        7               3                 1
# unspecified                         0               0                 0
# debt_yield_fall                     0               0                 1
# mezzanine_default                   1               2                 0
# bankruptcy                          0               0                 0
# tenant_failure                      1               0                 0
# renovations                         0               0                 0
# aggregate_debt_yield_fall           0               1                 0
# dscr_fall                           0               0                 0
# operator_termination                0               0                 0
# sponsor_termination                 0               0                 0
# sff                                 0               0                 0
# mezzanine_outstanding               0               0                 0
# aggregate_dscr_fall                 0               0                 0
# delayed_repayment                   0               0                 0
#
#                           bankruptcy tenant_failure renovations  \
# nontrigger                         1              1           2
# loan_default                       0              1           0
# unspecified                        0              0           0
# debt_yield_fall                    0              0           0
# mezzanine_default                  0              3           0
# bankruptcy                         0              0           0
# tenant_failure                     0              0           0
# renovations                        0              0           0
# aggregate_debt_yield_fall          0              0           0
# dscr_fall                          0              0           0
# operator_termination               0              0           0
# sponsor_termination                0              0           0
# sff                                0              0           0
# mezzanine_outstanding              0              0           0
# aggregate_dscr_fall                0              0           0
# delayed_repayment                  0              0           0
#
#                           aggregate_debt_yield_fall dscr_fall  \
# nontrigger                                        0         0
# loan_default                                      0         0
# unspecified                                       0         0
# debt_yield_fall                                   1         0
# mezzanine_default                                 0         0
# bankruptcy                                        0         0
# tenant_failure                                    0         0
# renovations                                       0         0
# aggregate_debt_yield_fall                         0         0
# dscr_fall                                         0         0
# operator_termination                              0         0
# sponsor_termination                               0         0
# sff                                               0         0
# mezzanine_outstanding                             0         0
# aggregate_dscr_fall                               0         0
# delayed_repayment                                 0         0
#
#                           operator_termination sponsor_termination sff  \
# nontrigger                                   0                   0   1
# loan_default                                 0                   0   0
# unspecified                                  2                   0   1
# debt_yield_fall                              0                   0   0
# mezzanine_default                            0                   0   0
# bankruptcy                                   0                   0   0
# tenant_failure                               0                   0   0
# renovations                                  0                   0   0
# aggregate_debt_yield_fall                    0                   0   0
# dscr_fall                                    0                   0   0
# operator_termination                         0                   0   0
# sponsor_termination                          0                   0   0
# sff                                          0                   0   0
# mezzanine_outstanding                        0                   0   0
# aggregate_dscr_fall                          0                   0   0
# delayed_repayment                            0                   0   0
#
#                           mezzanine_outstanding aggregate_dscr_fall  \
# nontrigger                                    0                   0
# loan_default                                  0                   0
# unspecified                                   2                   0
# debt_yield_fall                               0                   0
# mezzanine_default                             0                   0
# bankruptcy                                    0                   0
# tenant_failure                                0                   0
# renovations                                   0                   0
# aggregate_debt_yield_fall                     0                   0
# dscr_fall                                     0                   0
# operator_termination                          1                   0
# sponsor_termination                           0                   0
# sff                                           0                   0
# mezzanine_outstanding                         0                   0
# aggregate_dscr_fall                           0                   0
# delayed_repayment                             0                   0
#
#                           delayed_repayment
# nontrigger                                0
# loan_default                              0
# unspecified                               0
# debt_yield_fall                           0
# mezzanine_default                         0
# bankruptcy                                0
# tenant_failure                            0
# renovations                               0
# aggregate_debt_yield_fall                 0
# dscr_fall                                 0
# operator_termination                      0
# sponsor_termination                       0
# sff                                       0
# mezzanine_outstanding                     0
# aggregate_dscr_fall                       0
# delayed_repayment                         0

# %%
results_df.set_index('target', inplace = True)

# %%
final_misclassified_as_true
# Out:
#                            prediction  actual nontrigger loan_default  \
# nontrigger                        7.0     0.0          0            1
# loan_default                     15.0     0.0          3            0
# unspecified                      14.0     0.0          4            5
# debt_yield_fall                   2.0     0.0          0            2
# mezzanine_default                 5.0     0.0          1            2
# bankruptcy                        0.0     0.0          0            0
# tenant_failure                    2.0     0.0          0            1
# renovations                       1.0     0.0          1            0
# aggregate_debt_yield_fall         1.0     0.0          0            0
# dscr_fall                         0.0     0.0          0            0
# operator_termination              1.0     0.0          0            0
# sponsor_termination               1.0     0.0          0            1
# sff                               0.0     0.0          0            0
# mezzanine_outstanding             0.0     0.0          0            0
# aggregate_dscr_fall               0.0     0.0          0            0
# delayed_repayment                 0.0     0.0          0            0
#
#                           unspecified debt_yield_fall mezzanine_default  \
# nontrigger                          0               1                 0
# loan_default                        7               3                 1
# unspecified                         0               0                 0
# debt_yield_fall                     0               0                 1
# mezzanine_default                   1               2                 0
# bankruptcy                          0               0                 0
# tenant_failure                      1               0                 0
# renovations                         0               0                 0
# aggregate_debt_yield_fall           0               1                 0
# dscr_fall                           0               0                 0
# operator_termination                0               0                 0
# sponsor_termination                 0               0                 0
# sff                                 0               0                 0
# mezzanine_outstanding               0               0                 0
# aggregate_dscr_fall                 0               0                 0
# delayed_repayment                   0               0                 0
#
#                           bankruptcy tenant_failure renovations  \
# nontrigger                         1              1           2
# loan_default                       0              1           0
# unspecified                        0              0           0
# debt_yield_fall                    0              0           0
# mezzanine_default                  0              3           0
# bankruptcy                         0              0           0
# tenant_failure                     0              0           0
# renovations                        0              0           0
# aggregate_debt_yield_fall          0              0           0
# dscr_fall                          0              0           0
# operator_termination               0              0           0
# sponsor_termination                0              0           0
# sff                                0              0           0
# mezzanine_outstanding              0              0           0
# aggregate_dscr_fall                0              0           0
# delayed_repayment                  0              0           0
#
#                           aggregate_debt_yield_fall dscr_fall  \
# nontrigger                                        0         0
# loan_default                                      0         0
# unspecified                                       0         0
# debt_yield_fall                                   1         0
# mezzanine_default                                 0         0
# bankruptcy                                        0         0
# tenant_failure                                    0         0
# renovations                                       0         0
# aggregate_debt_yield_fall                         0         0
# dscr_fall                                         0         0
# operator_termination                              0         0
# sponsor_termination                               0         0
# sff                                               0         0
# mezzanine_outstanding                             0         0
# aggregate_dscr_fall                               0         0
# delayed_repayment                                 0         0
#
#                           operator_termination sponsor_termination sff  \
# nontrigger                                   0                   0   1
# loan_default                                 0                   0   0
# unspecified                                  2                   0   1
# debt_yield_fall                              0                   0   0
# mezzanine_default                            0                   0   0
# bankruptcy                                   0                   0   0
# tenant_failure                               0                   0   0
# renovations                                  0                   0   0
# aggregate_debt_yield_fall                    0                   0   0
# dscr_fall                                    0                   0   0
# operator_termination                         0                   0   0
# sponsor_termination                          0                   0   0
# sff                                          0                   0   0
# mezzanine_outstanding                        0                   0   0
# aggregate_dscr_fall                          0                   0   0
# delayed_repayment                            0                   0   0
#
#                           mezzanine_outstanding aggregate_dscr_fall  \
# nontrigger                                    0                   0
# loan_default                                  0                   0
# unspecified                                   2                   0
# debt_yield_fall                               0                   0
# mezzanine_default                             0                   0
# bankruptcy                                    0                   0
# tenant_failure                                0                   0
# renovations                                   0                   0
# aggregate_debt_yield_fall                     0                   0
# dscr_fall                                     0                   0
# operator_termination                          1                   0
# sponsor_termination                           0                   0
# sff                                           0                   0
# mezzanine_outstanding                         0                   0
# aggregate_dscr_fall                           0                   0
# delayed_repayment                             0                   0
#
#                           delayed_repayment
# nontrigger                                0
# loan_default                              0
# unspecified                               0
# debt_yield_fall                           0
# mezzanine_default                         0
# bankruptcy                                0
# tenant_failure                            0
# renovations                               0
# aggregate_debt_yield_fall                 0
# dscr_fall                                 0
# operator_termination                      0
# sponsor_termination                       0
# sff                                       0
# mezzanine_outstanding                     0
# aggregate_dscr_fall                       0
# delayed_repayment                         0

# %%
final_misclassified_as_false = results_df[['count_deduplicated', 'train_score', 'test_score']].merge(final_misclassified_as_false, left_index = True, right_index = True)
final_misclassified_as_false
# Out:
#                            count_deduplicated  train_score  test_score  \
# nontrigger                               1030     0.992347    0.976190
# loan_default                              531     0.985332    0.947917
# unspecified                               485     0.994898    0.955357
# debt_yield_fall                           184     1.000000    0.991071
# mezzanine_default                          67     0.999362    0.986607
# bankruptcy                                 44     0.998724    0.998512
# tenant_failure                             74     1.000000    0.933333
# renovations                                24     0.969697    0.666667
# aggregate_debt_yield_fall                  18     1.000000    0.666667
# dscr_fall                                  23     0.967742    0.444444
# operator_termination                       17     1.000000    0.500000
# sponsor_termination                        14     1.000000    0.571429
# sff                                         9     1.000000    0.500000
# mezzanine_outstanding                       8     0.909091    0.000000
# aggregate_dscr_fall                         8     1.000000    0.666667
# delayed_repayment                           3     1.000000    0.000000
#
#                            prediction  actual nontrigger loan_default  \
# nontrigger                        0.0     9.0          9            0
# loan_default                      0.0    20.0          0           20
# unspecified                       0.0    16.0          0            0
# debt_yield_fall                   0.0     4.0          0            3
# mezzanine_default                 0.0     4.0          0            4
# bankruptcy                        0.0     1.0          0            1
# tenant_failure                    0.0     1.0          0            0
# renovations                       0.0     3.0          0            1
# aggregate_debt_yield_fall         0.0     2.0          0            0
# dscr_fall                         0.0     5.0          0            2
# operator_termination              0.0     3.0          1            2
# sponsor_termination               0.0     2.0          0            0
# sff                               0.0     2.0          0            0
# mezzanine_outstanding             0.0     2.0          0            2
# aggregate_dscr_fall               0.0     1.0          0            1
# delayed_repayment                 0.0     1.0          0            1
#
#                           unspecified debt_yield_fall mezzanine_default  \
# nontrigger                          0               0                 0
# loan_default                        0               7                 4
# unspecified                        16               0                 0
# debt_yield_fall                     0               4                 1
# mezzanine_default                   0               1                 4
# bankruptcy                          0               1                 0
# tenant_failure                      0               0                 0
# renovations                         0               1                 0
# aggregate_debt_yield_fall           0               1                 0
# dscr_fall                           0               0                 2
# operator_termination                0               2                 2
# sponsor_termination                 0               0                 0
# sff                                 0               0                 0
# mezzanine_outstanding               0               0                 0
# aggregate_dscr_fall                 0               0                 0
# delayed_repayment                   0               0                 1
#
#                           bankruptcy tenant_failure renovations  \
# nontrigger                         0              0           0
# loan_default                       0              8           0
# unspecified                        0              0           0
# debt_yield_fall                    1              0           0
# mezzanine_default                  0              0           0
# bankruptcy                         1              0           1
# tenant_failure                     0              1           0
# renovations                        1              0           3
# aggregate_debt_yield_fall          0              0           0
# dscr_fall                          0              2           0
# operator_termination               0              2           0
# sponsor_termination                0              0           0
# sff                                0              0           0
# mezzanine_outstanding              0              0           0
# aggregate_dscr_fall                0              0           0
# delayed_repayment                  0              1           0
#
#                           aggregate_debt_yield_fall dscr_fall  \
# nontrigger                                        0         0
# loan_default                                      0         0
# unspecified                                       0         0
# debt_yield_fall                                   0         0
# mezzanine_default                                 1         0
# bankruptcy                                        0         0
# tenant_failure                                    0         0
# renovations                                       0         0
# aggregate_debt_yield_fall                         2         0
# dscr_fall                                         0         5
# operator_termination                              0         0
# sponsor_termination                               0         0
# sff                                               0         0
# mezzanine_outstanding                             0         0
# aggregate_dscr_fall                               0         0
# delayed_repayment                                 0         1
#
#                           operator_termination sponsor_termination sff  \
# nontrigger                                   0                   0   0
# loan_default                                 0                   0   0
# unspecified                                  0                   0   0
# debt_yield_fall                              0                   0   0
# mezzanine_default                            0                   0   1
# bankruptcy                                   0                   0   0
# tenant_failure                               0                   0   0
# renovations                                  0                   0   0
# aggregate_debt_yield_fall                    0                   0   0
# dscr_fall                                    0                   0   0
# operator_termination                         3                   0   2
# sponsor_termination                          0                   2   0
# sff                                          0                   0   2
# mezzanine_outstanding                        2                   0   0
# aggregate_dscr_fall                          0                   0   0
# delayed_repayment                            0                   0   0
#
#                           mezzanine_outstanding aggregate_dscr_fall  \
# nontrigger                                    0                   0
# loan_default                                  0                   0
# unspecified                                   0                   0
# debt_yield_fall                               0                   0
# mezzanine_default                             0                   0
# bankruptcy                                    0                   0
# tenant_failure                                0                   0
# renovations                                   0                   0
# aggregate_debt_yield_fall                     0                   0
# dscr_fall                                     0                   1
# operator_termination                          0                   0
# sponsor_termination                           0                   0
# sff                                           0                   0
# mezzanine_outstanding                         2                   0
# aggregate_dscr_fall                           0                   1
# delayed_repayment                             0                   0
#
#                           delayed_repayment
# nontrigger                                0
# loan_default                              0
# unspecified                               0
# debt_yield_fall                           0
# mezzanine_default                         0
# bankruptcy                                0
# tenant_failure                            0
# renovations                               0
# aggregate_debt_yield_fall                 0
# dscr_fall                                 1
# operator_termination                      0
# sponsor_termination                       0
# sff                                       0
# mezzanine_outstanding                     0
# aggregate_dscr_fall                       0
# delayed_repayment                         1

# %%
final_misclassified_as_true = results_df[['count_deduplicated', 'test_data_count','train_score', 'test_score']].merge(final_misclassified_as_true, left_index = True, right_index = True)
final_misclassified_as_true
# Out:
#                            count_deduplicated  test_data_count  train_score  \
# nontrigger                               1030              309     0.992347
# loan_default                              531              159     0.985332
# unspecified                               485              146     0.994898
# debt_yield_fall                           184               55     1.000000
# mezzanine_default                          67               20     0.999362
# bankruptcy                                 44               13     0.998724
# tenant_failure                             74               22     1.000000
# renovations                                24                7     0.969697
# aggregate_debt_yield_fall                  18                5     1.000000
# dscr_fall                                  23                7     0.967742
# operator_termination                       17                5     1.000000
# sponsor_termination                        14                4     1.000000
# sff                                         9                3     1.000000
# mezzanine_outstanding                       8                2     0.909091
# aggregate_dscr_fall                         8                2     1.000000
# delayed_repayment                           3                1     1.000000
#
#                            test_score  prediction  actual nontrigger  \
# nontrigger                   0.976190         7.0     0.0          0
# loan_default                 0.947917        15.0     0.0          3
# unspecified                  0.955357        14.0     0.0          4
# debt_yield_fall              0.991071         2.0     0.0          0
# mezzanine_default            0.986607         5.0     0.0          1
# bankruptcy                   0.998512         0.0     0.0          0
# tenant_failure               0.933333         2.0     0.0          0
# renovations                  0.666667         1.0     0.0          1
# aggregate_debt_yield_fall    0.666667         1.0     0.0          0
# dscr_fall                    0.444444         0.0     0.0          0
# operator_termination         0.500000         1.0     0.0          0
# sponsor_termination          0.571429         1.0     0.0          0
# sff                          0.500000         0.0     0.0          0
# mezzanine_outstanding        0.000000         0.0     0.0          0
# aggregate_dscr_fall          0.666667         0.0     0.0          0
# delayed_repayment            0.000000         0.0     0.0          0
#
#                           loan_default unspecified debt_yield_fall  \
# nontrigger                           1           0               1
# loan_default                         0           7               3
# unspecified                          5           0               0
# debt_yield_fall                      2           0               0
# mezzanine_default                    2           1               2
# bankruptcy                           0           0               0
# tenant_failure                       1           1               0
# renovations                          0           0               0
# aggregate_debt_yield_fall            0           0               1
# dscr_fall                            0           0               0
# operator_termination                 0           0               0
# sponsor_termination                  1           0               0
# sff                                  0           0               0
# mezzanine_outstanding                0           0               0
# aggregate_dscr_fall                  0           0               0
# delayed_repayment                    0           0               0
#
#                           mezzanine_default bankruptcy tenant_failure  \
# nontrigger                                0          1              1
# loan_default                              1          0              1
# unspecified                               0          0              0
# debt_yield_fall                           1          0              0
# mezzanine_default                         0          0              3
# bankruptcy                                0          0              0
# tenant_failure                            0          0              0
# renovations                               0          0              0
# aggregate_debt_yield_fall                 0          0              0
# dscr_fall                                 0          0              0
# operator_termination                      0          0              0
# sponsor_termination                       0          0              0
# sff                                       0          0              0
# mezzanine_outstanding                     0          0              0
# aggregate_dscr_fall                       0          0              0
# delayed_repayment                         0          0              0
#
#                           renovations aggregate_debt_yield_fall dscr_fall  \
# nontrigger                          2                         0         0
# loan_default                        0                         0         0
# unspecified                         0                         0         0
# debt_yield_fall                     0                         1         0
# mezzanine_default                   0                         0         0
# bankruptcy                          0                         0         0
# tenant_failure                      0                         0         0
# renovations                         0                         0         0
# aggregate_debt_yield_fall           0                         0         0
# dscr_fall                           0                         0         0
# operator_termination                0                         0         0
# sponsor_termination                 0                         0         0
# sff                                 0                         0         0
# mezzanine_outstanding               0                         0         0
# aggregate_dscr_fall                 0                         0         0
# delayed_repayment                   0                         0         0
#
#                           operator_termination sponsor_termination sff  \
# nontrigger                                   0                   0   1
# loan_default                                 0                   0   0
# unspecified                                  2                   0   1
# debt_yield_fall                              0                   0   0
# mezzanine_default                            0                   0   0
# bankruptcy                                   0                   0   0
# tenant_failure                               0                   0   0
# renovations                                  0                   0   0
# aggregate_debt_yield_fall                    0                   0   0
# dscr_fall                                    0                   0   0
# operator_termination                         0                   0   0
# sponsor_termination                          0                   0   0
# sff                                          0                   0   0
# mezzanine_outstanding                        0                   0   0
# aggregate_dscr_fall                          0                   0   0
# delayed_repayment                            0                   0   0
#
#                           mezzanine_outstanding aggregate_dscr_fall  \
# nontrigger                                    0                   0
# loan_default                                  0                   0
# unspecified                                   2                   0
# debt_yield_fall                               0                   0
# mezzanine_default                             0                   0
# bankruptcy                                    0                   0
# tenant_failure                                0                   0
# renovations                                   0                   0
# aggregate_debt_yield_fall                     0                   0
# dscr_fall                                     0                   0
# operator_termination                          1                   0
# sponsor_termination                           0                   0
# sff                                           0                   0
# mezzanine_outstanding                         0                   0
# aggregate_dscr_fall                           0                   0
# delayed_repayment                             0                   0
#
#                           delayed_repayment
# nontrigger                                0
# loan_default                              0
# unspecified                               0
# debt_yield_fall                           0
# mezzanine_default                         0
# bankruptcy                                0
# tenant_failure                            0
# renovations                               0
# aggregate_debt_yield_fall                 0
# dscr_fall                                 0
# operator_termination                      0
# sponsor_termination                       0
# sff                                       0
# mezzanine_outstanding                     0
# aggregate_dscr_fall                       0
# delayed_repayment                         0

# %%
# Export to CSV file

#final_misclassified_as_false.to_csv(f'../data/exported_data/misclassified_as_false_06_15_20.csv')
#final_misclassified_as_true.to_csv(f'../data/exported_data/misclassified_as_true_06_15_20.csv')
